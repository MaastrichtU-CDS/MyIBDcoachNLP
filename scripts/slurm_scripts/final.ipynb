# %% [markdown]
# # BERTopic Analysis of IBD Patient Messages

# %% [markdown]
# ### 1. Data Pre-Processing
# Run the following script to read, clean and save pre-processed data for analysis

# %%
# %run ./scripts/slurm_scripts/data_preprocessing.py --data data/anonymized_berichten.xlsx --output_path data/cleaned_patient_messages.xlsx
# Out:
# Dataset loaded.
# Number of total messages in dataset: 33237
# Time range of messages in dataset: 2014-09-23 12:26:59.407 to 2022-10-19 09:19:18.327
#
# =============Cleaning patient messages=================
# Number of messages from patients before cleaning: 13199
# Number of unique patient users in dataframe: 633
# Time range of messages: 2014-09-23 12:26:59.407 to 2022-10-19 09:19:18.327
# Step 1: Removing HTML tags...
# Step 2: Replacing numbered patterns in entity placeholders...
# Step 3: Removing greetings and sign-offs...
# Step 4: Dropping empty messages after cleaning...
# Number of messages from patients after cleaning: 13193
# ✅ Messages cleaned and saved to data/cleaned_patient_messages.xlsx
#
# ==========Splitting messages into sentences with NLTK=========
# Step 1: Automatic splitting with NLTK sentence tokenizer...
# Step 2: Manual splitting of long sentences exceeding 400 characters...
# Step 3: Correcting incorrect splits due to abbreviations...
# ...

# %% [markdown]
# # Add removal of duplicated messages to the script!!
