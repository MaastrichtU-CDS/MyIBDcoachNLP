# %% [markdown]
# # SBERT Sentence Analysis

# %% [markdown]
# ## 1. Preparations

# %% [markdown]
# ### 1.1 Read Data
# This new data is obtained after some further anonymization, and by putting previously incorrectly split sentences together, and removed duplicates

# %%
import pandas as pd
# read the sentence data 
df = pd.read_excel("/workspace/persistent/mijnidbcoachnlp/data/analysis_data_2021/translated_sentence_data_new.xlsx")
# check the he
# ad
df.head()
# Out:
#    Message_ID                                           Sentence  \
# 0           3  Ik ben 2 weken geleden met spoed opgenomen in ...
# 1           3  Ik kreeg acuut een pijnlijke druk op de borst,...
# 2           3                  Het begon 1 uur na het avondeten.
# 3           3  Ik had al de hele dag migraine, had dus ook we...
# 4           3  Ik werd heel erg misselijk, braakneigingen, du...
#
#                                       Clean_Sentence  Sentence_ID  \
# 0  Ik ben 2 weken geleden met spoed opgenomen in ...            1
# 1  Ik kreeg acuut een pijnlijke druk op de borst,...            2
# 2                  Het begon 1 uur na het avondeten.            3
# 3  Ik had al de hele dag migraine, had dus ook we...            4
# 4  Ik werd heel erg misselijk, braakneigingen, du...            5
#
#                                  Translated_Sentence
# 0  I was rushed into the [PRESSION] two weeks ago...
# 1  I was acutely under a painful pressure on the ...
# 2                    It started 1 hour after dinner.
# 3   I had migraines all day, so I hadn't eaten much.
# 4  I got very nauseous, vomiting, dizzy and rejuv...

# %%
# clean sentences as inputs
sentences = df["Clean_Sentence"].to_list()

# %%
# print the size of the data
len(sentences)
# There are 41143 sentences
# Out:
# 41143

# %% [markdown]
# ### 1.2. Import the list of stopwords

# %%
### Importing the list of Dutch stopwords (note that there are customized dutch words in there)

with open('/workspace/persistent/mijnidbcoachnlp/data/analysis_data_2021/stopwords.txt', 'r') as file:
    lines = [line.strip() for line in file.readlines()]

dutch_stopwords = lines

# %%
# Extend the stop words if needed
extra_list = [
    'maandag', 'dinsdag', 'woensdag', 'donderdag', 'vrijdag', 'zaterdag', 'zondag',
    'januari', 'februari', 'maart', 'april', 'mei', 'juni', 'juli', 'augustus', 'september', 'oktober', 'november', 'december',
    'jan', 'feb', 'mrt', 'apr', 'mei', 'jun', 'jul', 'aug', 'sep', 'okt', 'nov', 'dec', "jl", "weken", "week", "dagen", "dag", "mg", "coach", "mijnibdcoach", "dr", "uur", "dgs"
]

dutch_stopwords.extend(extra_list)

# %% [markdown]
# ### 1.4. Embed the lists of sentences with sentence-transformer multilingual-v1

# %%
from sentence_transformers import SentenceTransformer
import numpy as np

# load the embedding model
embedding_model = SentenceTransformer("distiluse-base-multilingual-cased-v1")

# run the following for embeddings if no pre-saved embeddings can be loaded
#embeddings = embedding_model.encode(sentences, show_progress_bar=True)
# save the pre-calculated embeddings 
#np.save('/workspace/mijnidbcoachnlp/data/embeddings/embeddings_st_v1_new_input.npy', embeddings)
# Out:
# /workspace/persistent/mijnidbcoachnlp/venv/lib/python3.8/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
from sentence_transformers import SentenceTransformer
import numpy as np
# load pre-saved embeddings if you have, otherwise calculate them using the commented-out codes
#embedding_model = SentenceTransformer("distiluse-base-multilingual-cased-v1")
embeddings = np.load("/workspace/persistent/mijnidbcoachnlp/data/embeddings/embeddings_st_v1_new_input.npy")

# %% [markdown]
# ### 1.5. Tokenize the documents for c_v score calculation

# %%
# download nltk and spacy library
import spacy
import nltk
from nltk.tokenize import word_tokenize

# Download NLTK's tokenizer (only needed once)
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# load spacy's tokenizer
nlp = spacy.load("nl_core_news_sm")

# %%
import nltk
from nltk.tokenize import word_tokenize

#nltk
tokenized_texts_nltk = [word_tokenize(sentence, language="dutch") for sentence in sentences]

# %%
tokenized_texts_nltk[:20]
# Out:
# [['Ik',
#   'ben',
#   '2',
#   'weken',
#   'geleden',
#   'met',
#   'spoed',
#   'opgenomen',
#   'in',
#   'het',
#   'in',
#   'met',
#   'verdenking',
#   'van',
#   'hartklachten',
#   '.'],
#  ['Ik',
#   'kreeg',
#   'acuut',
#   'een',
#   'pijnlijke',
#   'druk',
#   'op',
#   'de',
#   'borst',
#   ',',
#   'schouderbladen',
#   ',',
#   'uitstralend',
#   'naar',
#   'de',
#   'armen',
#   '.'],
#  ['Het', 'begon', '1', 'uur', 'na', 'het', 'avondeten', '.'],
#  ['Ik',
#   'had',
#   'al',
#   'de',
#   'hele',
#   'dag',
#   'migraine',
#   ',',
#   'had',
#   'dus',
#   'ook',
#   'weinig',
#   'gegeten',
#   '.'],
#  ['Ik',
#   'werd',
#   'heel',
#   'erg',
#   'misselijk',
#   ',',
#   'braakneigingen',
#   ',',
#   'duizelig',
#   'en',
#   'oprispingen.En',
#   'vreselijke',
#   'pijn',
#   '.'],
#  ['Op',
#   'de',
#   'eerste',
#   'hulp',
#   'hebben',
#   'ze',
#   'het',
#   'hart',
#   'de',
#   'longen',
#   'en',
#   'de',
#   'bloedvaten',
#   'onderzocht',
#   '.'],
#  ['er', 'kwamen', 'geen', 'rare', 'dingen', 'uit', '.'],
#  ['Later',
#   'op',
#   'de',
#   'dag',
#   'bij',
#   'het',
#   'eten',
#   'van',
#   'een',
#   'beschuitje',
#   'begon',
#   'het',
#   'weer',
#   '.'],
#  ['Ze',
#   'hebben',
#   'een',
#   'echo',
#   'van',
#   'de',
#   'gal',
#   'gemaakt',
#   'ook',
#   'zonder',
#   'resultaat',
#   '.'],
#  ['Er',
#   'is',
#   'nog',
#   'een',
#   'aanvullend',
#   'onderzoek',
#   'van',
#   'de',
#   'slokdarm',
#   'en',
#   'de',
#   'maag',
#   'gedaan',
#   ',',
#   'ook',
#   'geen',
#   'resultaat',
#   '.'],
#  ['Ik',
#   'heb',
#   'nog',
#   'altijd',
#   'last',
#   'van',
#   'oprispingen',
#   ',',
#   'hoofdpijn',
#   'en',
#   'gevoelig',
#   'rond',
#   'de',
#   'maagstreek',
#   '.'],
#  ['die',
#   'enorme',
#   'pijn',
#   'heb',
#   'ik',
#   'gelukkig',
#   'niet',
#   'meer',
#   'gehad',
#   '.'],
#  ['Morgen',
#   'moet',
#   'ik',
#   'bij',
#   'jullie',
#   'bloedprikken',
#   ',',
#   'en',
#   'ontlasting',
#   'inleveren',
#   '.'],
#  ['Toch', 'voelt', 'het', 'niet', 'helemaal', 'oke', '.'],
#  ['Mijn', 'bloeduitslagen', 'zijn', 'goed', 'hoor', 'ik', '.'],
#  ['Daar', 'ben', 'ik', 'blij', 'mee', '.'],
#  ['Toch', 'blijven', 'mijn', 'klachten', 'aanhouden', '.'],
#  ['Opboeren',
#   ',',
#   'branderige',
#   'pijn',
#   'in',
#   'de',
#   'maagstreek',
#   'na',
#   'het',
#   'eten',
#   '.'],
#  ['Opgeblazen', 'gevoel', '.'],
#  ['Soms',
#   'pijnscheuten',
#   'die',
#   'aanvalsgewijs',
#   'komen',
#   'rond',
#   'het',
#   'borstbeen',
#   '.']]

# %%
# load spacy's tokenizer
nlp = spacy.load("nl_core_news_sm")
tokenized_texts_spacy = [[token.text for token in nlp(sentence)] for sentence in sentences]

# %%
tokenized_texts_spacy[:20]
# Out:
# [['Ik',
#   'ben',
#   '2',
#   'weken',
#   'geleden',
#   'met',
#   'spoed',
#   'opgenomen',
#   'in',
#   'het',
#   ' ',
#   'in',
#   ' ',
#   'met',
#   'verdenking',
#   'van',
#   'hartklachten',
#   '.'],
#  ['Ik',
#   'kreeg',
#   'acuut',
#   'een',
#   'pijnlijke',
#   'druk',
#   'op',
#   'de',
#   'borst',
#   ',',
#   'schouderbladen',
#   ',',
#   'uitstralend',
#   'naar',
#   'de',
#   'armen',
#   '.'],
#  ['Het', 'begon', '1', 'uur', 'na', 'het', 'avondeten', '.'],
#  ['Ik',
#   'had',
#   'al',
#   'de',
#   'hele',
#   'dag',
#   'migraine',
#   ',',
#   'had',
#   'dus',
#   'ook',
#   'weinig',
#   'gegeten',
#   '.'],
#  ['Ik',
#   'werd',
#   'heel',
#   'erg',
#   'misselijk',
#   ',',
#   'braakneigingen',
#   ',',
#   'duizelig',
#   'en',
#   'oprispingen',
#   '.',
#   'En',
#   'vreselijke',
#   'pijn',
#   '.'],
#  ['Op',
#   'de',
#   'eerste',
#   'hulp',
#   'hebben',
#   'ze',
#   'het',
#   'hart',
#   'de',
#   'longen',
#   'en',
#   'de',
#   'bloedvaten',
#   'onderzocht',
#   '.'],
#  ['er', 'kwamen', 'geen', 'rare', 'dingen', 'uit', '.'],
#  ['Later',
#   'op',
#   'de',
#   'dag',
#   'bij',
#   'het',
#   'eten',
#   'van',
#   'een',
#   'beschuitje',
#   'begon',
#   'het',
#   'weer',
#   '.'],
#  ['Ze',
#   'hebben',
#   'een',
#   'echo',
#   'van',
#   'de',
#   'gal',
#   'gemaakt',
#   'ook',
#   'zonder',
#   'resultaat',
#   '.'],
#  ['Er',
#   'is',
#   'nog',
#   'een',
#   'aanvullend',
#   'onderzoek',
#   'van',
#   'de',
#   'slokdarm',
#   'en',
#   'de',
#   'maag',
#   'gedaan',
#   ',',
#   'ook',
#   'geen',
#   'resultaat',
#   '.'],
#  ['Ik',
#   'heb',
#   'nog',
#   'altijd',
#   'last',
#   'van',
#   'oprispingen',
#   ',',
#   'hoofdpijn',
#   'en',
#   'gevoelig',
#   'rond',
#   'de',
#   'maagstreek',
#   '.'],
#  ['die',
#   'enorme',
#   'pijn',
#   'heb',
#   'ik',
#   'gelukkig',
#   'niet',
#   'meer',
#   'gehad',
#   '.'],
#  ['Morgen',
#   'moet',
#   'ik',
#   'bij',
#   'jullie',
#   'bloedprikken',
#   ',',
#   'en',
#   'ontlasting',
#   'inleveren',
#   '.'],
#  ['Toch', 'voelt', 'het', 'niet', 'helemaal', 'oke', '.'],
#  ['Mijn', 'bloeduitslagen', 'zijn', 'goed', 'hoor', 'ik', '.'],
#  ['Daar', 'ben', 'ik', 'blij', 'mee', '.'],
#  ['Toch', 'blijven', 'mijn', 'klachten', 'aanhouden', '.'],
#  ['Opboeren',
#   ',',
#   'branderige',
#   'pijn',
#   'in',
#   'de',
#   'maagstreek',
#   'na',
#   'het',
#   'eten',
#   '.'],
#  ['Opgeblazen', 'gevoel', '.'],
#  ['Soms',
#   'pijnscheuten',
#   'die',
#   'aanvalsgewijs',
#   'komen',
#   'rond',
#   'het',
#   'borstbeen',
#   '.']]

# %%
tokenized_texts_plain = [doc.split() for doc in sentences]  # Tokenizing by splitting on spaces

# %%
# inspect the tokenized texts to see which one is better
tokenized_texts = tokenized_texts_nltk

# %%
from gensim.models.coherencemodel import CoherenceModel
from gensim.corpora.dictionary import Dictionary

# Create a dictionary representation of the words in topics
dictionary = Dictionary(tokenized_texts)

def get_top_words(topic_model):
    topics = topic_model.get_topics()
    top_words = [[word for word, _ in topic[:10]] for topic in topics.values() if topic]  # Top 10 words per topic
    return top_words

def calculate_c_v(topic_model):
    top_words = get_top_words(topic_model)
    coherence_model = CoherenceModel(topics=top_words, 
                                texts=tokenized_texts,
                                dictionary=dictionary, 
                                coherence='c_v')
    coherence_score = coherence_model.get_coherence()
    return coherence_score

# %%
# disable parallelism to avoid some warnings
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %% [markdown]
# ## 2. Fit a topic model in four modules

# %%
# Embedding
# Was already done so here we check the dimensions of the embedding
embeddings.shape
# Out:
# (41143, 512)

# %%
# Dimensionality reduction
from umap import UMAP
umap_model = UMAP(
    n_components=5,
    min_dist=0.0,
    metric="cosine",
    n_jobs=1, # setting n_jobs=1 to disable parallelism for reproducibility, for n_jobs > 1, set randome_state = None
    random_state=42)

reduced_embeddings = umap_model.fit_transform(embeddings)

# %%
reduced_embeddings.shape
# now each of the 41143 sentences has a dimension of 5
# Out:
# (41143, 5)

# %%
from hdbscan import HDBSCAN

hdbscan_model = HDBSCAN(
    min_cluster_size = int(np.log(len(reduced_embeddings)) * 5),  # Example heuristic
    metric="euclidean",
    cluster_selection_method="eom"
)

hdbscan_model.fit(reduced_embeddings)

clusters = hdbscan_model.labels_

# %%
len(clusters)
# Out:
# 41143

# %%
import random
import pickle
from sklearn.feature_extraction.text import CountVectorizer
from bertopic import BERTopic
from umap import UMAP
from hdbscan import HDBSCAN

# Precompute embeddings (this part depends on your chosen embedding model)
# Example: Assuming 'embeddings' is already computed and available
# embeddings = embedding_model.encode(sentences)

# Initialize BERTopic with the pre-fit vectorizer
topic_model = BERTopic()

# Define parameter ranges
range_n_neighbors = [10, 20, 30, 40, 50]
range_n_components = [2, 3, 4, 5, 6]
range_min_dist = [0.0, 0.05, 0.1]

# Number of random configurations to generate
num_configs = 3  # Adjust this as needed

# Generate random UMAP configurations
umap_configs = [
    {
        "n_neighbors": random.choice(range_n_neighbors),
        "n_components": random.choice(range_n_components),
        "min_dist": random.choice(range_min_dist),
    }
    for _ in range(num_configs)
]

# Define the ranges for HDBSCAN configurations
range_min_cluster_size = [10, 20, 30]  # Example values
range_min_samples = [10, 20, 30]  # Example values

# Generate random HDBSCAN configurations
hdbscan_configs = [
    {
        "min_cluster_size": random.choice(range_min_cluster_size),
        "min_samples": random.choice([x for x in range_min_samples if x <= random.choice(range_min_cluster_size)]),
    }
    for _ in range(num_configs)
]

# Initialize a dictionary to keep track of configurations and their associated coherence scores
tried_configs = {}

# Optionally, load previously tried configurations from a file (if running multiple times)
try:
    with open("tried_configs_st.pkl", "rb") as f:
        tried_configs = pickle.load(f)
except FileNotFoundError:
    pass  # If no previous file exists, we start fresh

# Variables to track the best model
best_topic_model = None
best_coherence_score = -float('inf')  # Initializing to a very low score
best_configure = None

# Set the outlier thresholds (upper and lower)
upper_outlier_threshold = 0.5  # Maximum allowed outlier percentage (5% of points)
lower_outlier_threshold = 0.2  # Minimum allowed outlier percentage (2% of points)

# %%
# Fine-tuning loop
for umap_params in umap_configs:
    for hdbscan_params in hdbscan_configs:
        config_tuple = (frozenset(umap_params.items()), frozenset(hdbscan_params.items()))

        # Skip if the configuration has already been tried
        if config_tuple in tried_configs:
            print(f"Skipping already tried configuration: {umap_params}, {hdbscan_params}")
            continue

        # Initialize UMAP and HDBSCAN with current configurations
        umap_model = UMAP(**umap_params)
        hdbscan_model = HDBSCAN(**hdbscan_params)
        print(f"Fitting model for UMAP {umap_params} and HDBSCAN {hdbscan_params}")

        # Update BERTopic with the new UMAP and HDBSCAN models
        topic_model.umap_model = umap_model
        topic_model.hdbscan_model = hdbscan_model
        topic_model.vectorizer_model = CountVectorizer(stop_words=dutch_stopwords, min_df=2, ngram_range=(1, 1), token_pattern=r'\b[a-zA-Z]{3,}\b')
        topic_model.calculate_probabilities = False

        # Fit the model
        topics, probs = topic_model.fit_transform(sentences, embeddings)

        # Calculate coherence score
        current_coherence_score = calculate_c_v(topic_model)

        # Check if the model has at least 20 topics
        num_topics = len(topic_model.get_topics())
        if num_topics < 20:
            print(f"Skipping model with {num_topics} topics (less than 20).")
            tried_configs[config_tuple] = "skipped"
            continue

        # Check outlier percentage
        outlier_cluster_size = sum(1 for label in hdbscan_model.labels_ if label == -1)
        outlier_percentage = outlier_cluster_size / len(hdbscan_model.labels_)
        
        if outlier_percentage > upper_outlier_threshold:
            print(f"Skipping model with {outlier_percentage * 100}% outliers (above {upper_outlier_threshold * 100}%).")
            tried_configs[config_tuple] = "skipped"
            continue
        elif outlier_percentage < lower_outlier_threshold:
            print(f"Skipping model with {outlier_percentage * 100}% outliers (below {lower_outlier_threshold * 100}%).")
            tried_configs[config_tuple] = "skipped"
            continue
        
        # Store the valid configuration and score
        tried_configs[config_tuple] = current_coherence_score

        # Update best model
        if current_coherence_score > best_coherence_score:
            best_coherence_score = current_coherence_score
            best_topic_model = topic_model
            best_configure = (umap_params, hdbscan_params)

        print(f"Coherence score: {current_coherence_score}\n")

        # Save tried configurations after every iteration
        with open("tried_configs_st.pkl", "wb") as f:
            pickle.dump(tried_configs, f)
# Out:
# Fitting model for UMAP {'n_neighbors': 50, 'n_components': 4, 'min_dist': 0.05} and HDBSCAN {'min_cluster_size': 10, 'min_samples': 10}
# Coherence score: 0.3662643130528934
#
# Fitting model for UMAP {'n_neighbors': 50, 'n_components': 4, 'min_dist': 0.05} and HDBSCAN {'min_cluster_size': 10, 'min_samples': 20}
# Coherence score: 0.35050085496611455
#
# Fitting model for UMAP {'n_neighbors': 50, 'n_components': 4, 'min_dist': 0.05} and HDBSCAN {'min_cluster_size': 30, 'min_samples': 10}
# Coherence score: 0.3582903721014854
#
# Fitting model for UMAP {'n_neighbors': 20, 'n_components': 4, 'min_dist': 0.1} and HDBSCAN {'min_cluster_size': 10, 'min_samples': 10}
# Coherence score: 0.3666985394181407
#
# Fitting model for UMAP {'n_neighbors': 20, 'n_components': 4, 'min_dist': 0.1} and HDBSCAN {'min_cluster_size': 10, 'min_samples': 20}
# Coherence score: 0.36657597532332886
#
# Fitting model for UMAP {'n_neighbors': 20, 'n_components': 4, 'min_dist': 0.1} and HDBSCAN {'min_cluster_size': 30, 'min_samples': 10}
# Coherence score: 0.35086625470653837
#
# Fitting model for UMAP {'n_neighbors': 20, 'n_components': 3, 'min_dist': 0.05} and HDBSCAN {'min_cluster_size': 10, 'min_samples': 10}
# Coherence score: 0.368752327810459
#
# Fitting model for UMAP {'n_neighbors': 20, 'n_components': 3, 'min_dist': 0.05} and HDBSCAN {'min_cluster_size': 10, 'min_samples': 20}
# Coherence score: 0.3552550163346731
#
# Skipping already tried configuration: {'n_neighbors': 20, 'n_components': 3, 'min_dist': 0.05}, {'min_cluster_size': 30, 'min_samples': 10}

# %%
# After the loop, print the best configurations and score
print("Best UMAP and HDBSCAN configurations based on coherence score:")
print(f"Best Coherence Score: {best_coherence_score}")
print(f"Best UMAP Params: {best_configure[0]}")
print(f"Best HDBSCAN Params: {best_configure[1]}")
# Out:
# Best UMAP and HDBSCAN configurations based on coherence score:
# Best Coherence Score: 0.368752327810459
# Best UMAP Params: {'n_neighbors': 20, 'n_components': 3, 'min_dist': 0.05}
# Best HDBSCAN Params: {'min_cluster_size': 10, 'min_samples': 10}

# %%
import pickle

# Load the file
with open("tried_configs_st.pkl", "rb") as f:
    tried_configs = pickle.load(f)

# Print the contents
for config, score in tried_configs.items():
    print(f"Config: {config}, Score: {score}")
# Out:
# Config: (frozenset({('n_neighbors', 10), ('min_dist', 0.1), ('n_components', 5)}), frozenset({('min_cluster_size', 30), ('min_samples', 10)})), Score: 0.3425443099837642
# Config: (frozenset({('n_neighbors', 10), ('n_components', 4), ('min_dist', 0.0)}), frozenset({('min_samples', 30), ('min_cluster_size', 20)})), Score: 0.35067638061555395
# Config: (frozenset({('n_neighbors', 10), ('n_components', 4), ('min_dist', 0.0)}), frozenset({('min_cluster_size', 30), ('min_samples', 10)})), Score: 0.3362990734428644
# Config: (frozenset({('n_neighbors', 10), ('n_components', 4), ('min_dist', 0.0)}), frozenset({('min_samples', 30), ('min_cluster_size', 10)})), Score: 0.3490907784930923
# Config: (frozenset({('n_neighbors', 10), ('n_components', 3), ('min_dist', 0.0)}), frozenset({('min_samples', 30), ('min_cluster_size', 20)})), Score: 0.33991947203180106
# Config: (frozenset({('n_neighbors', 10), ('n_components', 3), ('min_dist', 0.0)}), frozenset({('min_cluster_size', 30), ('min_samples', 10)})), Score: 0.3402959522597938
# Config: (frozenset({('n_neighbors', 10), ('n_components', 3), ('min_dist', 0.0)}), frozenset({('min_samples', 30), ('min_cluster_size', 10)})), Score: 0.3407447609808933
# Config: (frozenset({('n_neighbors', 10), ('n_components', 3), ('min_dist', 0.05)}), frozenset({('min_cluster_size', 30), ('min_samples', 10)})), Score: 0.34359721094465673
# Config: (frozenset({('n_components', 3), ('min_dist', 0.05), ('n_neighbors', 20)}), frozenset({('min_cluster_size', 30), ('min_samples', 10)})), Score: 0.3490352966230296
# Config: (frozenset({('n_components', 3), ('min_dist', 0.05), ('n_neighbors', 20)}), frozenset({('min_samples', 30), ('min_cluster_size', 20)})), Score: 0.3481460750168362
# Config: (frozenset({('n_components', 4), ('n_neighbors', 50), ('min_dist', 0.05)}), frozenset({('min_samples', 10), ('min_cluster_size', 10)})), Score: 0.3662643130528934
# Config: (frozenset({('n_components', 4), ('n_neighbors', 50), ('min_dist', 0.05)}), frozenset({('min_samples', 20), ('min_cluster_size', 10)})), Score: 0.35050085496611455
# Config: (frozenset({('n_components', 4), ('n_neighbors', 50), ('min_dist', 0.05)}), frozenset({('min_cluster_size', 30), ('min_samples', 10)})), Score: 0.3582903721014854
# Config: (frozenset({('n_components', 4), ('min_dist', 0.1), ('n_neighbors', 20)}), frozenset({('min_samples', 10), ('min_cluster_size', 10)})), Score: 0.3666985394181407
# Config: (frozenset({('n_components', 4), ('min_dist', 0.1), ('n_neighbors', 20)}), frozenset({('min_samples', 20), ('min_cluster_size', 10)})), Score: 0.36657597532332886
# Config: (frozenset({('n_components', 4), ('min_dist', 0.1), ('n_neighbors', 20)}), frozenset({('min_cluster_size', 30), ('min_samples', 10)})), Score: 0.35086625470653837
# Config: (frozenset({('n_components', 3), ('min_dist', 0.05), ('n_neighbors', 20)}), frozenset({('min_samples', 10), ('min_cluster_size', 10)})), Score: 0.368752327810459
# Config: (frozenset({('n_components', 3), ('min_dist', 0.05), ('n_neighbors', 20)}), frozenset({('min_samples', 20), ('min_cluster_size', 10)})), Score: 0.3552550163346731

# %%
best_topic_model.save("/workspace/persistent/mijnidbcoachnlp/saved_models/best_cv_score_st_model", serialization="pytorch", save_ctfidf=True, save_embedding_model=embedding_model)

# %%
calculate_c_v(best_topic_model)
# Out:
# 0.3552550163346731

# %%
best_topic_model.get_topic_info()
# Out:
#      Topic  Count                                               Name  \
# 0       -1  18597                        -1_afspraak_vraag_gaat_weet
# 1        0   3367            0_bloed_prikken_bloedprikken_ontlasting
# 2        1   1291                         1_huisarts_arts_dokter_mdl
# 3        2    556           2_medicatie_apotheek_medicijnen_medicijn
# 4        3    516                      3_pijn_buikpijn_pijnlijk_buik
# ..     ...    ...                                                ...
# 242    241     11  241_doorgestuurd_apotheekderrein_zorginstellin...
# 243    242     11             242_optie_rele_alternatieve_buitenland
# 244    243     10                243_verwachtte_kim_beloofd_schrijft
# 245    244     10              244_contactmoment_emailen_vlg_simpony
# 246    245     10             245_bijwerking_flagyl_budosenide_netol
#
#                                         Representation  \
# 0    [afspraak, vraag, gaat, weet, volgende, goed, ...
# 1    [bloed, prikken, bloedprikken, ontlasting, sli...
# 2    [huisarts, arts, dokter, mdl, ziekenhuis, cont...
# 3    [medicatie, apotheek, medicijnen, medicijn, re...
# 4    [pijn, buikpijn, pijnlijk, buik, pijnlijke, ru...
# ..                                                 ...
# 242  [doorgestuurd, apotheekderrein, zorginstelling...
# 243  [optie, rele, alternatieve, buitenland, vastge...
# 244  [verwachtte, kim, beloofd, schrijft, weekend, ...
# 245  [contactmoment, emailen, vlg, simpony, kontakt...
# 246  [bijwerking, flagyl, budosenide, netol, gewich...
#
#                                    Representative_Docs
# 0    [en/of , Het gaat de laatste 2 weken niet zo g...
# 1    [Afgelopen vrijdag ben ik bloed laten prikken....
# 2    [Ja bij mijn huisarts., Ja bij mijn huisarts.,...
# 3    [Nog steeds geen recept binnen bij apotheek!, ...
# 4    [Dit is ondoenlijk van wege de pijn!, Maar ik ...
# ..                                                 ...
# 242  [Het recept van de picoprep zou zijn doorgestu...
# 243  [Zijn er nog andere optie?, Is dit een reële o...
# 244  [Ik had beloofd nog even te laten weten hoe he...
# 245  [ik heb vorige week via de mail  nieuwe simpon...
# 246  [Misschien buikpijn als bijwerking hyrimoz?, K...
#
# [247 rows x 5 columns]

# %%
# check if reduce outliers now work
# Reduce outliers
topics = best_topic_model.topics_
new_topics = best_topic_model.reduce_outliers(sentences, topics)

# %%
best_topic_model.update_topics(sentences, topics=new_topics, vectorizer_model=CountVectorizer(stop_words=dutch_stopwords, min_df=2, ngram_range=(1, 1), token_pattern=r'\b[a-zA-Z]{3,}\b'))
# Out:
# 2025-02-13 05:22:51,663 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.

# %%
# check topic_info after outlier reduction
best_topic_model.get_topic_info()
# Out:
#      Topic  Count                                            Name  \
# 0       -1    259     -1_verstandigst_trant_heermevrouw_aangenaam
# 1        0   3567         0_bloed_prikken_ontlasting_bloedprikken
# 2        1   1458                      1_huisarts_arts_dokter_mdl
# 3        2    650        2_medicatie_medicijn_apotheek_medicijnen
# 4        3    694                   3_pijn_buikpijn_pijnlijk_buik
# ..     ...    ...                                             ...
# 242    241     36    241_doorgestuurd_picoprep_gestuurd_doorgezet
# 243    242     75    242_optie_alternatief_momenten_mogelijkheden
# 244    243     61               243_nou_wekelijks_geplande_volgen
# 245    244     48  244_gelezen_laboratorium_buikgriep_afgesproken
# 246    245     56  245_bijwerking_bijwerkingen_infliximab_innemen
#
#                                         Representation  \
# 0    [verstandigst, trant, heermevrouw, aangenaam, ...
# 1    [bloed, prikken, ontlasting, bloedprikken, sli...
# 2    [huisarts, arts, dokter, mdl, ziekenhuis, cont...
# 3    [medicatie, medicijn, apotheek, medicijnen, vo...
# 4    [pijn, buikpijn, pijnlijk, buik, pijnlijke, ru...
# ..                                                 ...
# 242  [doorgestuurd, picoprep, gestuurd, doorgezet, ...
# 243  [optie, alternatief, momenten, mogelijkheden, ...
# 244  [nou, wekelijks, geplande, volgen, geval, inna...
# 245  [gelezen, laboratorium, buikgriep, afgesproken...
# 246  [bijwerking, bijwerkingen, infliximab, innemen...
#
#                                    Representative_Docs
# 0    [en/of , Het gaat de laatste 2 weken niet zo g...
# 1    [Afgelopen vrijdag ben ik bloed laten prikken....
# 2    [Ja bij mijn huisarts., Ja bij mijn huisarts.,...
# 3    [Nog steeds geen recept binnen bij apotheek!, ...
# 4    [Dit is ondoenlijk van wege de pijn!, Maar ik ...
# ..                                                 ...
# 242  [Het recept van de picoprep zou zijn doorgestu...
# 243  [Zijn er nog andere optie?, Is dit een reële o...
# 244  [Ik had beloofd nog even te laten weten hoe he...
# 245  [ik heb vorige week via de mail  nieuwe simpon...
# 246  [Misschien buikpijn als bijwerking hyrimoz?, K...
#
# [247 rows x 5 columns]

# %%
best_topic_model.save("/workspace/persistent/mijnidbcoachnlp/saved_models/best_cv_score_st_model_ro", serialization="pytorch", save_ctfidf=True, save_embedding_model=embedding_model)

# %%
calculate_c_v(best_topic_model)
# Out:
# 0.3566552534427884

# %% [markdown]
# ##  3. Merge topics

# %%
from bertopic import BERTopic
topic_model = BERTopic.load("/workspace/persistent/mijnidbcoachnlp/saved_models/best_cv_score_st_model_ro", embedding_model=embedding_model)

# %%
topic_model.get_topic_info().head()
# Out:
#    Topic  Count                                         Name  \
# 0     -1    259  -1_verstandigst_trant_heermevrouw_aangenaam
# 1      0   3567      0_bloed_prikken_ontlasting_bloedprikken
# 2      1   1458                   1_huisarts_arts_dokter_mdl
# 3      2    650     2_medicatie_medicijn_apotheek_medicijnen
# 4      3    694                3_pijn_buikpijn_pijnlijk_buik
#
#                                       Representation  Representative_Docs
# 0  [verstandigst, trant, heermevrouw, aangenaam, ...                  NaN
# 1  [bloed, prikken, ontlasting, bloedprikken, sli...                  NaN
# 2  [huisarts, arts, dokter, mdl, ziekenhuis, cont...                  NaN
# 3  [medicatie, medicijn, apotheek, medicijnen, vo...                  NaN
# 4  [pijn, buikpijn, pijnlijk, buik, pijnlijke, ru...                  NaN

# %%
# settings for plotly
import plotly.io as pio
pio.renderers.default = "notebook"
pio.renderers.default = "browser" # option to open the plots in brower

# visualize the hierarchy and manually merge some topics
hierarchical_topics = topic_model.hierarchical_topics(sentences)
#topic_model.visualize_hierarchy(hierarchical_topics=hierarchical_topics)
# Out:
# 100%|██████████| 245/245 [00:01<00:00, 141.87it/s]

# %%
# Reduce the topics with a similarity threshold < 0.5
threshold = 0.5 # Define the threshold for merging
filtered_hierarchical_topics = hierarchical_topics[hierarchical_topics["Distance"] <= threshold]

# Ensure the loop stops when no more topics can be merged
while not filtered_hierarchical_topics.empty:  

    list_topics_to_merge = filtered_hierarchical_topics["Topics"].to_list()

    # Merge topics
    topic_model.merge_topics(sentences, list_topics_to_merge)

    # Recompute hierarchical topics after merging
    hierarchical_topics = topic_model.hierarchical_topics(sentences)

    # Update the filtered topics for the next iteration
    filtered_hierarchical_topics = hierarchical_topics[hierarchical_topics["Distance"] <= threshold]
# Out:
# 100%|██████████| 214/214 [00:01<00:00, 142.49it/s]
# 100%|██████████| 210/210 [00:01<00:00, 141.84it/s]
# 100%|██████████| 209/209 [00:01<00:00, 142.00it/s]
# 100%|██████████| 208/208 [00:01<00:00, 140.20it/s]

# %%
topic_info  = topic_model.get_topic_info()
topic_info[topic_info["Name"].str.contains("thuistes")]
# Out:
#      Topic  Count                                         Name  \
# 43      42    243               42_thuis_thuistest_huis_liggen
# 106    105    127  105_thuistesten_verwijzing_versturen_nieuwe
#
#                                                                                            Representation  \
# 43                     [thuis, thuistest, huis, liggen, gedaan, calpro, werk, ziek, uitvoeren, werkgever]
# 106  [thuistesten, verwijzing, versturen, nieuwe, oog, ontstoken, nogmaals, huisadres, zalf, terugbellen]
#
#                                                                                                                            Representative_Docs
# 43   [Nee  ik heb niks meer in huis heb wel nog thuistest hier, Ik heb deze thuistest nog niet in huis., Ik heb nog 1 thuistest thuis liggen.]
# 106                                 [Ik heb twee thuistesten., Nu was mijn vraag of ik nieuwe thuistesten kan krijgen., Thuistesten wel nog !]

# %%
doc_info = topic_model.get_document_info(sentences)
pd.set_option("display.max_colwidth", None)
doc_info[doc_info["Topic"] == 105]
# Out:
#                                                                                                                            Document  \
# 164    Ik moet nog voor een nieuwe boven en ondergebit en ik moet er ook 7 tanden laten treken dat weten de Dokters in [ZIEKENHUIS]
# 322                                                                 Heel fijn,  zou u mij ook nog 3 of 4 thuistesten kunnen sturen?
# 1131                                                                 Zouden jullie ook een verwijzing kunnen maken voor de oogarts?
# 1292                                                                     Moet ik dan nog een nieuwe voorraad Co-Trimoxazol krijgen?
# 1454                                                                                   Als die op zijn heb ik dan nog nieuwe nodig?
# ...                                                                                                                             ...
# 39767                                  Het kan een algemene ziekteverklaring zijn; die met het oog op de toekomst ook bruikbaar is.
# 39825                                                                                      Zouden jullie het opnieuw kunnen sturen?
# 40318                                                       Is het een mogelijkheid dat jullie een verwijzing sturen naar die poli?
# 40547                                                              Tja het is natuurlijk de vraag of die thuistesten het weer doen.
# 40711                                                                                  Zou u mij dan weer een nieuwe kunnen sturen?
#
#        Topic                                         Name  \
# 164      105  105_thuistesten_verwijzing_versturen_nieuwe
# 322      105  105_thuistesten_verwijzing_versturen_nieuwe
# 1131     105  105_thuistesten_verwijzing_versturen_nieuwe
# 1292     105  105_thuistesten_verwijzing_versturen_nieuwe
# 1454     105  105_thuistesten_verwijzing_versturen_nieuwe
# ...      ...                                          ...
# 39767    105  105_thuistesten_verwijzing_versturen_nieuwe
# 39825    105  105_thuistesten_verwijzing_versturen_nieuwe
# 40318    105  105_thuistesten_verwijzing_versturen_nieuwe
# 40547    105  105_thuistesten_verwijzing_versturen_nieuwe
# 40711    105  105_thuistesten_verwijzing_versturen_nieuwe
#
#                                                                                              Representation  \
# 164    [thuistesten, verwijzing, versturen, nieuwe, oog, ontstoken, nogmaals, huisadres, zalf, terugbellen]
# 322    [thuistesten, verwijzing, versturen, nieuwe, oog, ontstoken, nogmaals, huisadres, zalf, terugbellen]
# 1131   [thuistesten, verwijzing, versturen, nieuwe, oog, ontstoken, nogmaals, huisadres, zalf, terugbellen]
# 1292   [thuistesten, verwijzing, versturen, nieuwe, oog, ontstoken, nogmaals, huisadres, zalf, terugbellen]
# 1454   [thuistesten, verwijzing, versturen, nieuwe, oog, ontstoken, nogmaals, huisadres, zalf, terugbellen]
# ...                                                                                                     ...
# 39767  [thuistesten, verwijzing, versturen, nieuwe, oog, ontstoken, nogmaals, huisadres, zalf, terugbellen]
# 39825  [thuistesten, verwijzing, versturen, nieuwe, oog, ontstoken, nogmaals, huisadres, zalf, terugbellen]
# 40318  [thuistesten, verwijzing, versturen, nieuwe, oog, ontstoken, nogmaals, huisadres, zalf, terugbellen]
# 40547  [thuistesten, verwijzing, versturen, nieuwe, oog, ontstoken, nogmaals, huisadres, zalf, terugbellen]
# 40711  [thuistesten, verwijzing, versturen, nieuwe, oog, ontstoken, nogmaals, huisadres, zalf, terugbellen]
#
#                                                                                               Representative_Docs  \
# 164    [Ik heb twee thuistesten., Nu was mijn vraag of ik nieuwe thuistesten kan krijgen., Thuistesten wel nog !]
# 322    [Ik heb twee thuistesten., Nu was mijn vraag of ik nieuwe thuistesten kan krijgen., Thuistesten wel nog !]
# 1131   [Ik heb twee thuistesten., Nu was mijn vraag of ik nieuwe thuistesten kan krijgen., Thuistesten wel nog !]
# 1292   [Ik heb twee thuistesten., Nu was mijn vraag of ik nieuwe thuistesten kan krijgen., Thuistesten wel nog !]
# 1454   [Ik heb twee thuistesten., Nu was mijn vraag of ik nieuwe thuistesten kan krijgen., Thuistesten wel nog !]
# ...                                                                                                           ...
# 39767  [Ik heb twee thuistesten., Nu was mijn vraag of ik nieuwe thuistesten kan krijgen., Thuistesten wel nog !]
# 39825  [Ik heb twee thuistesten., Nu was mijn vraag of ik nieuwe thuistesten kan krijgen., Thuistesten wel nog !]
# 40318  [Ik heb twee thuistesten., Nu was mijn vraag of ik nieuwe thuistesten kan krijgen., Thuistesten wel nog !]
# 40547  [Ik heb twee thuistesten., Nu was mijn vraag of ik nieuwe thuistesten kan krijgen., Thuistesten wel nog !]
# 40711  [Ik heb twee thuistesten., Nu was mijn vraag of ik nieuwe thuistesten kan krijgen., Thuistesten wel nog !]
#
#                                                                                                        Top_n_words  \
# 164    thuistesten - verwijzing - versturen - nieuwe - oog - ontstoken - nogmaals - huisadres - zalf - terugbellen
# 322    thuistesten - verwijzing - versturen - nieuwe - oog - ontstoken - nogmaals - huisadres - zalf - terugbellen
# 1131   thuistesten - verwijzing - versturen - nieuwe - oog - ontstoken - nogmaals - huisadres - zalf - terugbellen
# 1292   thuistesten - verwijzing - versturen - nieuwe - oog - ontstoken - nogmaals - huisadres - zalf - terugbellen
# 1454   thuistesten - verwijzing - versturen - nieuwe - oog - ontstoken - nogmaals - huisadres - zalf - terugbellen
# ...                                                                                                            ...
# 39767  thuistesten - verwijzing - versturen - nieuwe - oog - ontstoken - nogmaals - huisadres - zalf - terugbellen
# 39825  thuistesten - verwijzing - versturen - nieuwe - oog - ontstoken - nogmaals - huisadres - zalf - terugbellen
# 40318  thuistesten - verwijzing - versturen - nieuwe - oog - ontstoken - nogmaals - huisadres - zalf - terugbellen
# 40547  thuistesten - verwijzing - versturen - nieuwe - oog - ontstoken - nogmaals - huisadres - zalf - terugbellen
# 40711  thuistesten - verwijzing - versturen - nieuwe - oog - ontstoken - nogmaals - huisadres - zalf - terugbellen
#
#        Representative_document
# 164                      False
# 322                      False
# 1131                     False
# 1292                     False
# 1454                     False
# ...                        ...
# 39767                    False
# 39825                    False
# 40318                    False
# 40547                    False
# 40711                    False
#
# [127 rows x 7 columns]

# %%
# settings for plotly
import plotly.io as pio
pio.renderers.default = "notebook"
pio.renderers.default = "browser" # option to open the plots in brower

# visualize the hierarchy and manually merge some topics
hierarchical_topics = topic_model.hierarchical_topics(sentences)
#topic_model.visualize_hierarchy(hierarchical_topics=hierarchical_topics)
# Out:
# 100%|██████████| 208/208 [00:01<00:00, 133.79it/s]

# %%
topics_to_merge_manually = [[190, 25],#food, appetite
[65, 3],# GI symptoms
[108, 54], #sleep
[171, 7, 89, 83, 57, 115, 60, 5, 93], #medicine/medication use
[92, 90, 2], #pharmacy and prescription
[193, 107, 173, 70], # telephone contact
[180, 87, 151], # vitamins and minerals
[197, 59], #inquire of test results
[80, 72], # advice
[113, 156, 18], # coronavirus & vaccine
[124, 142], #fever
[11, 130], # quetion/questionaire
[42, 94, 14, 183], #calprotectin home-test
[189, 20, 149, 162, 55, 102, 167, 208, 154, 53, 109, 187, 98, 78, 52, 101, 23, 22, 179] # sign-offs and greetings
]
topic_model.merge_topics(sentences, topics_to_merge_manually)

# %%
topic_info = topic_model.get_topic_info()
topic_info[topic_info["Name"].str.contains("thuistes")]
# Out:
#     Topic  Count                                        Name  \
# 87     86    127  86_thuistesten_verwijzing_versturen_nieuwe
#
#                                        Representation  \
# 87  [thuistesten, verwijzing, versturen, nieuwe, n...
#
#                                   Representative_Docs
# 87  [Ik heb de thuistesten ontvangen., Thuistesten...

# %%
topic_names = topic_model.get_topic_info()["Name"].to_list()
topic_names
# Out:
# ['-1_verstandigst_trant_aangenaam_zenuwachtig',
#  '0_bloed_prikken_ontlasting_slijm',
#  '1_dank_bedankt_reactie_snelle',
#  '2_medicatie_gebruik_tabletten_daags',
#  '3_huisarts_arts_dokter_mdl',
#  '4_recept_apotheek_nieuw_sturen',
#  '5_pijn_buikpijn_buik_pijnlijk',
#  '6_thuis_cal_quanton_vorige',
#  '7_hoor_graag_horen_alvast',
#  '8_merk_last_tijd_laatste',
#  '9_vraag_vragen_vraagje_vragenlijst',
#  '10_voel_gevoel_voelt_voelen',
#  '11_corona_vaccin_vaccinatie_positief',
#  '12_contact_telefonisch_opnemen_consult',
#  '13_gepland_staan_poli_afspraak',
#  '14_wacht_hoop_wachten_hopelijk',
#  '15_telefoon_bereikbaar_nummer_oproep',
#  '16_klachten_kleine_vermoeidheid_dun',
#  '17_goed_gaat_ging_algemeen',
#  '18_test_gedaan_zelftest_testen',
#  '19_eten_eet_eetlust_drinken',
#  '20_sessie_uitnodiging_afspraak_nieuwe',
#  '21_advies_adviseren_overleggen_overleg',
#  '22_nacht_wakker_slaap_vannacht',
#  '23_toilet_diarree_vaker_aandrang',
#  '24_infuus_komende_echo_vanmiddag',
#  '25_weten_laat_laten_duidelijkheid',
#  '26_afspraak_verzetten_nodig_fysieke',
#  '27_crohn_ziekte_verklaring_ulcerosa',
#  '28_beter_gebeurd_gaat_stuk',
#  '29_brief_bericht_mail_ontvangen',
#  '30_maanden_maand_maandelijks_vragenlijst',
#  '31_ijzer_vitamine_ijzerinfuus_foliumzuur',
#  '32_mogelijk_mogelijkheid_manier_snel',
#  '33_stoppen_rekening_cortiment_doorgaan',
#  '34_keer_maal_diaree_frequentie',
#  '35_uitslag_uitslagen_toevallig_ontlastingstest',
#  '36_bekend_uitslagen_uitslag_ontlastingsonderzoek',
#  '37_papieren_toesturen_formulieren_formulier',
#  '38_middag_zetten_aanstaande_morgen',
#  '39_geregeld_opsturen_gekeken_doorgeven',
#  '40_humira_hyrimoz_gespoten_starten',
#  '41_morgen_morgenvroeg_vanmorgen_ophalen',
#  '42_werk_bereikbaar_liefst_minuten',
#  '43_ochtend_hele_dagelijks_ene',
#  '44_jaar_vorig_jaren_leeftijd',
#  '45_potje_formulier_formulieren_potjes',
#  '46_weet_ermee_goed_houdt',
#  '47_controle_ziekenhuis_check_periodieke',
#  '48_vandaag_belafspraak_gebeld_achteraan',
#  '49_vernomen_gebeld_helaas_extra',
#  '50_scopie_infusie_poliafspraak_poli',
#  '51_volgende_mailen_hoeft_spuiten',
#  '52_dermatoloog_huid_dermatologie_gezicht',
#  '53_mee_hieraan_vreemd_valt',
#  '54_antibiotica_kuur_antibioticakuur_bacterie',
#  '55_gelukkig_blij_gelukt_tevreden',
#  '56_prima_helemaal_allemaal_genoteerd',
#  '57_onderzoek_akkoord_melden_meedoen',
#  '58_vakantie_vertrek_reizen_terug',
#  '59_ibd_ibdcoach_sessie_abuis',
#  '60_idee_denk_meld_klopt',
#  '61_duurt_ruim_natuurlijk_lang',
#  '62_koorts_temperatuur_verhoging_koude',
#  '63_telefonische_eind_opstaan_verzet',
#  '64_gaan_besproken_betekenen_houd',
#  '65_proberen_geprobeerd_lukt_probeer',
#  '66_mri_scan_dunne_darm',
#  '67_info_informatie_ter_bedankt',
#  '68_zorgen_begin_ongerust_echt',
#  '69_zwangerschap_zwanger_gynaecoloog_medicijngebruik',
#  '70_bellen_geprobeerd_poli_terug',
#  '71_fijne_feestdagen_jaarwisseling_gewenst',
#  '72_plannen_inplannen_termijn_korte',
#  '73_doorgeven_geven_volledig_oplossing',
#  '74_calprotectine_bekend_uitslag_waarde',
#  '75_keuze_opvlamming_bang_gal',
#  '76_vertellen_hoogte_informeren_weten',
#  '77_gegaan_mis_verkeerd_fout',
#  '78_zorginstelling_apotheek_ziekenhuis_naam',
#  '79_spiegel_dalspiegel_ustekinumab_bekend',
#  '80_ontvangen_heden_moviprep_folder',
#  '81_normaal_normale_zacht_dunner',
#  '82_coloscopie_endoscopie_darmonderzoek_verhuisd',
#  '83_zie_vlak_zien_verkeerde',
#  '84_sorry_excuses_late_lastig',
#  '85_operatie_chirurg_chirurgie_kringspier',
#  '86_thuistesten_verwijzing_versturen_nieuwe',
#  '87_dosering_combinatie_dosis_laag',
#  '88_waarde_waardes_hoog_bepalen',
#  '89_mail_mailadres_gestuurd_vele',
#  '90_resultaten_hiervan_resultaat_vernemen',
#  '91_bedoeling_teveel_doorgegeven_vergoed',
#  '92_wilde_reden_dringend_denkt',
#  '93_veranderd_infusen_helft_interval',
#  '94_app_downloaden_telefoon_ondersteund',
#  '95_gemeten_waarde_verschil_calprotectine',
#  '96_voorraad_doosje_doos_stuks',
#  '97_bespreken_spreken_persoonlijk_praten',
#  '98_soms_amper_borrelt_alsof',
#  '99_beste_hey_onafhankelijkheid_picoprepp',
#  '100_spuit_doorsturen_metamucil_injecties',
#  '101_next_vorige_ziekenhuis_verpleegkundigen',
#  '102_gewicht_kilo_afgevallen_weeg',
#  '103_lactose_gestopt_beangstigend_vergissing',
#  '104_zsm_jazeker_okay_verzorgen',
#  '105_dacht_twijfel_smeer_sporten',
#  '106_foto_bijgevoegd_bestand_bijgaand',
#  '107_nachten_duidelijk_kort_bestaat',
#  '108_probleem_toekomst_echt_problemen',
#  '109_stress_invloed_druk_rol',
#  '110_zekerheid_navragen_vragenlijsten_moeizaam',
#  '111_pillen_systeem_azathiopirine_heen',
#  '112_gehoord_gehoor_heden_kapper',
#  '113_chirurg_ingepland_gevolgen_vedoluzimab',
#  '114_ontsteking_galstenen_idd_aanvallen',
#  '115_weet_lab_letten_sport',
#  '116_gestart_entyvio_verhuizen_gevaccineerd',
#  '117_vergeten_herinnering_herinneren_geheugen',
#  '118_vandaar_gevraagd_griep_stuur',
#  '119_maagonderzoek_kloppen_vervolgafspraak_begrepen',
#  '120_ophalen_gang_fistel_bezig',
#  '121_druppels_has_are_kale',
#  '122_rechts_linker_inspanning_steken',
#  '123_voldoende_hopende_hiermee_hoop',
#  '124_hiervoor_situatie_ten_eraan',
#  '125_gaten_houden_hou_gehouden',
#  '126_helpen_kastje_muur_hiermee',
#  '127_optie_alternatief_momenten_mogelijkheden',
#  '128_vermelden_originele_hoor_biologische',
#  '129_aanhouden_verstandig_rest_vervolg',
#  '130_regelmatig_gegeten_lucht_pak',
#  '131_heftige_vlagen_uitleggen_jeuk',
#  '132_bekeken_lukken_betekend_geeft',
#  '133_biologicals_biological_bureau_weekse',
#  '134_adres_oude_gewijzigd_email',
#  '135_risico_risicogroep_val_loop',
#  '136_urine_kweek_gecontroleerd_urinekweek',
#  '137_fax_faxnummer_vriendelijk_tel',
#  '138_verneem_hoor_smaak_etoricoxib',
#  '139_meewerken_annuleren_uitsluitsel_tijdstip',
#  '140_energie_energielevel_moe_stukken',
#  '141_toestemming_toestemmingsformulier_geef_bijlage',
#  '142_wekelijks_nou_volgen_geplande',
#  '143_verzekering_aanvraag_gegevens_overlijdensrisicoverzekering',
#  '144_duren_verbetering_langs_harde',
#  '145_werkt_aangeef_traject_darmkrampen',
#  '146_wensen_allereerst_gezond_wens',
#  '147_bijwerking_bijwerkingen_infliximab_innemen',
#  '148_eerstvolgende_aanstaande_groot_maandagmiddag',
#  '149_problemen_lange_hierdoor_persen',
#  '150_fysiek_opeens_heden_straks',
#  '151_team_ibd_matig_idb',
#  '152_gezondheidscheck_periodieke_vullen_invullen',
#  '153_gelezen_laboratorium_buikgriep_afgesproken',
#  '154_tandarts_tandvlees_kaakchirurg_mond',
#  '155_betekent_vervolgstappen_stappen_the',
#  '156_aangepast_baat_beclometason_tabletjes',
#  '157_tegemoet_zie_reactie_hieronder',
#  '158_terugkoppeling_terugkoppelen_bedankt_dank',
#  '159_doorgestuurd_picoprep_gestuurd_zorginstelling',
#  '160_eerlijk_hoor_geboorte_gezegd',
#  '161_geboortedatum_geboorte_geb_geboren',
#  '162_nieuws_goed_goede_geloven',
#  '163_ggd_hoor_tel_graag']

# %%
# visualize the hierarchy and manually merge some topics
hierarchical_topics = topic_model.hierarchical_topics(sentences)
#topic_model.visualize_hierarchy(hierarchical_topics=hierarchical_topics)
# Out:
# 100%|██████████| 163/163 [00:01<00:00, 139.06it/s]

# %%
doc_info = topic_model.get_document_info(sentences)
pd.set_option("display.max_colwidth", None)
doc_info[doc_info["Topic"] == 45]
# Out:
#                                                                                                                                                Document  \
# 456                                                              Ik heb dus morgen een buisje bij me met ontlasting alleen heb ik geen formulier erbij.
# 566                                                                                        Ik zal bij de eerst volgende keer potje ontlasting meenemen.
# 629                                                                                         Ik heb pas een ontlastingformulier ontvangen met een potje.
# 662                                                                                                  ik ben weer aan mijn laatste potje purinethol toe.
# 733                                                                                                    Laboratoriumformulieren heb ik niet, potje wel..
# ...                                                                                                                                                 ...
# 40350                                                                                             Ook heb ik een formulier gekregen voor de ontlasting.
# 40440                                                                                              Nee heb geen potje meer, zou u deze kunnen opsturen.
# 40615                                                                                                         Ik heb geen lab formulieren/buisjes meer.
# 40623                                                                                                 Ik heb het formulier en potje nog niet ontvangen.
# 40954  Vandaag heb ik mijn prikformulieren gesorteerd, daarbij zag ik dat ik geen prik formulieren meer heb voor de MDL, zou je deze toe kunnen zenden?
#
#        Topic                                   Name  \
# 456       45  45_potje_formulier_formulieren_potjes
# 566       45  45_potje_formulier_formulieren_potjes
# 629       45  45_potje_formulier_formulieren_potjes
# 662       45  45_potje_formulier_formulieren_potjes
# 733       45  45_potje_formulier_formulieren_potjes
# ...      ...                                    ...
# 40350     45  45_potje_formulier_formulieren_potjes
# 40440     45  45_potje_formulier_formulieren_potjes
# 40615     45  45_potje_formulier_formulieren_potjes
# 40623     45  45_potje_formulier_formulieren_potjes
# 40954     45  45_potje_formulier_formulieren_potjes
#
#                                                                                                   Representation  \
# 456    [potje, formulier, formulieren, potjes, lab, buisje, ontvangen, bezit, prikformulieren, informatiefolder]
# 566    [potje, formulier, formulieren, potjes, lab, buisje, ontvangen, bezit, prikformulieren, informatiefolder]
# 629    [potje, formulier, formulieren, potjes, lab, buisje, ontvangen, bezit, prikformulieren, informatiefolder]
# 662    [potje, formulier, formulieren, potjes, lab, buisje, ontvangen, bezit, prikformulieren, informatiefolder]
# 733    [potje, formulier, formulieren, potjes, lab, buisje, ontvangen, bezit, prikformulieren, informatiefolder]
# ...                                                                                                          ...
# 40350  [potje, formulier, formulieren, potjes, lab, buisje, ontvangen, bezit, prikformulieren, informatiefolder]
# 40440  [potje, formulier, formulieren, potjes, lab, buisje, ontvangen, bezit, prikformulieren, informatiefolder]
# 40615  [potje, formulier, formulieren, potjes, lab, buisje, ontvangen, bezit, prikformulieren, informatiefolder]
# 40623  [potje, formulier, formulieren, potjes, lab, buisje, ontvangen, bezit, prikformulieren, informatiefolder]
# 40954  [potje, formulier, formulieren, potjes, lab, buisje, ontvangen, bezit, prikformulieren, informatiefolder]
#
#                                                                                                Representative_Docs  \
# 456    [Ik heb nog een formulier en potje., Formulier en potje heb ik., Ja ik heb nog een potje en een formulier.]
# 566    [Ik heb nog een formulier en potje., Formulier en potje heb ik., Ja ik heb nog een potje en een formulier.]
# 629    [Ik heb nog een formulier en potje., Formulier en potje heb ik., Ja ik heb nog een potje en een formulier.]
# 662    [Ik heb nog een formulier en potje., Formulier en potje heb ik., Ja ik heb nog een potje en een formulier.]
# 733    [Ik heb nog een formulier en potje., Formulier en potje heb ik., Ja ik heb nog een potje en een formulier.]
# ...                                                                                                            ...
# 40350  [Ik heb nog een formulier en potje., Formulier en potje heb ik., Ja ik heb nog een potje en een formulier.]
# 40440  [Ik heb nog een formulier en potje., Formulier en potje heb ik., Ja ik heb nog een potje en een formulier.]
# 40615  [Ik heb nog een formulier en potje., Formulier en potje heb ik., Ja ik heb nog een potje en een formulier.]
# 40623  [Ik heb nog een formulier en potje., Formulier en potje heb ik., Ja ik heb nog een potje en een formulier.]
# 40954  [Ik heb nog een formulier en potje., Formulier en potje heb ik., Ja ik heb nog een potje en een formulier.]
#
#                                                                                                             Top_n_words  \
# 456    potje - formulier - formulieren - potjes - lab - buisje - ontvangen - bezit - prikformulieren - informatiefolder
# 566    potje - formulier - formulieren - potjes - lab - buisje - ontvangen - bezit - prikformulieren - informatiefolder
# 629    potje - formulier - formulieren - potjes - lab - buisje - ontvangen - bezit - prikformulieren - informatiefolder
# 662    potje - formulier - formulieren - potjes - lab - buisje - ontvangen - bezit - prikformulieren - informatiefolder
# 733    potje - formulier - formulieren - potjes - lab - buisje - ontvangen - bezit - prikformulieren - informatiefolder
# ...                                                                                                                 ...
# 40350  potje - formulier - formulieren - potjes - lab - buisje - ontvangen - bezit - prikformulieren - informatiefolder
# 40440  potje - formulier - formulieren - potjes - lab - buisje - ontvangen - bezit - prikformulieren - informatiefolder
# 40615  potje - formulier - formulieren - potjes - lab - buisje - ontvangen - bezit - prikformulieren - informatiefolder
# 40623  potje - formulier - formulieren - potjes - lab - buisje - ontvangen - bezit - prikformulieren - informatiefolder
# 40954  potje - formulier - formulieren - potjes - lab - buisje - ontvangen - bezit - prikformulieren - informatiefolder
#
#        Representative_document
# 456                      False
# 566                      False
# 629                      False
# 662                      False
# 733                      False
# ...                        ...
# 40350                    False
# 40440                    False
# 40615                    False
# 40623                    False
# 40954                    False
#
# [241 rows x 7 columns]

# %%
topics_to_merge_manually_2 = [[5, 131], # GI symptoms
[16, 8], # general symptoms
[34, 23], # diarrhea
[101, 3], # hospital/doctor visit
[20, 26, 13, 50], # appointment/session
[88, 95, 74], # calprotectin value
[18, 6], # home test
[45, 37], # stool sampling forms and papers
[29, 89, 134], # mail and address
[162, 67, 1], # sign-offs
[56, 104], # non-actionable 
]
topic_model.merge_topics(sentences, topics_to_merge_manually_2)

# %%
topic_info = topic_model.get_topic_info()
topic_info[topic_info["Name"].str.contains("thuis")]
# Out:
#     Topic  Count                                        Name  \
# 7       6   1239                 6_test_thuis_gedaan_quanton
# 78     77    127  77_thuistesten_verwijzing_versturen_nieuwe
#
#                                                                                      Representation  \
# 7                    [test, thuis, gedaan, quanton, cal, testen, thuistest, huis, vorige, zelftest]
# 78  [thuistesten, verwijzing, versturen, nieuwe, nogmaals, oog, ontstoken, huisadres, sturen, zalf]
#
#                                                                                                 Representative_Docs
# 7   [De test was echter nog niet over de datum., Moet ik deze test nu doen ?, Ik heb inderdaad nog een test thuis.]
# 78       [Thuistesten wel nog !, Ik heb twee thuistesten., Nu was mijn vraag of ik nieuwe thuistesten kan krijgen.]

# %%
# visualize the hierarchy and manually merge some topics
hierarchical_topics = topic_model.hierarchical_topics(sentences)
#topic_model.visualize_hierarchy(hierarchical_topics=hierarchical_topics)
# Out:
# 100%|██████████| 147/147 [00:00<00:00, 152.00it/s]

# %%
topic_names = topic_model.get_topic_info()["Name"].to_list()
topic_names
# Out:
# ['-1_verstandigst_trant_aangenaam_zenuwachtig',
#  '0_bloed_prikken_ontlasting_slijm',
#  '1_bedankt_dank_reactie_snelle',
#  '2_medicatie_gebruik_tabletten_medicijnen',
#  '3_huisarts_arts_dokter_mdl',
#  '4_afspraak_gepland_sessie_poli',
#  '5_recept_apotheek_nieuw_sturen',
#  '6_test_thuis_gedaan_quanton',
#  '7_pijn_buikpijn_buik_pijnlijk',
#  '8_klachten_merk_last_tijd',
#  '9_hoor_graag_horen_alvast',
#  '10_toilet_keer_diarree_vaker',
#  '11_vraag_vragen_vraagje_vragenlijst',
#  '12_voel_gevoel_voelt_voelen',
#  '13_corona_vaccinatie_vaccin_positief',
#  '14_contact_telefonisch_opnemen_consult',
#  '15_formulieren_formulier_potje_papieren',
#  '16_mail_brief_adres_bericht',
#  '17_wacht_hoop_wachten_hopelijk',
#  '18_telefoon_bereikbaar_nummer_oproep',
#  '19_goed_gaat_ging_algemeen',
#  '20_calprotectine_waarde_waardes_bekend',
#  '21_eten_eet_eetlust_drinken',
#  '22_advies_adviseren_overleggen_graag',
#  '23_nacht_wakker_slaap_vannacht',
#  '24_infuus_komende_echo_vanmiddag',
#  '25_weten_laat_laten_duidelijkheid',
#  '26_crohn_ziekte_verklaring_humira',
#  '27_prima_helemaal_allemaal_zsm',
#  '28_beter_gebeurd_gaat_stuk',
#  '29_maanden_maand_maandelijks_vragenlijst',
#  '30_ijzer_vitamine_ijzerinfuus_foliumzuur',
#  '31_mogelijk_mogelijkheid_manier_snel',
#  '32_stoppen_rekening_cortiment_doorgaan',
#  '33_uitslag_uitslagen_toevallig_ontlastingstest',
#  '34_bekend_uitslagen_uitslag_ontlastingsonderzoek',
#  '35_middag_zetten_aanstaande_morgen',
#  '36_geregeld_opsturen_gekeken_doorgeven',
#  '37_humira_hyrimoz_gespoten_starten',
#  '38_morgen_vanmorgen_morgenvroeg_ophalen',
#  '39_werk_bereikbaar_liefst_minuten',
#  '40_ochtend_hele_dagelijks_ene',
#  '41_jaar_vorig_jaren_leeftijd',
#  '42_weet_ermee_goed_houdt',
#  '43_controle_ziekenhuis_check_periodieke',
#  '44_vandaag_belafspraak_gebeld_achteraan',
#  '45_vernomen_gebeld_helaas_extra',
#  '46_volgende_mailen_hoeft_spuiten',
#  '47_dermatoloog_huid_dermatologie_gezicht',
#  '48_mee_hieraan_vreemd_valt',
#  '49_antibiotica_kuur_antibioticakuur_bacterie',
#  '50_gelukkig_blij_gelukt_tevreden',
#  '51_onderzoek_akkoord_melden_meedoen',
#  '52_vakantie_vertrek_terug_reizen',
#  '53_ibd_ibdcoach_sessie_abuis',
#  '54_duurt_ruim_natuurlijk_lang',
#  '55_idee_denk_meld_klopt',
#  '56_koorts_temperatuur_verhoging_koude',
#  '57_telefonische_eind_opstaan_verzet',
#  '58_gaan_besproken_betekenen_houd',
#  '59_proberen_geprobeerd_lukt_probeer',
#  '60_mri_scan_dunne_uitslag',
#  '61_zorgen_begin_ongerust_echt',
#  '62_zwangerschap_zwanger_gynaecoloog_medicijngebruik',
#  '63_bellen_geprobeerd_poli_terug',
#  '64_fijne_feestdagen_jaarwisseling_gewenst',
#  '65_plannen_inplannen_termijn_korte',
#  '66_doorgeven_geven_volledig_oplossing',
#  '67_keuze_opvlamming_bang_gal',
#  '68_vertellen_hoogte_informeren_weten',
#  '69_gegaan_mis_verkeerd_fout',
#  '70_spiegel_dalspiegel_ustekinumab_bekend',
#  '71_zorginstelling_apotheek_ziekenhuis_naam',
#  '72_ontvangen_heden_moviprep_bevestiging',
#  '73_normaal_normale_zacht_dunner',
#  '74_coloscopie_endoscopie_darmonderzoek_verhuisd',
#  '75_sorry_excuses_late_lastig',
#  '76_zie_vlak_zien_verkeerde',
#  '77_thuistesten_verwijzing_versturen_nieuwe',
#  '78_operatie_chirurg_chirurgie_kringspier',
#  '79_dosering_combinatie_dosis_laag',
#  '80_resultaten_hiervan_resultaat_vernemen',
#  '81_bedoeling_teveel_doorgegeven_vergoed',
#  '82_wilde_reden_dringend_denkt',
#  '83_veranderd_infusen_helft_interval',
#  '84_app_downloaden_telefoon_ondersteund',
#  '85_voorraad_doosje_doos_stuks',
#  '86_soms_amper_borrelt_alsof',
#  '87_bespreken_spreken_persoonlijk_praten',
#  '88_beste_hey_betreft_aandoen',
#  '89_spuit_doorsturen_metamucil_injecties',
#  '90_gewicht_kilo_afgevallen_weeg',
#  '91_lactose_gestopt_beangstigend_vergissing',
#  '92_dacht_twijfel_smeer_sporten',
#  '93_foto_bijgevoegd_bestand_bijgaand',
#  '94_nachten_duidelijk_kort_bestaat',
#  '95_probleem_toekomst_echt_problemen',
#  '96_pillen_systeem_azathiopirine_heen',
#  '97_zekerheid_navragen_vragenlijsten_checken',
#  '98_gehoord_gehoor_heden_kapper',
#  '99_stress_invloed_druk_rol',
#  '100_chirurg_ingepland_gevolgen_vedoluzimab',
#  '101_ontsteking_galstenen_idd_aanvallen',
#  '102_weet_lab_letten_sport',
#  '103_vergeten_herinnering_herinneren_geheugen',
#  '104_gestart_entyvio_verhuizen_gevaccineerd',
#  '105_vandaar_gevraagd_griep_stuur',
#  '106_ophalen_gang_fistel_bezig',
#  '107_maagonderzoek_kloppen_vervolgafspraak_begrepen',
#  '108_druppels_has_kale_are',
#  '109_rechts_linker_inspanning_steken',
#  '110_hiervoor_situatie_ten_eraan',
#  '111_voldoende_hopende_hiermee_hoop',
#  '112_gaten_houden_hou_gehouden',
#  '113_helpen_kastje_hiermee_muur',
#  '114_optie_alternatief_momenten_mogelijkheden',
#  '115_aanhouden_verstandig_rest_vervolg',
#  '116_vermelden_originele_hoor_biologische',
#  '117_regelmatig_gegeten_lucht_pak',
#  '118_biologicals_biological_bureau_wratten',
#  '119_bekeken_lukken_betekend_geeft',
#  '120_risico_risicogroep_val_loop',
#  '121_urine_kweek_gecontroleerd_urinekweek',
#  '122_fax_faxnummer_vriendelijk_tel',
#  '123_verneem_hoor_smaak_etoricoxib',
#  '124_annuleren_meewerken_uitsluitsel_tijdstip',
#  '125_energie_energielevel_moe_stukken',
#  '126_toestemming_toestemmingsformulier_geef_bijlage',
#  '127_wekelijks_nou_volgen_geplande',
#  '128_verzekering_aanvraag_gegevens_overlijdensrisicoverzekering',
#  '129_duren_verbetering_langs_harde',
#  '130_werkt_aangeef_traject_darmkrampen',
#  '131_wensen_allereerst_gezond_wens',
#  '132_bijwerking_bijwerkingen_infliximab_innemen',
#  '133_eerstvolgende_aanstaande_groot_maandagmiddag',
#  '134_problemen_lange_hierdoor_persen',
#  '135_fysiek_opeens_heden_straks',
#  '136_team_ibd_matig_idb',
#  '137_gezondheidscheck_periodieke_vullen_invullen',
#  '138_gelezen_laboratorium_afgesproken_buikgriep',
#  '139_tandarts_tandvlees_kaakchirurg_mond',
#  '140_betekent_vervolgstappen_stappen_the',
#  '141_aangepast_baat_beclometason_tabletjes',
#  '142_tegemoet_zie_reactie_hieronder',
#  '143_terugkoppeling_terugkoppelen_bedankt_dank',
#  '144_doorgestuurd_picoprep_gestuurd_zorginstelling',
#  '145_eerlijk_hoor_gezegd_geboorte',
#  '146_geboortedatum_geboorte_geb_geboren',
#  '147_ggd_hoor_tel_graag']

# %%
doc_info = topic_model.get_document_info(sentences)
pd.set_option("display.max_colwidth", 200)
doc_info[doc_info["Topic"] == 57]
# Out:
#                                                                                                                          Document  \
# 458                                                                                                       Half 10 heb ik de echo.
# 495                                                              en ,  Op 6 april om 22:37 uur ben ik bevallen van onze dochter .
# 1257                                                          Sinds de scopie van 2 november zijn mijn darmklachten verslechterd.
# 1259   Enige pluspuntje is dat ik sinds 7 november 's nachts af en toe scheetjes laat want dat ging vanaf eind oktober niet meer.
# 1267                                                       sinds zaterdag 11 november gebruik ik een verhoogd schema prednisolon.
# ...                                                                                                                           ...
# 40430                                                                      oktober/november 2021 ben ik op controle geweest bij .
# 40528                                         In januari heb ik een afspraak opstaan en daarvoor heb ik een lab briefje gekregen.
# 40554                                                                                      Dus dat zou dan ook eind februari zijn
# 40810                                                                                      De laatste medicatie is entocort  3mg.
# 40861                                                   De eerste week van november zou nog een controle afspraak gemaakt worden.
#
#        Topic                                 Name  \
# 458       57  57_telefonische_eind_opstaan_verzet
# 495       57  57_telefonische_eind_opstaan_verzet
# 1257      57  57_telefonische_eind_opstaan_verzet
# 1259      57  57_telefonische_eind_opstaan_verzet
# 1267      57  57_telefonische_eind_opstaan_verzet
# ...      ...                                  ...
# 40430     57  57_telefonische_eind_opstaan_verzet
# 40528     57  57_telefonische_eind_opstaan_verzet
# 40554     57  57_telefonische_eind_opstaan_verzet
# 40810     57  57_telefonische_eind_opstaan_verzet
# 40861     57  57_telefonische_eind_opstaan_verzet
#
#                                                                                 Representation  \
# 458    [telefonische, eind, opstaan, verzet, entocort, half, bevallen, afspraak, dochter, kom]
# 495    [telefonische, eind, opstaan, verzet, entocort, half, bevallen, afspraak, dochter, kom]
# 1257   [telefonische, eind, opstaan, verzet, entocort, half, bevallen, afspraak, dochter, kom]
# 1259   [telefonische, eind, opstaan, verzet, entocort, half, bevallen, afspraak, dochter, kom]
# 1267   [telefonische, eind, opstaan, verzet, entocort, half, bevallen, afspraak, dochter, kom]
# ...                                                                                        ...
# 40430  [telefonische, eind, opstaan, verzet, entocort, half, bevallen, afspraak, dochter, kom]
# 40528  [telefonische, eind, opstaan, verzet, entocort, half, bevallen, afspraak, dochter, kom]
# 40554  [telefonische, eind, opstaan, verzet, entocort, half, bevallen, afspraak, dochter, kom]
# 40810  [telefonische, eind, opstaan, verzet, entocort, half, bevallen, afspraak, dochter, kom]
# 40861  [telefonische, eind, opstaan, verzet, entocort, half, bevallen, afspraak, dochter, kom]
#
#                                                                                                                                                                     Representative_Docs  \
# 458    [Moet ik zelf een telefonische afspraak maken?, Afgelopen maandag had ik een telefonische afspraak met ., Afgelopen maandag 20-12 zou ik een telefonische afspraak hebben met .]
# 495    [Moet ik zelf een telefonische afspraak maken?, Afgelopen maandag had ik een telefonische afspraak met ., Afgelopen maandag 20-12 zou ik een telefonische afspraak hebben met .]
# 1257   [Moet ik zelf een telefonische afspraak maken?, Afgelopen maandag had ik een telefonische afspraak met ., Afgelopen maandag 20-12 zou ik een telefonische afspraak hebben met .]
# 1259   [Moet ik zelf een telefonische afspraak maken?, Afgelopen maandag had ik een telefonische afspraak met ., Afgelopen maandag 20-12 zou ik een telefonische afspraak hebben met .]
# 1267   [Moet ik zelf een telefonische afspraak maken?, Afgelopen maandag had ik een telefonische afspraak met ., Afgelopen maandag 20-12 zou ik een telefonische afspraak hebben met .]
# ...                                                                                                                                                                                 ...
# 40430  [Moet ik zelf een telefonische afspraak maken?, Afgelopen maandag had ik een telefonische afspraak met ., Afgelopen maandag 20-12 zou ik een telefonische afspraak hebben met .]
# 40528  [Moet ik zelf een telefonische afspraak maken?, Afgelopen maandag had ik een telefonische afspraak met ., Afgelopen maandag 20-12 zou ik een telefonische afspraak hebben met .]
# 40554  [Moet ik zelf een telefonische afspraak maken?, Afgelopen maandag had ik een telefonische afspraak met ., Afgelopen maandag 20-12 zou ik een telefonische afspraak hebben met .]
# 40810  [Moet ik zelf een telefonische afspraak maken?, Afgelopen maandag had ik een telefonische afspraak met ., Afgelopen maandag 20-12 zou ik een telefonische afspraak hebben met .]
# 40861  [Moet ik zelf een telefonische afspraak maken?, Afgelopen maandag had ik een telefonische afspraak met ., Afgelopen maandag 20-12 zou ik een telefonische afspraak hebben met .]
#
#                                                                                           Top_n_words  \
# 458    telefonische - eind - opstaan - verzet - entocort - half - bevallen - afspraak - dochter - kom
# 495    telefonische - eind - opstaan - verzet - entocort - half - bevallen - afspraak - dochter - kom
# 1257   telefonische - eind - opstaan - verzet - entocort - half - bevallen - afspraak - dochter - kom
# 1259   telefonische - eind - opstaan - verzet - entocort - half - bevallen - afspraak - dochter - kom
# 1267   telefonische - eind - opstaan - verzet - entocort - half - bevallen - afspraak - dochter - kom
# ...                                                                                               ...
# 40430  telefonische - eind - opstaan - verzet - entocort - half - bevallen - afspraak - dochter - kom
# 40528  telefonische - eind - opstaan - verzet - entocort - half - bevallen - afspraak - dochter - kom
# 40554  telefonische - eind - opstaan - verzet - entocort - half - bevallen - afspraak - dochter - kom
# 40810  telefonische - eind - opstaan - verzet - entocort - half - bevallen - afspraak - dochter - kom
# 40861  telefonische - eind - opstaan - verzet - entocort - half - bevallen - afspraak - dochter - kom
#
#        Representative_document
# 458                      False
# 495                      False
# 1257                     False
# 1259                     False
# 1267                     False
# ...                        ...
# 40430                    False
# 40528                    False
# 40554                    False
# 40810                    False
# 40861                    False
#
# [186 rows x 7 columns]

# %%
# large merge
topics_to_merge_manually_3 = [[145, 147, 9, 123], # hoor graag
[25, 68], # want to know
[33, 34], # results inquiry
[102, 42], # weet
[92, 55], # thought process
[143, 1],
[78, 100], # operation
[18, 63, 59, 39, 44, 4, 57] # appointment and contact
]
topic_model.merge_topics(sentences, topics_to_merge_manually_3)

# %%
topic_model.get_topic_info()[:10]
# Out:
#    Topic  Count                                         Name  \
# 0     -1    259  -1_verstandigst_trant_aangenaam_zenuwachtig
# 1      0   3567             0_bloed_prikken_ontlasting_laten
# 2      1   3130                1_bedankt_dank_reactie_snelle
# 3      2   2871        2_afspraak_bellen_proberen_bereikbaar
# 4      3   2298     3_medicatie_gebruik_tabletten_medicijnen
# 5      4   1559                   4_huisarts_arts_dokter_mdl
# 6      5   1347               5_recept_apotheek_nieuw_sturen
# 7      6   1239                  6_test_thuis_gedaan_quanton
# 8      7   1088                7_pijn_buikpijn_buik_pijnlijk
# 9      8   1012                    8_klachten_merk_last_tijd
#
#                                                                                                  Representation  \
# 0  [verstandigst, trant, aangenaam, zenuwachtig, onderwerpen, genegeerd, docter, dexamfetamine, glucose, hogen]
# 1      [bloed, prikken, ontlasting, laten, slijm, bloedprikken, ingeleverd, bloeduitslagen, geprikt, inleveren]
# 2                         [bedankt, dank, reactie, snelle, alvast, bericht, antwoord, dankjewel, fijn, weekend]
# 3                      [afspraak, bellen, proberen, bereikbaar, gepland, poli, vandaag, telefoon, staan, staat]
# 4            [medicatie, gebruik, tabletten, medicijnen, daags, gebruiken, pentasa, tablet, apotheek, medicijn]
# 5          [huisarts, arts, dokter, mdl, ziekenhuis, contact, verpleegkundige, medische, afspraak, behandeling]
# 6                  [recept, apotheek, nieuw, sturen, herhaalrecept, faxen, purinethol, nethol, puri, aanvragen]
# 7                                [test, thuis, gedaan, quanton, cal, testen, vorige, thuistest, huis, zelftest]
# 8                          [pijn, buikpijn, buik, pijnlijk, last, pijnlijke, rug, gevoel, onderbuik, hoofdpijn]
# 9                            [klachten, merk, last, tijd, darmen, laatste, vermoeidheid, kleine, geworden, dun]
#
#                                                                                                                                                                                        Representative_Docs
# 0                                                                                                                        [Of iets in die trant., Wat is voor mij het verstandigst., Of iets in die trant.]
# 1                                                       [ik nooit meer bloed te laten prikken?, Afgelopen maandag 4 juli heb ik bloed laten prikken via ., Maar moet ik niet ook nog bloed laten prikken?]
# 2                                                                                             [heer ,  Oké, dank u voor de snelle reactie!, Alvast dank voor uw reactie, Fijn bedankt voor snelle reactie]
# 3                                                                   [Ik zal een afspraak maken., De afspraak is inmiddels op een andere dag vastgezet., Ik heb afgelopen vrijdag een afspraak met  gehad.]
# 4  [Graag zou ik andere medicatie willen., ik zou graag een recept voor 3 maanden willen hebben van : Azathioprine 25 mg 1 x daags 1 tablet Azathioprine 50 mg 1 x daags 2 tablet Forlax 10 gram 4 x da...
# 5                                                                               [De huisarts vroeg zich af of dit kan door ., Ik ben afgelopen vrijdag weer bij de huisarts geweest., Ja via de huisarts.]
# 6                        [Kunt u een nieuw recept sturen naar apotheek ?, Kunnen jullie a.u.b. een nieuw recept naar de apotheek sturen., Zou u anders een nieuw recept kunnen sturen naar mijn apotheek?]
# 7                                                                                          [Moet ik deze test nu doen ?, De test was echter nog niet over de datum., Ik heb inderdaad nog een test thuis.]
# 8                                                                                                             [Geen pijn meer in., Maar ik heb af en toe meer pijn., Deze doet niet pijn, het groeit wel.]
# 9                          [ik heb de laatste tijd weer meer last van mijn buik., Ik heb de laatste dagen meer klachten van mijn darmen., Nu merk ik sinds gisteren dat ik meer last heb van mijn darmen.]

# %%
# large merge
topics_to_merge_manually_4 = [[106, 78, 7, 8, 39, 24, 10, 66], # symptoms and complaints
[0, 6], # stool and blood test
[21, 15, 63], # calprotectin home test
[14, 2], #contact and appointment
]
topic_model.merge_topics(sentences, topics_to_merge_manually_4)

# %%
# visualize the hierarchy and manually merge some topics
hierarchical_topics = topic_model.hierarchical_topics(sentences)
#topic_model.visualize_hierarchy(hierarchical_topics=hierarchical_topics)
# Out:
# 100%|██████████| 121/121 [00:00<00:00, 139.01it/s]

# %%
topic_info = topic_model.get_topic_info()

# %%
topic_info = topic_model.get_topic_info()
topic_names = topic_info["Name"].to_list()
topic_names
# Out:
# ['-1_verstandigst_trant_aangenaam_zenuwachtig',
#  '0_bloed_prikken_ontlasting_test',
#  '1_pijn_buikpijn_toilet_last',
#  '2_afspraak_telefonisch_contact_bellen',
#  '3_bedankt_dank_reactie_snelle',
#  '4_medicatie_gebruik_tabletten_medicijnen',
#  '5_huisarts_arts_dokter_mdl',
#  '6_recept_apotheek_nieuw_sturen',
#  '7_bekend_calprotectine_uitslag_waarde',
#  '8_hoor_graag_horen_verneem',
#  '9_vraag_vragen_vraagje_vragenlijst',
#  '10_voel_gevoel_voelt_voelen',
#  '11_corona_vaccinatie_vaccin_positief',
#  '12_formulieren_formulier_potje_papieren',
#  '13_mail_brief_adres_bericht',
#  '14_weten_laat_vertellen_laten',
#  '15_hoop_wacht_wachten_hopelijk',
#  '16_goed_gaat_ging_algemeen',
#  '17_eten_eet_eetlust_drinken',
#  '18_advies_adviseren_overleggen_graag',
#  '19_infuus_komende_echo_vanmiddag',
#  '20_weet_ermee_goed_houdt',
#  '21_crohn_ziekte_verklaring_humira',
#  '22_prima_helemaal_allemaal_zsm',
#  '23_beter_gebeurd_gaat_stuk',
#  '24_ijzer_vitamine_ijzerinfuus_foliumzuur',
#  '25_maanden_maand_vragenlijst_maandelijks',
#  '26_mogelijk_mogelijkheid_manier_snel',
#  '27_stoppen_rekening_cortiment_doorgaan',
#  '28_idee_denk_dacht_meld',
#  '29_middag_zetten_aanstaande_morgen',
#  '30_geregeld_opsturen_gekeken_doorgeven',
#  '31_humira_hyrimoz_gespoten_spuiten',
#  '32_morgen_vanmorgen_morgenvroeg_ophalen',
#  '33_jaar_vorig_jaren_leeftijd',
#  '34_controle_ziekenhuis_check_periodieke',
#  '35_vernomen_gebeld_helaas_extra',
#  '36_dermatoloog_huid_dermatologie_gezicht',
#  '37_volgende_mailen_hoeft_spuiten',
#  '38_mee_hieraan_vreemd_valt',
#  '39_antibiotica_kuur_antibioticakuur_bacterie',
#  '40_operatie_chirurg_ingepland_gevolgen',
#  '41_gelukkig_blij_gelukt_tevreden',
#  '42_vakantie_vertrek_terug_reizen',
#  '43_onderzoek_akkoord_melden_meedoen',
#  '44_ibd_ibdcoach_sessie_vragen',
#  '45_duurt_ruim_natuurlijk_lang',
#  '46_koorts_temperatuur_verhoging_koude',
#  '47_gaan_besproken_betekenen_houd',
#  '48_mri_scan_dunne_uitslag',
#  '49_zorgen_begin_ongerust_echt',
#  '50_zwangerschap_zwanger_gynaecoloog_medicijngebruik',
#  '51_fijne_feestdagen_jaarwisseling_gewenst',
#  '52_plannen_inplannen_termijn_afspraak',
#  '53_doorgeven_geven_volledig_oplossing',
#  '54_keuze_opvlamming_bang_gal',
#  '55_gegaan_mis_verkeerd_fout',
#  '56_ontvangen_heden_moviprep_bevestiging',
#  '57_zorginstelling_apotheek_ziekenhuis_naam',
#  '58_coloscopie_endoscopie_darmonderzoek_verhuisd',
#  '59_sorry_excuses_late_lastig',
#  '60_zie_vlak_zien_verkeerde',
#  '61_thuistesten_verwijzing_nieuwe_versturen',
#  '62_dosering_combinatie_dosis_laag',
#  '63_resultaten_hiervan_resultaat_vernemen',
#  '64_bedoeling_teveel_doorgegeven_vergoed',
#  '65_wilde_reden_dringend_denkt',
#  '66_veranderd_infusen_helft_interval',
#  '67_app_downloaden_telefoon_ondersteund',
#  '68_voorraad_doosje_doos_stuks',
#  '69_bespreken_spreken_persoonlijk_praten',
#  '70_beste_hey_betreft_aandoen',
#  '71_spuit_doorsturen_metamucil_injecties',
#  '72_gewicht_kilo_afgevallen_weeg',
#  '73_lactose_gestopt_beangstigend_gedaald',
#  '74_nachten_duidelijk_kort_bestaat',
#  '75_foto_bijgevoegd_bestand_bijgaand',
#  '76_probleem_toekomst_echt_problemen',
#  '77_stress_invloed_druk_rol',
#  '78_zekerheid_navragen_vragenlijsten_checken',
#  '79_pillen_systeem_azathiopirine_heen',
#  '80_gehoord_gehoor_heden_kapper',
#  '81_ontsteking_galstenen_idd_aanvallen',
#  '82_vergeten_herinnering_herinneren_geheugen',
#  '83_gestart_entyvio_gevaccineerd_verhuizen',
#  '84_vandaar_gevraagd_griep_stuur',
#  '85_ophalen_gang_fistel_bezig',
#  '86_maagonderzoek_kloppen_vervolgafspraak_begrepen',
#  '87_druppels_has_are_kale',
#  '88_rechts_linker_steken_inspanning',
#  '89_hiervoor_situatie_ten_eraan',
#  '90_voldoende_hopende_hiermee_hoop',
#  '91_gaten_houden_hou_gehouden',
#  '92_helpen_kastje_hiermee_muur',
#  '93_optie_alternatief_momenten_mogelijkheden',
#  '94_vermelden_originele_hoor_biologische',
#  '95_aanhouden_verstandig_rest_vervolg',
#  '96_bekeken_lukken_betekend_geeft',
#  '97_biologicals_biological_bureau_wratten',
#  '98_risico_risicogroep_val_loop',
#  '99_urine_kweek_gecontroleerd_urinekweek',
#  '100_fax_faxnummer_vriendelijk_tel',
#  '101_energie_energielevel_moe_stukken',
#  '102_annuleren_meewerken_uitsluitsel_tijdstip',
#  '103_toestemming_toestemmingsformulier_geef_bijlage',
#  '104_wekelijks_nou_volgen_geplande',
#  '105_verzekering_aanvraag_gegevens_levensverzekering',
#  '106_duren_verbetering_langs_werken',
#  '107_werkt_aangeef_traject_darmkrampen',
#  '108_wensen_allereerst_gezond_wens',
#  '109_bijwerking_bijwerkingen_infliximab_innemen',
#  '110_eerstvolgende_aanstaande_groot_terecht',
#  '111_problemen_lange_hierdoor_persen',
#  '112_fysiek_opeens_heden_straks',
#  '113_team_ibd_binnenkort_matig',
#  '114_gezondheidscheck_periodieke_invullen_vullen',
#  '115_gelezen_laboratorium_afgesproken_buikgriep',
#  '116_tandarts_tandvlees_kaakchirurg_mond',
#  '117_betekent_vervolgstappen_stappen_the',
#  '118_aangepast_baat_beclometason_tabletjes',
#  '119_tegemoet_zie_reactie_graag',
#  '120_doorgestuurd_picoprep_gestuurd_zorginstelling',
#  '121_geboortedatum_geboorte_geb_geboren']

# %%
labels = [
    "A",  # -1_verstandigst_trant_aangenaam_zenuwachtig
    "M",  # 0_bloed_prikken_ontlasting_test
    "M",  # 1_pijn_buikpijn_toilet_last
    "A",  # 2_afspraak_telefonisch_contact_bellen
    "A",  # 3_bedankt_dank_reactie_snelle
    "M",  # 4_medicatie_gebruik_tabletten_medicijnen
    "M",  # 5_huisarts_arts_dokter_mdl
    "A",  # 6_recept_apotheek_nieuw_sturen
    "M",  # 7_bekend_calprotectine_uitslag_waarde
    "A",  # 8_hoor_graag_horen_verneem
    "A",  # 9_vraag_vragen_vraagje_vragenlijst
    "M",  # 10_voel_gevoel_voelt_voelen
    "M",  # 11_corona_vaccinatie_vaccin_positief
    "A",  # 12_formulieren_formulier_potje_papieren
    "A",  # 13_mail_brief_adres_bericht
    "A",  # 14_weten_laat_vertellen_laten
    "A",  # 15_hoop_wacht_wachten_hopelijk
    "M",  # 16_goed_gaat_ging_algemeen
    "M",  # 17_eten_eet_eetlust_drinken
    "M",  # 18_advies_adviseren_overleggen_graag
    "M",  # 19_infuus_komende_echo_vanmiddag
    "A",  # 20_weet_ermee_goed_houdt
    "M",  # 21_crohn_ziekte_verklaring_humira
    "A",  # 22_prima_helemaal_allemaal_zsm
    "M",  # 23_beter_gebeurd_gaat_stuk
    "M",  # 24_ijzer_vitamine_ijzerinfuus_foliumzuur
    "A",  # 25_maanden_maand_vragenlijst_maandelijks
    "A",  # 26_mogelijk_mogelijkheid_manier_snel
    "M",  # 27_stoppen_rekening_cortiment_doorgaan
    "A",  # 28_idee_denk_dacht_meld
    "A", #29
    "A",  # 30_geregeld_opsturen_gekeken_doorgeven
    "M",  # 31_humira_hyrimoz_gespoten_spuiten
    "A",  # 32_morgen_vanmorgen_morgenvroeg_ophalen
    "A",  # 33_jaar_vorig_jaren_leeftijd
    "M",  # 34_controle_ziekenhuis_check_periodieke
    "A",  # 35_vernomen_gebeld_helaas_extra
    "M",  # 36_dermatoloog_huid_dermatologie_gezicht
    "A",  # 37_volgende_mailen_hoeft_spuiten
    "A",  # 38_mee_hieraan_vreemd_valt
    "M",  # 39_antibiotica_kuur_antibioticakuur_bacterie
    "M",  # 40_operatie_chirurg_ingepland_gevolgen
    "A",  # 41_gelukkig_blij_gelukt_tevreden
    "A",  # 42_vakantie_vertrek_terug_reizen
    "M",  # 43_onderzoek_akkoord_melden_meedoen
    "A",  # 44_ibd_ibdcoach_sessie_vragen
    "M",  # 45_duurt_ruim_natuurlijk_lang
    "M",  # 46_koorts_temperatuur_verhoging_koude
    "A",  # 47_gaan_besproken_betekenen_houd
    "M",  # 48_mri_scan_dunne_uitslag
    "M",  # 49_zorgen_begin_ongerust_echt
    "M",  # 50_zwangerschap_zwanger_gynaecoloog_medicijngebruik
    "A",  # 51_fijne_feestdagen_jaarwisseling_gewenst
    "A",  # 52_plannen_inplannen_termijn_afspraak
    "A",  # 53_doorgeven_geven_volledig_oplossing
    "M",  # 54_keuze_opvlamming_bang_gal
    "A",  # 55_gegaan_mis_verkeerd_fout
    "A",  # 56_ontvangen_heden_moviprep_bevestiging
    "A",  # 57_zorginstelling_apotheek_ziekenhuis_naam
    "M",  # 58_coloscopie_endoscopie_darmonderzoek_verhuisd
    "A",  # 59_sorry_excuses_late_lastig
    "A",  # 60_zie_vlak_zien_verkeerde
    "A",  # 61_thuistesten_verwijzing_nieuwe_versturen
    "M",  # 62_dosering_combinatie_dosis_laag
    "A",  # 63_resultaten_hiervan_resultaat_vernemen
    "A",  # 64_bedoeling_teveel_doorgegeven_vergoed
    "A",  # 65_wilde_reden_dringend_denkt
    "M",  # 66_veranderd_infusen_helft_interval
    "A",  # 67_app_downloaden_telefoon_ondersteund
    "A",  # 68_voorraad_doosje_doos_stuks
    "A",  # 69_bespreken_spreken_persoonlijk_praten
    "A",  # 70_beste_hey_betreft_aandoen
    "M",  # 71_spuit_doorsturen_metamucil_injecties
    "M",  # 72_gewicht_kilo_afgevallen_weeg
    "M",  # 73_lactose_gestopt_beangstigend_gedaald
    "A",  # 74_nachten_duidelijk_kort_bestaat
    "A",  # 75_foto_bijgevoegd_bestand_bijgaand
    "A",  # 76_probleem_toekomst_echt_problemen
    "M",  # 77_stress_invloed_druk_rol
    "A",  # 78_zekerheid_navragen_vragenlijsten_checken
    "M",  # 79_pillen_systeem_azathiopirine_heen
    "A",  # 80_gehoord_gehoor_heden_kapper
    "M",  # 81_ontsteking_galstenen_idd_aanvallen
    "A",  # 82_vergeten_herinnering_herinneren_geheugen
    "M",  # 83_gestart_entyvio_gevaccineerd_verhuizen
    "A",  # 84_vandaar_gevraagd_griep_stuur
    "M",  # 85_ophalen_gang_fistel_bezig
    "M",  # 86_maagonderzoek_kloppen_vervolgafspraak_begrepen
    "A",  # 87_druppels_has_are_kale
    "M",  # 88_rechts_linker_steken_inspanning
    "A",  # 89_hiervoor_situatie_ten_eraan
    "A",  # 90_voldoende_hopende_hiermee_hoop
    "A",  # 91_gaten_houden_hou_gehouden
    "A",  # 92_helpen_kastje_hiermee_muur
    "A",  # 93_optie_alternatief_momenten_mogelijkheden
    "A",  # 94_vermelden_originele_hoor_biologische
    "A",  # 95_aanhouden_verstandig_rest_vervolg
    "A",  # 96_bekeken_lukken_betekend_geeft
    "M",  # 97_biologicals_biological_bureau_wratten
    "M",  # 98_risico_risicogroep_val_loop
    "M",  # 99_urine_kweek_gecontroleerd_urinekweek
    "A",  # 100_fax_faxnummer_vriendelijk_tel
    "M",  # 101_energie_energielevel_moe_stukken
    "A",  # 102_annuleren_meewerken_uitsluitsel_tijdstip
    "A",  # 103_toestemming_toestemmingsformulier_geef_bijlage
    "A",  # 104_wekelijks_nou_volgen_geplande
    "A",  # 105_verzekering_aanvraag_gegevens_levensverzekering
    "A",  # 106_duren_verbetering_langs_werken
    "M",  # 107_werkt_aangeef_traject_darmkrampen
    "A",  # 108_wensen_allereerst_gezond_wens
    "M",  # 109_bijwerking_bijwerkingen_infliximab_innemen
    "A",  # 110_eerstvolgende_aanstaande_groot_terecht
    "M",  # 111_problemen_lange_hierdoor_persen
    "A",  # 112_fysiek_opeens_heden_straks
    "A",  # 113_team_ibd_binnenkort_matig
    "A",  # 114_gezondheidscheck_periodieke_invullen_vullen
    "A",  # 115_gelezen_laboratorium_afgesproken_buikgriep
    "M",  # 116_tandarts_tandvlees_kaakchirurg_mond
    "A",  # 117_betekent_vervolgstappen_stappen_the
    "M",  # 118_aangepast_baat_beclometason_tabletjes
    "A",  # 119_tegemoet_zie_reactie_graag
    "A",  # 120_doorgestuurd_picoprep_gestuurd_zorginstelling
    "A",  # 121_geboortedatum_geboorte_geb_geboren
]
len(labels)
# Out:
# 123

# %%
topic_summaries = [
    "outlier",  # -1_verstandigst_trant_aangenaam_zenuwachtig
    "blood/stool test",  # 0_bloed_prikken_ontlasting_test
    "symptoms",  # 1_pijn_buikpijn_toilet_last
    "appointment scheduling",  # 2_afspraak_telefonisch_contact_bellen
    "other",  # 3_bedankt_dank_reactie_snelle
    "medication use",  # 4_medicatie_gebruik_tabletten_medicijnen
    "doctor/hospital contact",  # 5_huisarts_arts_dokter_mdl
    "prescription refill",  # 6_recept_apotheek_nieuw_sturen
    "calprotectin results",  # 7_bekend_calprotectine_uitslag_waarde
    "other",  # 8_hoor_graag_horen_verneem
    "questions/inquiries",  # 9_vraag_vragen_vraagje_vragenlijst
    "feelings",  # 10_voel_gevoel_voelt_voelen
    "COVID-19 vaccination",  # 11_corona_vaccinatie_vaccin_positief
    "forms/documents",  # 12_formulieren_formulier_potje_papieren
    "email/mail communication",  # 13_mail_brief_adres_bericht
    "other",  # 14_weten_laat_vertellen_laten
    "other",  # 15_hoop_wacht_wachten_hopelijk
    "general health update",  # 16_goed_gaat_ging_algemeen
    "eating/drinking",  # 17_eten_eet_eetlust_drinken
    "advice",  # 18_advies_adviseren_overleggen_graag
    "infusion/echo appointment",  # 19_infuus_komende_echo_vanmiddag
    "other",  # 20_weet_ermee_goed_houdt
    "Crohn's disease/Humira",  # 21_crohn_ziekte_verklaring_humira
    "other",  # 22_prima_helemaal_allemaal_zsm
    "general health update",  # 23_beter_gebeurd_gaat_stup
    "iron/vitamin",  # 24_ijzer_vitamine_ijzerinfuus_foliumzuur
    "monthly updates",  # 25_maanden_maand_vragenlijst_maandelijks
    "possibilities/options",  # 26_mogelijk_mogelijkheid_manier_snel
    "medication continuation",  # 27_stoppen_rekening_cortiment_doorgaan
    "thoughts/ideas",  # 28_idee_denk_dacht_meld
    "morning_plans", #29
    "follow-up",  # 30_geregeld_opsturen_gekeken_doorgeven
    "Humira/Hyrimoz injections",  # 31_humira_hyrimoz_gespoten_spuiten
    "other",  # 32_morgen_vanmorgen_morgenvroeg_ophalen
    "age/years",  # 33_jaar_vorig_jaren_leeftijd
    "hospital check-up",  # 34_controle_ziekenhuis_check_periodieke
    "follow-up",  # 35_vernomen_gebeld_helaas_extra
    "dermatology/skin",  # 36_dermatoloog_huid_dermatologie_gezicht
    "next steps",  # 37_volgende_mailen_hoeft_spuiten
    "confusion/concerns",  # 38_mee_hieraan_vreemd_valt
    "antibiotics",  # 39_antibiotica_kuur_antibioticakuur_bacterie
    "surgery/operation",  # 40_operatie_chirurg_ingepland_gevolgen
    "happiness/satisfaction",  # 41_gelukkig_blij_gelukt_tevreden
    "travel/vacation",  # 42_vakantie_vertrek_terug_reizen
    "research participation",  # 43_onderzoek_akkoord_melden_meedoen
    "other",  # 44_ibd_ibdcoach_sessie_vragen
    "waiting time",  # 45_duurt_ruim_natuurlijk_lang
    "fever/temperature",  # 46_koorts_temperatuur_verhoging_koude
    "discussions",  # 47_gaan_besproken_betekenen_houd
    "MRI scan",  # 48_mri_scan_dunne_uitslag
    "worries/concerns",  # 49_zorgen_begin_ongerust_echt
    "pregnancy/medication",  # 50_zwangerschap_zwanger_gynaecoloog_medicijngebruik
    "other",  # 51_fijne_feestdagen_jaarwisseling_gewenst
    "planning/scheduling",  # 52_plannen_inplannen_termijn_afspraak
    "information sharing",  # 53_doorgeven_geven_volledig_oplossing
    "flare-up concerns",  # 54_keuze_opvlamming_bang_gal
    "mistakes/issues",  # 55_gegaan_mis_verkeerd_fout
    "receipt confirmation",  # 56_ontvangen_heden_moviprep_bevestiging
    "healthcare facility",  # 57_zorginstelling_apotheek_ziekenhuis_naam
    "colonoscopy/endoscopy",  # 58_coloscopie_endoscopie_darmonderzoek_verhuisd
    "apologies",  # 59_sorry_excuses_late_lastig
    "other",  # 60_zie_vlak_zien_verkeerde
    "requests for supplies",  # 61_thuistesten_verwijzing_nieuwe_versturen
    "dosage adjustments",  # 62_dosering_combinatie_dosis_laag
    "results discussion",  # 63_resultaten_hiervan_resultaat_vernemen
    "intentions/overpayment",  # 64_bedoeling_teveel_doorgegeven_vergoed
    "urgent requests",  # 65_wilde_reden_dringend_denkt
    "infusion changes",  # 66_veranderd_infusen_helft_interval
    "mobile app",  # 67_app_downloaden_telefoon_ondersteund
    "medication stock",  # 68_voorraad_doosje_doos_stuks
    "personal discussions",  # 69_bespreken_spreken_persoonlijk_praten
    "greetings",  # 70_beste_hey_betreft_aandoen
    "injections",  # 71_spuit_doorsturen_metamucil_injecties
    "weight changes",  # 72_gewicht_kilo_afgevallen_weeg
    "lactose intolerance",  # 73_lactose_gestopt_beangstigend_gedaald
    "sleep issues",  # 74_nachten_duidelijk_kort_bestaat
    "attached files",  # 75_foto_bijgevoegd_bestand_bijgaand
    "future problems",  # 76_probleem_toekomst_echt_problemen
    "stress impact",  # 77_stress_invloed_druk_rol
    "confirmation/questions",  # 78_zekerheid_navragen_vragenlijsten_checken
    "medication system",  # 79_pillen_systeem_azathiopirine_heen
    "general updates",  # 80_gehoord_gehoor_heden_kapper
    "inflammation/gallstones",  # 81_ontsteking_galstenen_idd_aanvallen
    "forgetfulness/memory",  # 82_vergeten_herinnering_herinneren_geheugen
    "Entyvio start/vaccination",  # 83_gestart_entyvio_gevaccineerd_verhuizen
    "inquiries/flu",  # 84_vandaar_gevraagd_griep_stuur
    "fistula issues",  # 85_ophalen_gang_fistel_bezig
    "stomach examination",  # 86_maagonderzoek_kloppen_vervolgafspraak_begrepen
    "drops/medication",  # 87_druppels_has_are_kale
    "pain locations",  # 88_rechts_linker_steken_inspanning
    "other",  # 89_hiervoor_situatie_ten_eraan
    "other",  # 90_voldoende_hopende_hiermee_hoop
    "other",  # 91_gaten_houden_hou_gehouden
    "assistance/help",  # 92_helpen_kastje_hiermee_muur
    "options/alternatives",  # 93_optie_alternatief_momenten_mogelijkheden
    "biological medication",  # 94_vermelden_originele_hoor_biologische
    "continuation/rest",  # 95_aanhouden_verstandig_rest_vervolg
    "other",  # 96_bekeken_lukken_betekend_geeft
    "biologicals treatment",  # 97_biologicals_biological_bureau_wratten
    "risk factors",  # 98_risico_risicogroep_val_loop
    "urine test",  # 99_urine_kweek_gecontroleerd_urinekweek
    "fax communication",  # 100_fax_faxnummer_vriendelijk_tel
    "energy levels",  # 101_energie_energielevel_moe_stukken
    "cancellation/cooperation",  # 102_annuleren_meewerken_uitsluitsel_tijdstip
    "consent forms",  # 103_toestemming_toestemmingsformulier_geef_bijlage
    "weekly updates",  # 104_wekelijks_nou_volgen_geplande
    "insurance matters",  # 105_verzekering_aanvraag_gegevens_levensverzekering
    "duration/improvement",  # 106_duren_verbetering_langs_werken
    "treatment effectiveness",  # 107_werkt_aangeef_traject_darmkrampen
    "other",  # 108_wensen_allereerst_gezond_wens
    "medication side effects",  # 109_bijwerking_bijwerkingen_infliximab_innemen
    "next appointment",  # 110_eerstvolgende_aanstaande_groot_terecht
    "long-term issues",  # 111_problemen_lange_hierdoor_persen
    "physical changes",  # 112_fysiek_opeens_heden_straks
    "other",  # 113_team_ibd_binnenkort_matig
    "health check",  # 114_gezondheidscheck_periodieke_invullen_vullen
    "lab results",  # 115_gelezen_laboratorium_afgesproken_buikgriep
    "dental issues",  # 116_tandarts_tandvlees_kaakchirurg_mond
    "next steps",  # 117_betekent_vervolgstappen_stappen_the
    "medication adjustment",  # 118_aangepast_baat_beclometason_tabletjes
    "other",  # 119_tegemoet_zie_reactie_graag
    "forwarded documents",  # 120_doorgestuurd_picoprep_gestuurd_zorginstelling
    "birthdate",  # 121_geboortedatum_geboorte_geb_geboren
]

len(topic_summaries)
# Out:
# 123

# %%
topic_info[topic_info["Name"].str.contains("operatie")]
# Out:
#     Topic  Count                                    Name  \
# 41     40    217  40_operatie_chirurg_ingepland_gevolgen
#
#                                                                                                     Representation  \
# 41  [operatie, chirurg, ingepland, gevolgen, vedoluzimab, chirurgie, verplaatsen, verergerd, afspraak, jaarlijkse]
#
#                                                                                                                                             Representative_Docs
# 41  [Graag zou ik nu weten wat dat voor een operatie zou zijn., Nu hoor ik net dat mijn operatie pas over 3 weken., of  afgelopen maandag mijn operatie gehad.]

# %%
topic_info["Label"] = labels
topic_info["Summary"] = topic_summaries
labeled_topic_info = topic_info

# %%
non_informative_topics = labeled_topic_info["Topic"][labeled_topic_info["Summary"] == "other"].to_list()
non_informative_topics
# Out:
# [3, 8, 14, 15, 20, 22, 44, 51, 60, 89, 90, 91, 96, 108, 113, 119]

# %%
meaningful_topic_info = labeled_topic_info[labeled_topic_info["Summary"] != "other"][1:]

# %%
medication_topics = meaningful_topic_info[meaningful_topic_info["Summary"].str.contains("medication|injection|dosage|treatment|vitamin|antibio")]
remaining_topics = meaningful_topic_info[~meaningful_topic_info["Summary"].str.contains("medication|injection|dosage|treatment|vitamin|antibio")]
medication_topics
# Out:
#      Topic  Count                                                 Name  \
# 5        4   2298             4_medicatie_gebruik_tabletten_medicijnen
# 25      24    296             24_ijzer_vitamine_ijzerinfuus_foliumzuur
# 28      27    292               27_stoppen_rekening_cortiment_doorgaan
# 32      31    257                   31_humira_hyrimoz_gespoten_spuiten
# 40      39    217         39_antibiotica_kuur_antibioticakuur_bacterie
# 51      50    171  50_zwangerschap_zwanger_gynaecoloog_medicijngebruik
# 63      62    122                    62_dosering_combinatie_dosis_laag
# 69      68    107                        68_voorraad_doosje_doos_stuks
# 72      71    102              71_spuit_doorsturen_metamucil_injecties
# 80      79     91                 79_pillen_systeem_azathiopirine_heen
# 88      87     82                             87_druppels_has_are_kale
# 95      94     74              94_vermelden_originele_hoor_biologische
# 98      97     72             97_biologicals_biological_bureau_wratten
# 108    107     58                107_werkt_aangeef_traject_darmkrampen
# 110    109     56       109_bijwerking_bijwerkingen_infliximab_innemen
# 119    118     39            118_aangepast_baat_beclometason_tabletjes
#
#                                                                                                               Representation  \
# 5                         [medicatie, gebruik, tabletten, medicijnen, gebruiken, daags, pentasa, tablet, apotheek, medicijn]
# 25                                   [ijzer, vitamine, ijzerinfuus, foliumzuur, vitamines, vit, crp, injectie, laag, tekort]
# 28                                   [stoppen, rekening, cortiment, doorgaan, mee, houden, stop, slikken, handig, tijdelijk]
# 32                                    [humira, hyrimoz, gespoten, spuiten, starten, zetten, gebruik, spuit, naald, injectie]
# 40   [antibiotica, kuur, antibioticakuur, bacterie, antibioticum, allergische, tabletje, voorgeschreven, gekregen, infectie]
# 51      [zwangerschap, zwanger, gynaecoloog, medicijngebruik, baby, hartje, berekening, vruchtbaarheid, kinkhoest, effecten]
# 63                      [dosering, combinatie, dosis, laag, aankijken, los, vloeibaar, dubbele, besmettingen, behandelingen]
# 69                                      [voorraad, doosje, doos, stuks, zakjes, elkaar, aangeven, pilletjes, buisjes, volle]
# 72                         [spuit, doorsturen, metamucil, injecties, recept, apotheek, zorginstelling, meerssen, gezet, geb]
# 80                           [pillen, systeem, azathiopirine, heen, simponi, reageert, lever, azethoprine, dossier, xeljanz]
# 88                                                        [druppels, has, are, kale, trek, the, heftig, not, eenmaal, worse]
# 95                        [vermelden, originele, hoor, biologische, tacal, stempel, voorzien, recept, koortslip, aanvulling]
# 98                      [biologicals, biological, bureau, wratten, weekse, biopsie, starten, aangetroffen, plekke, switchen]
# 108                             [werkt, aangeef, traject, darmkrampen, valt, interpreteren, zit, inenting, afspreken, regel]
# 110    [bijwerking, bijwerkingen, infliximab, innemen, concentreren, budosenide, flagyl, gewichtstoename, bijsluiter, ofwel]
# 119                 [aangepast, baat, beclometason, tabletjes, middel, nachtrust, weerstand, beviel, concluderen, echinacea]
#
#                                                                                                                                                                                          Representative_Docs  \
# 5                                                     [Kan dit Met de medicatie te maken hebben?, graag recept voor: Pentasa 500, 2x per dag 2 tabletten, 360 stuks., Graag zou ik andere medicatie willen.]
# 25                         [er hebben ze ook gelijk op ijzer geprikt., het bloed is getest of ijzer en de vitamine b12-, Is het tevens mogelijk om dan ook nog eens vitamine b12 en ijzer te laten prikken?]
# 28                                                                            [Mijn vraag: kan ik nu stoppen met de Cortiment?, En cortiment na 8 dagen stoppen (omdat ik niet meer heb?), Dan stoppen hè ?]
# 32                   [Mijn eigen prikschema met Humira is om de twee weken op de donderdag en wel op op 8 april en 20 mei., Ik kan elke week humira niet aan., Ik heb mijn Humira deze week nog niet gehad.]
# 40                                                        [Ik heb antibiotica gekregen., ik ben bij de huisarts geweest en heb een antibiotica kuur van 5 dagen gekregen., Nee geen antibiotica kuur gehad.]
# 51                                                                                        [Dit vanwege mijn zwangerschap., Dit mag gewoon tijdens de zwangerschap., Dit had ik ook tijdens de zwangerschap.]
# 63                                                                                            [Misschien is de dosering te laag ., Is de dosering van 20mg te laag?, Mag dit in combinatie met mijn infuus?]
# 69   [Ik heb er nu nog 2 in voorraad., Ik heb er nog slechts 3 in voorraad., Ik kreeg in het begin steeds 2 doosjes (120 stuks), dat werd erna verminderd tot 1,5 doosje (90 stuks) en de laatste keer ze...
# 72   [Aangezien het ook een spuit is., Willen jullie een recept voor de B12 spuit en Metamucil doorsturen naar de apotheek in ., Willen jullie een recept voor de B12 spuit doorsturen naar de apotheek  ...
# 80                                                             [mijn azathiopirine pillen zijn weer bijna op., mijn azathiopirine pillen zijn weer bijna op., mijn azathiopirine pillen zijn weer bijna op.]
# 88   [I am afraid the complaints will only get worse and worse if I need to wait at least two weeks more., Originally I thought it may be a consequence of my cyst infection or a reaction between the an...
# 95                                                                [Op het recept graag de originele vermelden., Op het recept graag de originele vermelden., Op het recept graag de    originele vermelden.]
# 98                                                                                                           [Biologicals bureau., Kan ik dit bij de biologicals inleveren?, ik gebruik biologicals humira.]
# 108                                                                                                 [Prednisolon werkt., Als huishoudfolie ook werkt dan gebruik ik deze., Hoe werkt dit eigenlijk precies.]
# 110                                                                    [Is dit een bijwerking van het infuus?, Weet namelijk niet of dit een bijwerking kan zijn., Is dat een bijwerking bij die medicatie?]
# 119          [Zou dit ook nog aangepast kunnen worden?, De gezondheidspremie wordt aangepast., Ik heb hier toch veel meer baat bij dan bij de Beclometason 3x per week en nu gaat het goed met de klachten.]
#
#     Label                    Summary
# 5       M             medication use
# 25      M               iron/vitamin
# 28      M    medication continuation
# 32      M  Humira/Hyrimoz injections
# 40      M                antibiotics
# 51      M       pregnancy/medication
# 63      M         dosage adjustments
# 69      A           medication stock
# 72      M                 injections
# 80      M          medication system
# 88      A           drops/medication
# 95      A      biological medication
# 98      M      biologicals treatment
# 108     M    treatment effectiveness
# 110     M    medication side effects
# 119     M      medication adjustment

# %%
# medication topics to merge
[94, 97], #biologicals
[62, 118], #dose adjustment
[68, 79] # medication stock
[31, 71] # injections

# %%
health_update_topics = remaining_topics[remaining_topics["Summary"].str.contains("update|follow-up|improvement|check")]
remaining_topics = remaining_topics[~remaining_topics["Summary"].str.contains("update|follow-up|improvement|check")]
health_update_topics
# Out:
#      Topic  Count                                             Name  \
# 17      16    400                       16_goed_gaat_ging_algemeen
# 24      23    301                       23_beter_gebeurd_gaat_stuk
# 26      25    296         25_maanden_maand_vragenlijst_maandelijks
# 31      30    257           30_geregeld_opsturen_gekeken_doorgeven
# 35      34    237          34_controle_ziekenhuis_check_periodieke
# 36      35    232                  35_vernomen_gebeld_helaas_extra
# 81      80     91                   80_gehoord_gehoor_heden_kapper
# 105    104     61                104_wekelijks_nou_volgen_geplande
# 107    106     59               106_duren_verbetering_langs_werken
# 115    114     48  114_gezondheidscheck_periodieke_invullen_vullen
#
#                                                                                                Representation  \
# 17                                     [goed, gaat, ging, algemeen, gegaan, darmen, fijn, idee, moment, baby]
# 24                             [beter, gebeurd, gaat, stuk, langzaam, ging, helaas, toepassing, alweer, gaan]
# 26          [maanden, maand, vragenlijst, maandelijks, laatste, maandelijkse, aantal, tijd, enkele, ingevuld]
# 31             [geregeld, opsturen, gekeken, doorgeven, nagaan, aanpassen, verlengen, afmelden, wilt, succes]
# 35       [controle, ziekenhuis, check, periodieke, bedrijfsarts, zojuist, ingevuld, komen, werk, vragenlijst]
# 36             [vernomen, gebeld, helaas, extra, jammer, klachten, moment, roesje, ontlastingtesten, printer]
# 81                    [gehoord, gehoor, heden, kapper, helaas, tijdig, besloten, hoor, groep, verpleegkundig]
# 105                 [wekelijks, nou, volgen, geplande, geval, inname, polibezoek, gezet, opgenomen, schrijft]
# 107                [duren, verbetering, langs, werken, harde, belang, geluiden, durf, relevant, supplementen]
# 115  [gezondheidscheck, periodieke, invullen, vullen, meerwaarde, vragenlijst, ingevuld, staat, basis, colon]
#
#                                                                                                                                                                                          Representative_Docs  \
# 17                                                                                                 [Verder gaat het goed met me., Gaat vrij goed met mij., Op wat restverschijnselen na gaat het weer goed.]
# 24                                                                                                                    [Verder gaat het wel weer wat beter., Maar des te beter., Het wordt er niet beter op.]
# 26                                                                                                                    [Zal dit deze maand doen!, Graag weer voor 3 maanden., Graag voor 3 maanden dan weer.]
# 31                                                                                                [Zou dit alsnog geregeld kunnen worden?, Zou dat alsnog geregeld kunnen worden?, Kan dat geregeld worden?]
# 35                                                          [Vervolgens ben ik op 12 juni op controle geweest bij ., Afgelopen maandag nog op controle geweest bij ., Heb er ook niet altijd controle over.]
# 36                                                                           [helaas heb  ik  nog niks vernomen van ., Helaas heb ik niks meer vernomen., Helaas heb ik niks vernomen, wordt ik nog gebeld?]
# 81                                                                                            [Ik heb hier nog niets van gehoord., Ik heb niets meer gehoord., Ik heb hier namelijk niks meer over gehoord.]
# 105  [Moet ik nou gewoon afwachten tot polibezoek in januari of moet er eerder al iets gebeuren?, Ik neem het nu wekelijks, dus heb het volgende week dinsdag nodig., Afgelopen week heb ik de spuit een ...
# 107  [Ik weet dat het even kan duren voordat dit werkt., Ik weet dat het nog enige tijd kan duren voordat de Thiosix begint te werken., Ik weet niet of het van belang is om dit te weten, maar mijn darm...
# 115  [Er staat nog een gezondheidscheck voor mij klaar., In de periodieke gezondheidscheck heb ik aangegeven dat ik ziek was de afgelopen week., Ik ben mijn periodieke gezondheidscheck in aan het vulle...
#
#     Label                Summary
# 17      M  general health update
# 24      M  general health update
# 26      A        monthly updates
# 31      A              follow-up
# 35      M      hospital check-up
# 36      A              follow-up
# 81      A        general updates
# 105     A         weekly updates
# 107     A   duration/improvement
# 115     A           health check

# %%
health_update_topics["Topic"].to_list()
# all merge together
# Out:
# [16, 23, 25, 30, 34, 35, 80, 104, 106, 114]

# %%
test_topics = remaining_topics[remaining_topics["Summary"].str.contains("test|lab|improvement|calpro")]
remaining_topics = remaining_topics[~remaining_topics["Summary"].str.contains("test|lab|improvement|calpro")]
test_topics
#[0, 115]
# Out:
#      Topic  Count                                            Name  \
# 1        0   4806                 0_bloed_prikken_ontlasting_test
# 8        7   1074           7_bekend_calprotectine_uitslag_waarde
# 100     99     67         99_urine_kweek_gecontroleerd_urinekweek
# 116    115     48  115_gelezen_laboratorium_afgesproken_buikgriep
#
#                                                                                                 Representation  \
# 1          [bloed, prikken, ontlasting, test, laten, slijm, bloedprikken, ingeleverd, bloeduitslagen, geprikt]
# 8                [bekend, calprotectine, uitslag, waarde, spiegel, uitslagen, waardes, gemeten, hoog, waarden]
# 100  [urine, kweek, gecontroleerd, urinekweek, urineweginfectie, constateren, blaas, snappen, infectie, gezet]
# 116  [gelezen, laboratorium, afgesproken, buikgriep, briefje, aankomende, afgegeven, toenemen, kontakt, naast]
#
#                                                                                                                                                                                          Representative_Docs  \
# 1                                      [Ik heb echter nog geen bloed laten prikken., Ik heb overigens gisterenochtend bloed laten prikken., m.v.g. Ben op  in kerkrade geweest voor bloed te laten prikken.]
# 8                              [dames,  Is de uitslag van de calprotectine al bekend van 25 november?, De uitslag van de Calprotectine is nog niet bekend., Is de uitslag van mijn calprotectine al bekend.]
# 100                                                                        [Moet ik ook ontlasting en urine ,mee nemen ., Huisarts heeft urine op kweek laten zetten., Is er al een uitslag vd urine kweek?]
# 116  [Mijn briefje met het herhaalrecept heb ik vorige week afgegeven in ., Tijdens dit contactmoment hebben we afgesproken dat ik deze week een bericht stuur hoe het met mij gaat (vorige week namelijk...
#
#     Label               Summary
# 1       M      blood/stool test
# 8       M  calprotectin results
# 100     M            urine test
# 116     A           lab results

# %%
contact_topics = remaining_topics[remaining_topics["Summary"].str.contains("appointment|call|telephone|fax|email|mail")]
contact_topics
#[2, 110]
# Out:
#      Topic  Count                                        Name  \
# 3        2   3416       2_afspraak_telefonisch_contact_bellen
# 14      13    491                 13_mail_brief_adres_bericht
# 20      19    340            19_infuus_komende_echo_vanmiddag
# 101    100     66           100_fax_faxnummer_vriendelijk_tel
# 111    110     53  110_eerstvolgende_aanstaande_groot_terecht
#
#                                                                                                  Representation  \
# 3               [afspraak, telefonisch, contact, bellen, proberen, bereikbaar, vandaag, poli, gepland, opnemen]
# 14                             [mail, brief, adres, bericht, ontvangen, oude, mailadres, gestuurd, post, email]
# 20                   [infuus, komende, echo, vanmiddag, terug, gebeld, stage, aanstaande, vedolizumab, entyvio]
# 101                [fax, faxnummer, vriendelijk, tel, service, zorginstelling, apotheek, nummer, mail, bedankt]
# 111  [eerstvolgende, aanstaande, groot, terecht, maandagmiddag, prikpen, meteen, trager, belafspraak, gespoten]
#
#                                                                                                                                                                  Representative_Docs  \
# 3        [Kan een afspraak via u, of neem ik hier zelf contact over op?, 22 november heb ik telefonisch contact gehad met ., Anders moeten we nog even telefonisch contact op nemen]
# 14   [Ook heb ik nog geen brief/mail ontvangen over mijn endoscopie datum, tijd en locatie, weet u dit misschien?, Deze mail heb ik zeker niet al eerder gehad!!, Daarom deze mail.]
# 20                                         [Op 10 maar moet ik in  zijn voor mijn infuus., Komende donderdag krijg ik weer mijn infuus., Komende maandag heb ik mijn tweede infuus.]
# 101                                                                                           [Apotheek  fax:  mail:   [ID], Dit is onze nieuwe apotheek Fax nr ., Fax nr [ID]    .]
# 111                                                       [Van aanstaande maandag., Eerstvolgende prikpen is a.s. maandagmiddag., Ik heb op 4 januari aanstaande een afspraak bij .]
#
#     Label                    Summary
# 3       A     appointment scheduling
# 14      A   email/mail communication
# 20      M  infusion/echo appointment
# 101     A          fax communication
# 111     A           next appointment

# %%
remaining_topics = remaining_topics[~remaining_topics["Summary"].str.contains("appointment|call|telephone|fax|email|mail")]
remaining_topics
# Out:
#      Topic  Count                                               Name  \
# 2        1   3651                        1_pijn_buikpijn_toilet_last
# 6        5   1559                         5_huisarts_arts_dokter_mdl
# 7        6   1347                     6_recept_apotheek_nieuw_sturen
# 10       9    579                 9_vraag_vragen_vraagje_vragenlijst
# 11      10    558                        10_voel_gevoel_voelt_voelen
# ..     ...    ...                                                ...
# 113    112     50                     112_fysiek_opeens_heden_straks
# 117    116     45            116_tandarts_tandvlees_kaakchirurg_mond
# 118    117     42            117_betekent_vervolgstappen_stappen_the
# 121    120     36  120_doorgestuurd_picoprep_gestuurd_zorginstelling
# 122    121     34             121_geboortedatum_geboorte_geb_geboren
#
#                                                                                                    Representation  \
# 2                                    [pijn, buikpijn, toilet, last, keer, buik, klachten, normaal, soms, diarree]
# 6            [huisarts, arts, dokter, mdl, ziekenhuis, contact, verpleegkundige, medische, afspraak, behandeling]
# 7                    [recept, apotheek, nieuw, sturen, herhaalrecept, faxen, purinethol, nethol, puri, aanvragen]
# 10                 [vraag, vragen, vraagje, vragenlijst, vraagjes, daarnaast, vandaar, aantal, korte, aanleiding]
# 11                                     [voel, gevoel, voelt, voelen, moe, gevoelig, voelde, lekker, goed, slecht]
# ..                                                                                                            ...
# 113                 [fysiek, opeens, heden, straks, beantwoord, aangegeven, aangevraagd, nml, reactie, ontvangen]
# 117                     [tandarts, tandvlees, kaakchirurg, mond, kies, tanden, verwezen, acute, ontsteking, tong]
# 118           [betekent, vervolgstappen, stappen, the, vervolg, vervolgstap, leukocyten, rapportage, attach, far]
# 121  [doorgestuurd, picoprep, gestuurd, zorginstelling, doorgezet, derrein, recept, apotheek, gram, hartbewaking]
# 122                    [geboortedatum, geboorte, geb, geboren, hpm, afschaffen, inlevering, welkom, datums, woog]
#
#                                                                                                                                                                                          Representative_Docs  \
# 2    [maar ik heb tot nu toe nog steeds last van buikpijn en pijn aan mijn maag als ik het goed heb .. nu is de vraag is dat normaal of niet ., Ik heb veel pijn in mijn buik., Wel wat diarree, maar gee...
# 6                                                                                                  [Of moet dat ook via de huisarts?, Kan dit alles bij de huisarts?, Bij de huisarts of in het ziekenhuis?]
# 7    [Graag wil ik wel even vragen of jullie een nieuw recept voor de azathioprone 50 Mg kunnen sturen naar apotheek ., Recept mag naar apotheek  ()., Kunnen jullie a.u.b. een nieuw recept naar de apot...
# 10                                                                                                                              [Ik heb eigenlijk een vraag., ik heb een vraag., Ik heb namelijk een vraag.]
# 11                                                       [Ik voel me nog altijd niet goed., Nee ik voel me juist heel erg goed., Ik heb afgelopen vrijdag 10 km gerend en sindsdien voel ik me in onbalans.]
# ..                                                                                                                                                                                                       ...
# 113                      [Tot op heden heb ik geen reactie mogen ontvangen., Dit is reeds eerder aangevraagd maar tot op heden nog geen reactie., Tot op vandaag nog geen reactie van de fysiek  ontvangen.]
# 117                                                [Morgen ga ik hiervoor naar de tandarts., Afspraak met tandarts is inmiddels gemaakt., 2 juni a.s. krijg ik een wortelkanaalbehandeling bij de tandarts.]
# 118                                                                                                                                             [Wat betekent dit nu?, Wat betekent dit?, Wat betekent dit?]
# 121                    [Dit mag doorgestuurd worden naar de [APOTHEEK] in ., Dit mag doorgestuurd worden naar de [APOTHEEK] in ., Het recept van de picoprep zou zijn doorgestuurd naar [APOTHEEK]derrein .]
# 122                                                                                                                                      [De geboortedatum is ., geboortedatum is: ., De geboortedatum is .]
#
#     Label                  Summary
# 2       M                 symptoms
# 6       M  doctor/hospital contact
# 7       A      prescription refill
# 10      A      questions/inquiries
# 11      M                 feelings
# ..    ...                      ...
# 113     A         physical changes
# 117     M            dental issues
# 118     A               next steps
# 121     A      forwarded documents
# 122     A                birthdate
#
# [71 rows x 7 columns]

# %%
remaining_topics[49:]
# Out:
#      Topic  Count                                                 Name  \
# 79      78     91          78_zekerheid_navragen_vragenlijsten_checken
# 82      81     89                81_ontsteking_galstenen_idd_aanvallen
# 83      82     85          82_vergeten_herinnering_herinneren_geheugen
# 84      83     85            83_gestart_entyvio_gevaccineerd_verhuizen
# 85      84     84                      84_vandaar_gevraagd_griep_stuur
# 86      85     83                         85_ophalen_gang_fistel_bezig
# 87      86     83    86_maagonderzoek_kloppen_vervolgafspraak_begrepen
# 89      88     81                   88_rechts_linker_steken_inspanning
# 93      92     76                        92_helpen_kastje_hiermee_muur
# 94      93     75          93_optie_alternatief_momenten_mogelijkheden
# 96      95     74                 95_aanhouden_verstandig_rest_vervolg
# 99      98     68                       98_risico_risicogroep_val_loop
# 102    101     63                 101_energie_energielevel_moe_stukken
# 103    102     63         102_annuleren_meewerken_uitsluitsel_tijdstip
# 104    103     62   103_toestemming_toestemmingsformulier_geef_bijlage
# 106    105     60  105_verzekering_aanvraag_gegevens_levensverzekering
# 112    111     51                  111_problemen_lange_hierdoor_persen
# 113    112     50                       112_fysiek_opeens_heden_straks
# 117    116     45              116_tandarts_tandvlees_kaakchirurg_mond
# 118    117     42              117_betekent_vervolgstappen_stappen_the
# 121    120     36    120_doorgestuurd_picoprep_gestuurd_zorginstelling
# 122    121     34               121_geboortedatum_geboorte_geb_geboren
#
#                                                                                                                                     Representation  \
# 79                                                [zekerheid, navragen, vragenlijsten, checken, moeizaam, feit, wou, engels, doorheen, vereniging]
# 82                                         [ontsteking, galstenen, idd, aanvallen, gerelateerd, overgeven, gefaxt, vermoeden, onsteking, gasthuis]
# 83                                       [vergeten, herinnering, herinneren, geheugen, vergeet, vragen, concentratie, helemaal, sneller, verzocht]
# 84                                           [gestart, entyvio, gevaccineerd, verhuizen, afspraken, trouwens, gemaakt, uitgerekend, gepaard, kwam]
# 85                                             [vandaar, gevraagd, griep, stuur, infuuscentrum, vergist, buikklachten, vervroegd, midden, correct]
# 86                                                                  [ophalen, gang, fistel, bezig, thiosix, einde, dient, laxeren, ervaring, mede]
# 87                                                [maagonderzoek, kloppen, vervolgafspraak, begrepen, vast, stond, erbij, doorgaat, indien, spoed]
# 89                                                          [rechts, linker, steken, inspanning, handen, voeten, linkerkant, nier, onderste, name]
# 93                                                           [helpen, kastje, hiermee, muur, hierbij, klysma, steun, hoop, alsjeblieft, onrustige]
# 94                                     [optie, alternatief, momenten, mogelijkheden, mss, alternatieve, nederland, vastgesteld, buitenland, groot]
# 96                                             [aanhouden, verstandig, rest, vervolg, microlax, slim, blijft, boumans, voedingspatroon, neussonde]
# 99                                                                [risico, risicogroep, val, loop, behoor, groep, bso, trigger, lopen, prikdienst]
# 102                                                    [energie, energielevel, moe, stukken, aant, krijgt, richting, energieniveau, hormonen, eet]
# 103                                          [annuleren, meewerken, uitsluitsel, tijdstip, aanbod, graag, meedoen, uiteindelijk, vernemen, inzien]
# 104                              [toestemming, toestemmingsformulier, geef, bijlage, informatiefolder, erbij, toesturen, inzage, retour, gegevens]
# 106  [verzekering, aanvraag, gegevens, levensverzekering, overlijdensrisicoverzekering, medische, opvragen, verzekeringsarts, schijnt, opgevraagd]
# 112                                           [problemen, lange, hierdoor, persen, onderdrukt, stimuleren, activiteit, buurt, fulltime, verklaren]
# 113                                                  [fysiek, opeens, heden, straks, beantwoord, aangegeven, aangevraagd, nml, reactie, ontvangen]
# 117                                                      [tandarts, tandvlees, kaakchirurg, mond, kies, tanden, verwezen, acute, ontsteking, tong]
# 118                                            [betekent, vervolgstappen, stappen, the, vervolg, vervolgstap, leukocyten, rapportage, attach, far]
# 121                                   [doorgestuurd, picoprep, gestuurd, zorginstelling, doorgezet, derrein, recept, apotheek, gram, hartbewaking]
# 122                                                     [geboortedatum, geboorte, geb, geboren, hpm, afschaffen, inlevering, welkom, datums, woog]
#
#                                                                                                                                                                                          Representative_Docs  \
# 79                                                                                                [Maar ik vraag het toch even voor de zekerheid., Ik vraag dit voor de zekerheid., Even voor de zekerheid.]
# 82                                                                                                                            [(Ik heb galstenen)., De ontsteking is nl., De ontsteking is nu wel weer weg.]
# 83                                           [Kan het zijn dat dit vergeten is?, Nee, ik heb het er niet met  over gehad want dat was ik vergeten., Ik was alleen iets vergeten en iets vergeten te vragen.]
# 84                                                                               [Ze zijn gestart met weeenremmers en longrijping., 17-09 gestart met  1 dag 10 en 1 dag 5., Zodat dese gestart kan worden.]
# 85                           [Vandaar dat het opnieuw moest., Vandaar eigenlijk liever niet., Nu werd mij gevraagd om na twee weken contact met jullie op te nemen, dus vandaar dat ik een berichtje stuur.]
# 86                                                 [Ik ga het donderdag ophalen., Of moet ik het ergens ophalen?, Dankjewel dat alles zo snel in gang gezet wordt, ik zal het recept volgende week ophalen.]
# 87                             [Ik moet die dag toch voor maagonderzoek., N.a.v. Het maagonderzoek., Zodra er een datum vast stond voor  maagonderzoek moest ik de datum doorgeven wanneer het vast stond .]
# 89   [Bij inspanning vaker last van steken aan linkerzijde buik (vergelijkbaar met steken tijdens opvlamming)., Bij inspanning vaker last van steken aan linkerzijde buik (vergelijkbaar met steken tijde...
# 93                                                                                                                  [Kunnen jullie me helpen?, Kun jij mij verder helpen?, zouden jullie mij kunnen helpen?]
# 94                                                                                                                                          [Is dit een optie?, Is dat een optie?, zou dit een optie zijn?.]
# 96                                                                                                                      [De buikpijn blijft aanhouden., Wat moet ik nu aanhouden?, Kan ik dit zo aanhouden?]
# 99                                                                                                                  [Loop ik dan nog meer verhoogd risico., Loop ik extra risico?, Kan ik het risico nemen?]
# 102                                                                                            [Ik heb veel minder buikpijn en heb ook meer energie., wel heb ik iets meer energie., Wel iets meer energie.]
# 103                                                                                     [Bedankt voor het annuleren van de afspraak., Graag zou ik deze willen annuleren., ik wil hier graag aan meewerken.]
# 104                                                                    [ik geef toestemming n.klever, Ik geef graag toestemming, wilt u mij het toestemmingsformulier toesturen?, Geef bij deze toestemming]
# 106  [Er is een aanvraag gedaan vanuit de verzekeraar Allianz voor een overlijdensrisico verzekering, hiervoor is informatie opgevraagd bij het ziekenhuis maar hier is geen reactie op gekomen., Ivm de ...
# 112  [Ik heb zelf het idee dat de cortiment de reumatische klachten lange tijd onderdrukt heeft en deze, nu ik hiermee gestopt ben, weer tot uiting komen., Echt problemen met de darmen heb ik niet., Ik...
# 113                      [Tot op heden heb ik geen reactie mogen ontvangen., Dit is reeds eerder aangevraagd maar tot op heden nog geen reactie., Tot op vandaag nog geen reactie van de fysiek  ontvangen.]
# 117                                                [Morgen ga ik hiervoor naar de tandarts., Afspraak met tandarts is inmiddels gemaakt., 2 juni a.s. krijg ik een wortelkanaalbehandeling bij de tandarts.]
# 118                                                                                                                                             [Wat betekent dit nu?, Wat betekent dit?, Wat betekent dit?]
# 121                    [Dit mag doorgestuurd worden naar de [APOTHEEK] in ., Dit mag doorgestuurd worden naar de [APOTHEEK] in ., Het recept van de picoprep zou zijn doorgestuurd naar [APOTHEEK]derrein .]
# 122                                                                                                                                      [De geboortedatum is ., geboortedatum is: ., De geboortedatum is .]
#
#     Label                    Summary
# 79      A     confirmation/questions
# 82      M    inflammation/gallstones
# 83      A       forgetfulness/memory
# 84      M  Entyvio start/vaccination
# 85      A              inquiries/flu
# 86      M             fistula issues
# 87      M        stomach examination
# 89      M             pain locations
# 93      A            assistance/help
# 94      A       options/alternatives
# 96      A          continuation/rest
# 99      M               risk factors
# 102     M              energy levels
# 103     A   cancellation/cooperation
# 104     A              consent forms
# 106     A          insurance matters
# 112     M           long-term issues
# 113     A           physical changes
# 117     M              dental issues
# 118     A                 next steps
# 121     A        forwarded documents
# 122     A                  birthdate

# %%
# visualize the hierarchy and manually merge some topics
hierarchical_topics = topic_model.hierarchical_topics(sentences)
topic_model.visualize_hierarchy(hierarchical_topics=hierarchical_topics)
# Out:
# 100%|██████████| 121/121 [00:00<00:00, 131.55it/s]

# %%
topics_to_merge_5 = [[94, 97], #biologicals
[62, 118], #dose adjustment
[68, 79], # medication stock
[31, 71], # injections
[16, 23, 25, 30, 34, 35, 80, 104, 106, 114], # health updates
[2, 110, 39, 52, 29], # appointment
[0, 115], #bloodtest
[37, 49] # worries/concerns
]

topic_model.merge_topics(sentences, topics_to_merge_5)

# %%
topic_info_after_merge = topic_model.get_topic_info()

# %%
topic_info_after_merge["Name"].to_list()
# Out:
# ['-1_verstandigst_trant_aangenaam_zenuwachtig',
#  '0_bloed_prikken_ontlasting_test',
#  '1_afspraak_telefonisch_contact_bellen',
#  '2_pijn_buikpijn_toilet_last',
#  '3_bedankt_dank_reactie_snelle',
#  '4_medicatie_gebruik_tabletten_medicijnen',
#  '5_maanden_beter_maand_goed',
#  '6_huisarts_arts_dokter_mdl',
#  '7_recept_apotheek_nieuw_sturen',
#  '8_bekend_uitslag_calprotectine_waarde',
#  '9_hoor_graag_horen_verneem',
#  '10_vraag_vragen_vraagje_vragenlijst',
#  '11_voel_gevoel_voelt_voelen',
#  '12_corona_vaccinatie_vaccin_positief',
#  '13_formulieren_formulier_potje_papieren',
#  '14_mail_brief_adres_bericht',
#  '15_weten_laat_vertellen_laten',
#  '16_hoop_wacht_wachten_hopelijk',
#  '17_zorgen_volgende_begin_mailen',
#  '18_eten_eet_eetlust_drinken',
#  '19_humira_spuit_doorsturen_injecties',
#  '20_advies_adviseren_graag_overleggen',
#  '21_infuus_komende_echo_terug',
#  '22_weet_ermee_goed_houdt',
#  '23_crohn_ziekte_verklaring_humira',
#  '24_prima_helemaal_allemaal_zsm',
#  '25_ijzer_vitamine_ijzerinfuus_foliumzuur',
#  '26_mogelijk_mogelijkheid_manier_snel',
#  '27_stoppen_rekening_cortiment_doorgaan',
#  '28_idee_denk_dacht_meld',
#  '29_middag_zetten_aanstaande_morgen',
#  '30_morgen_vanmorgen_morgenvroeg_ophalen',
#  '31_jaar_vorig_jaren_leeftijd',
#  '32_dermatoloog_huid_dermatologie_gezicht',
#  '33_mee_hieraan_vreemd_valt',
#  '34_operatie_chirurg_ingepland_gevolgen',
#  '35_gelukkig_blij_gelukt_tevreden',
#  '36_vakantie_vertrek_terug_reizen',
#  '37_onderzoek_akkoord_melden_meedoen',
#  '38_pillen_voorraad_systeem_azathiopirine',
#  '39_duurt_ruim_natuurlijk_lang',
#  '40_ibd_ibdcoach_sessie_vragen',
#  '41_koorts_temperatuur_verhoging_koude',
#  '42_gaan_besproken_betekenen_houd',
#  '43_mri_scan_dunne_uitslag',
#  '44_zwangerschap_zwanger_gynaecoloog_medicijngebruik',
#  '45_fijne_feestdagen_jaarwisseling_gewenst',
#  '46_doorgeven_geven_volledig_oplossing',
#  '47_dosering_combinatie_dosis_laag',
#  '48_keuze_opvlamming_bang_gal',
#  '49_gegaan_mis_verkeerd_fout',
#  '50_biologicals_vermelden_originele_biological',
#  '51_ontvangen_heden_moviprep_bevestiging',
#  '52_zorginstelling_apotheek_ziekenhuis_naam',
#  '53_coloscopie_endoscopie_darmonderzoek_verhuisd',
#  '54_zie_vlak_zien_verkeerde',
#  '55_sorry_excuses_late_lastig',
#  '56_thuistesten_verwijzing_nieuwe_versturen',
#  '57_resultaten_hiervan_resultaat_vernemen',
#  '58_bedoeling_teveel_doorgegeven_vergoed',
#  '59_wilde_reden_dringend_denkt',
#  '60_veranderd_infusen_helft_interval',
#  '61_app_downloaden_telefoon_ondersteund',
#  '62_bespreken_spreken_persoonlijk_praten',
#  '63_beste_hey_betreft_bellen',
#  '64_gewicht_kilo_afgevallen_weeg',
#  '65_lactose_gestopt_komt_beangstigend',
#  '66_foto_bijgevoegd_bestand_bijgaand',
#  '67_nachten_duidelijk_kort_bestaat',
#  '68_probleem_toekomst_echt_problemen',
#  '69_stress_invloed_druk_rol',
#  '70_zekerheid_navragen_checken_vragenlijsten',
#  '71_ontsteking_galstenen_idd_aanvallen',
#  '72_vergeten_herinnering_herinneren_geheugen',
#  '73_gestart_entyvio_gevaccineerd_verhuizen',
#  '74_vandaar_gevraagd_griep_stuur',
#  '75_maagonderzoek_kloppen_vervolgafspraak_begrepen',
#  '76_ophalen_gang_fistel_bezig',
#  '77_druppels_has_are_kale',
#  '78_rechts_linker_steken_inspanning',
#  '79_hiervoor_situatie_ten_eraan',
#  '80_voldoende_hopende_hiermee_hoop',
#  '81_gaten_houden_hou_gehouden',
#  '82_helpen_hiermee_kastje_muur',
#  '83_optie_alternatief_momenten_mogelijkheden',
#  '84_aanhouden_verstandig_rest_vervolg',
#  '85_bekeken_lukken_betekend_geeft',
#  '86_risico_risicogroep_val_loop',
#  '87_urine_kweek_gecontroleerd_urinekweek',
#  '88_fax_faxnummer_vriendelijk_tel',
#  '89_energie_energielevel_moe_stukken',
#  '90_annuleren_meewerken_uitsluitsel_tijdstip',
#  '91_toestemming_toestemmingsformulier_geef_bijlage',
#  '92_verzekering_aanvraag_gegevens_levensverzekering',
#  '93_werkt_aangeef_traject_darmkrampen',
#  '94_wensen_allereerst_gezond_wens',
#  '95_bijwerking_bijwerkingen_infliximab_innemen',
#  '96_problemen_lange_hierdoor_persen',
#  '97_fysiek_opeens_heden_straks',
#  '98_team_ibd_binnenkort_matig',
#  '99_tandarts_tandvlees_kaakchirurg_mond',
#  '100_betekent_vervolgstappen_stappen_the',
#  '101_tegemoet_zie_reactie_graag',
#  '102_doorgestuurd_picoprep_gestuurd_zorginstelling',
#  '103_geboortedatum_geboorte_geb_geboren']

# %%
new_topic_summaries = [
    "outlier",  # -1_verstandigst_trant_aangenaam_zenuwachtig
    "blood/stool test",  # 0_bloed_prikken_ontlasting_test
    "appointment scheduling",  # 1_afspraak_telefonisch_contact_bellen
    "symptoms",  # 2_pijn_buikpijn_toilet_last
    "other",  # 3_bedankt_dank_reactie_snelle
    "medication use",  # 4_medicatie_gebruik_tabletten_medicijnen
    "health update",  # 5_maanden_beter_maand_goed
    "doctor/hospital visit",  # 6_huisarts_arts_dokter_mdl
    "prescription refill",  # 7_recept_apotheek_nieuw_sturen
    "calprotectin results",  # 8_bekend_uitslag_calprotectine_waarde
    "other",  # 9_hoor_graag_horen_verneem
    "questions/inquiries",  # 10_vraag_vragen_vraagje_vragenlijst
    "feelings",  # 11_voel_gevoel_voelt_voelen
    "COVID-19 vaccination",  # 12_corona_vaccinatie_vaccin_positief
    "forms/documents",  # 13_formulieren_formulier_potje_papieren
    "email/mail communication",  # 14_mail_brief_adres_bericht
    "other",  # 15_weten_laat_vertellen_laten
    "other",  # 16_hoop_wacht_wachten_hopelijk
    "worries",  # 17_zorgen_volgende_begin_mailen
    "eating/drinking habits",  # 18_eten_eet_eetlust_drinken
    "Humira injections",  # 19_humira_spuit_doorsturen_injecties
    "seeking advice",  # 20_advies_adviseren_graag_overleggen
    "infusion/echo follow-up",  # 21_infuus_komende_echo_terug
    "other",  # 22_weet_ermee_goed_houdt
    "Crohn's disease/Humira",  # 23_crohn_ziekte_verklaring_humira
    "other",  # 24_prima_helemaal_allemaal_zsm
    "iron/vitamin supplements",  # 25_ijzer_vitamine_ijzerinfuus_foliumzuur
    "possibilities/options",  # 26_mogelijk_mogelijkheid_manier_snel
    "medication continuation",  # 27_stoppen_rekening_cortiment_doorgaan
    "thoughts/ideas",  # 28_idee_denk_dacht_meld
    "other",  # 30_morgen_vanmorgen_morgenvroeg_ophalen
    "age/years",  # 31_jaar_vorig_jaren_leeftijd
    "dermatology/skin issues",  # 32_dermatoloog_huid_dermatologie_gezicht
    "confusion/concerns",  # 33_mee_hieraan_vreemd_valt
    "surgery/operation",  # 34_operatie_chirurg_ingepland_gevolgen
    "happiness/satisfaction",  # 35_gelukkig_blij_gelukt_tevreden
    "travel/vacation",  # 36_vakantie_vertrek_terug_reizen
    "research participation",  # 37_onderzoek_akkoord_melden_meedoen
    "medication stock/system",  # 38_pillen_voorraad_systeem_azathiopirine
    "waiting time",  # 39_duurt_ruim_natuurlijk_lang
    "other",  # 40_ibd_ibdcoach_sessie_vragen
    "fever/temperature",  # 41_koorts_temperatuur_verhoging_koude
    "discussions/meaning",  # 42_gaan_besproken_betekenen_houd
    "MRI scan results",  # 43_mri_scan_dunne_uitslag
    "pregnancy/medication",  # 44_zwangerschap_zwanger_gynaecoloog_medicijngebruik
    "other",  # 45_fijne_feestdagen_jaarwisseling_gewenst
    "information/communication",  # 46_doorgeven_geven_volledig_oplossing
    "dosage adjustments",  # 47_dosering_combinatie_dosis_laag
    "flare-up",  # 48_keuze_opvlamming_bang_gal
    "mistakes/issues",  # 49_gegaan_mis_verkeerd_fout
    "biological medication",  # 50_biologicals_vermelden_originele_biological
    "receipt confirmation",  # 51_ontvangen_heden_moviprep_bevestiging
    "healthcare facility",  # 52_zorginstelling_apotheek_ziekenhuis_naam
    "colonoscopy/darmonderzoek",  # 53_coloscopie_endoscopie_darmonderzoek_verhuisd
    "other",  # 54_zie_vlak_zien_verkeerde
    "other",  # 55_sorry_excuses_late_lastig
    "home tests/referrals",  # 56_thuistesten_verwijzing_nieuwe_versturen
    "results discussion",  # 57_resultaten_hiervan_resultaat_vernemen
    "goal",  # 58_bedoeling_teveel_doorgegeven_vergoed
    "urgent requests",  # 59_wilde_reden_dringend_denkt
    "infusion changes",  # 60_veranderd_infusen_helft_interval
    "app download",  # 61_app_downloaden_telefoon_ondersteund
    "discussions",  # 62_bespreken_spreken_persoonlijk_praten
    "other",  # 63_beste_hey_betreft_bellen
    "weight changes",  # 64_gewicht_kilo_afgevallen_weeg
    "lactose intolerance",  # 65_lactose_gestopt_komt_beangstigend
    "attached files",  # 66_foto_bijgevoegd_bestand_bijgaand
    "sleep issues",  # 67_nachten_duidelijk_kort_bestaat
    "future problems",  # 68_probleem_toekomst_echt_problemen
    "stress impact",  # 69_stress_invloed_druk_rol
    "confirmation/questions",  # 70_zekerheid_navragen_checken_vragenlijsten
    "inflammation/gallstones",  # 71_ontsteking_galstenen_idd_aanvallen
    "forgetfulness",  # 72_vergeten_herinnering_herinneren_geheugen
    "Entyvio start/vaccination",  # 73_gestart_entyvio_gevaccineerd_verhuizen
    "inquires",  # 74_vandaar_gevraagd_griep_stuur
    "stomach examination",  # 75_maagonderzoek_kloppen_vervolgafspraak_begrepen
    "fistula issues",  # 76_ophalen_gang_fistel_bezig
    "drops/medication",  # 77_druppels_has_are_kale
    "pain locations",  # 78_rechts_linker_steken_inspanning
    "other",  # 79_hiervoor_situatie_ten_eraan
    "other",  # 80_voldoende_hopende_hiermee_hoop
    "other",  # 81_gaten_houden_hou_gehouden
    "assistance",  # 82_helpen_hiermee_kastje_muur
    "options/alternatives",  # 83_optie_alternatief_momenten_mogelijkheden
    "continuation/rest",  # 84_aanhouden_verstandig_rest_vervolg
    "other",  # 85_bekeken_lukken_betekend_geeft
    "risk factors",  # 86_risico_risicogroep_val_loop
    "urine test",  # 87_urine_kweek_gecontroleerd_urinekweek
    "fax communication",  # 88_fax_faxnummer_vriendelijk_tel
    "energy levels",  # 89_energie_energielevel_moe_stukken
    "cancellation/cooperation",  # 90_annuleren_meewerken_uitsluitsel_tijdstip
    "consent forms",  # 91_toestemming_toestemmingsformulier_geef_bijlage
    "insurance matters",  # 92_verzekering_aanvraag_gegevens_levensverzekering
    "treatment effectiveness",  # 93_werkt_aangeef_traject_darmkrampen
    "other",  # 94_wensen_allereerst_gezond_wens
    "medication side effects",  # 95_bijwerking_bijwerkingen_infliximab_innemen
    "long-term issues",  # 96_problemen_lange_hierdoor_persen
    "physical changes",  # 97_fysiek_opeens_heden_straks
    "other",  # 98_team_ibd_binnenkort_matig
    "dental issues",  # 99_tandarts_tandvlees_kaakchirurg_mond
    "next steps",  # 100_betekent_vervolgstappen_stappen_the
    "other",  # 101_tegemoet_zie_reactie_graag
    "forwarded documents",  # 102_doorgestuurd_picoprep_gestuurd_zorginstelling
    "birthdate",  # 103_geboortedatum_geboorte_geb_geboren
]

# %%
new_labels = [
    "A",  # -1_verstandigst_trant_aangenaam_zenuwachtig - 
    "A",  # 0_bloed_prikken_ontlasting_test - 
    "A",  # 1_afspraak_telefonisch_contact_bellen - 
    "M",  # 2_pijn_buikpijn_toilet_last - 
    "A",  # 3_bedankt_dank_reactie_snelle - 
    "M",  # 4_medicatie_gebruik_tabletten_medicijnen -
    "A",  # 5_maanden_beter_maand_goed - 
    "M",  # 6_huisarts_arts_dokter_mdl - 
    "A",  # 7_recept_apotheek_nieuw_sturen - 
    "A",  # 8_bekend_uitslag_calprotectine_waarde - 
    "A",  # 9_hoor_graag_horen_verneem - 
    "A",  # 10_vraag_vragen_vraagje_vragenlijst  -
    "M",  # 11_voel_gevoel_voelt_voelen -
    "M",  # 12_corona_vaccinatie_vaccin_positief - 
    "A",  # 13_formulieren_formulier_potje_papieren - 
    "A",  # 14_mail_brief_adres_bericht - 
    "A",  # 15_weten_laat_vertellen_laten -
    "A",  # 16_hoop_wacht_wachten_hopelijk - 
    "M",  # 17_zorgen_volgende_begin_mailen - 
    "M",  # 18_eten_eet_eetlust_drinken - 
    "M",  # 19_humira_spuit_doorsturen_injecties - 
    "M",  # 20_advies_adviseren_graag_overleggen - 
    "A",  # 21_infuus_komende_echo_terug - # labeled "A" as it is likely talking about appointment of infusion & echo
    "A",  # 22_weet_ermee_goed_houdt -
    "M",  # 23_crohn_ziekte_verklaring_humira - 
    "A",  # 24_prima_helemaal_allemaal_zsm -
    "M",  # 25_ijzer_vitamine_ijzerinfuus_foliumzuur - 
    "A",  # 26_mogelijk_mogelijkheid_manier_snel -
    "M",  # 27_stoppen_rekening_cortiment_doorgaan -
    "A",  # 28_idee_denk_dacht_meld - 
    "A",  # 29_morgen_vanmorgen_morgenvroeg_ophalen -
    "M",  # 30_jaar_vorig_jaren_leeftijd - 
    "M",  # 31_dermatoloog_huid_dermatologie_gezicht - 
    "M",  # 32_mee_hieraan_vreemd_valt -
    "M",  # 33_operatie_chirurg_ingepland_gevolgen - 
    "M",  # 34_gelukkig_blij_gelukt_tevreden - 
    "A",  # 35_vakantie_vertrek_terug_reizen -
    "A",  # 36_onderzoek_akkoord_melden_meedoen - 
    "M",  # 37_pillen_voorraad_systeem_azathiopirine - 
    "A",  # 38_duurt_ruim_natuurlijk_lang - 
    "M",  # 39_ibd_ibdcoach_sessie_vragen - 
    "M",  # 40_koorts_temperatuur_verhoging_koude - 
    "M",  # 41_gaan_besproken_betekenen_houd -
    "M",  # 42_mri_scan_dunne_uitslag - 
    "M",  # 43_zwangerschap_zwanger_gynaecoloog_medicijngebruik - 
    "A",  # 44_fijne_feestdagen_jaarwisseling_gewenst - 
    "A",  # 45_doorgeven_geven_volledig_oplossing - 
    "M",  # 46_dosering_combinatie_dosis_laag -
    "M",  # 47_keuze_opvlamming_bang_gal - 
    "A",  # 48_gegaan_mis_verkeerd_fout - 
    "M",  # 49_biologicals_vermelden_originele_biological
    "A",  # 50_ontvangen_heden_moviprep_bevestiging - 
    "A",  # 51_zorginstelling_apotheek_ziekenhuis_naam-
    "M",  # 52_coloscopie_endoscopie_darmonderzoek_verhuisd
    "A",  # 53_zie_vlak_zien_verkeerde -
    "A",  # 54_sorry_excuses_late_lastig - 
    "A",  # 55_thuistesten_verwijzing_nieuwe_versturen - 
    "A",  # 57_resultaten_hiervan_resultaat_vernemen  -
    "M",  # 58_bedoeling_teveel_doorgegeven_vergoed - 
    "A",  # 59_wilde_reden_dringend_denkt -
    "M",  # 60_veranderd_infusen_helft_interval - 
    "A",  # 61_app_downloaden_telefoon_ondersteund -
    "A",  # 62_bespreken_spreken_persoonlijk_praten - 
    "A",  # 63_beste_hey_betreft_bellen -
    "M",  # 64_gewicht_kilo_afgevallen_weeg - 
    "M",  # 65_lactose_gestopt_komt_beangstigend - 
    "A",  # 66_foto_bijgevoegd_bestand_bijgaand - 
    "M",  # 67_nachten_duidelijk_kort_bestaat -
    "M",  # 68_probleem_toekomst_echt_problemen - 
    "M",  # 69_stress_invloed_druk_rol - 
    "M",  # 70_zekerheid_navragen_checken_vragenlijsten - 
    "M",  # 71_ontsteking_galstenen_idd_aanvallen - 
    "A",  # 72_vergeten_herinnering_herinneren_geheugen - 
    "M",  # 73_gestart_entyvio_gevaccineerd_verhuizen -
    "M",  # 74_vandaar_gevraagd_griep_stuur - 
    "A",  # 75_maagonderzoek_kloppen_vervolgafspraak_begrepen - 
    "M",  # 76_ophalen_gang_fistel_bezig - 
    "M",  # 77_druppels_has_are_kale - 
    "M",  # 78_rechts_linker_steken_inspanning - 
    "A",  # 79_hiervoor_situatie_ten_eraan - 
    "A",  # 80_voldoende_hopende_hiermee_hoop - 
    "A",  # 81_gaten_houden_hou_gehouden -
    "M",  # 82_helpen_hiermee_kastje_muur -
    "A",  # 83_optie_alternatief_momenten_mogelijkheden
    "A",  # 84_aanhouden_verstandig_rest_vervolg
    "A",  # 85_bekeken_lukken_betekend_geeft
    "M",  # 86_risico_risicogroep_val_loop
    "M",  # 87_urine_kweek_gecontroleerd_urinekweek
    "A",  # 88_fax_faxnummer_vriendelijk_tel
    "M",  # 89_energie_energielevel_moe_stukken
    "A",  # 90_annuleren_meewerken_uitsluitsel_tijdstip
    "A",  # 91_toestemming_toestemmingsformulier_geef_bijlage
    "A",  # 92_verzekering_aanvraag_gegevens_levensverzekering
    "M",  # 93_werkt_aangeef_traject_darmkrampen
    "A",  # 94_wensen_allereerst_gezond_wens
    "M",  # 95_bijwerking_bijwerkingen_infliximab_innemen
    "M",  # 96_problemen_lange_hierdoor_persen
    "A",  # 97_fysiek_opeens_heden_straks
    "A",  # 97_team_ibd_binnenkort_matig
    "M",  # 98_tandarts_tandvlees_kaakchirurg_mond
    "M",  # 99_betekent_vervolgstappen_stappen_the
    "A",  # 100_tegemoet_zie_reactie_graag
    "A",  # 101_doorgestuurd_picoprep_gestuurd_zorginstelling
    "A",  # 102_geboortedatum_geboorte_geb_geboren
]

# %%
len(topic_info_after_merge)
# Out:
# 104

# %%
labeled_topic_info_merged = topic_info_after_merge
labeled_topic_info_merged.head()
# Out:
#    Topic  Count                                         Name  \
# 0     -1    259  -1_verstandigst_trant_aangenaam_zenuwachtig
# 1      0   4854              0_bloed_prikken_ontlasting_test
# 2      1   4109        1_afspraak_telefonisch_contact_bellen
# 3      2   3651                  2_pijn_buikpijn_toilet_last
# 4      3   3130                3_bedankt_dank_reactie_snelle
#
#                                       Representation  \
# 0  [verstandigst, trant, aangenaam, zenuwachtig, ...
# 1  [bloed, prikken, ontlasting, test, laten, slij...
# 2  [afspraak, telefonisch, contact, bellen, vanda...
# 3  [pijn, buikpijn, toilet, last, keer, buik, kla...
# 4  [bedankt, dank, reactie, snelle, alvast, beric...
#
#                                  Representative_Docs
# 0  [Of iets in die trant., Wat is voor mij het ve...
# 1  [Ik heb inderdaad bloed laten prikken in het ....
# 2  [Is het mogelijk dat deze afspraak telefonisch...
# 3  [moet nog een afspraak maken bij de dockter he...
# 4  [Dank alvast voor de reactie!, Alvast dank voo...

# %%
final_meaningful_topic_info = labeled_topic_info_merged[labeled_topic_info_merged["Summary"] != "other"][1:]
final_meaningful_topic_info
# Out:
#      Topic  Count                                               Name  \
# 1        0   4854                    0_bloed_prikken_ontlasting_test
# 2        1   4109              1_afspraak_telefonisch_contact_bellen
# 3        2   3651                        2_pijn_buikpijn_toilet_last
# 5        4   2298           4_medicatie_gebruik_tabletten_medicijnen
# 6        5   1982                         5_maanden_beter_maand_goed
# ..     ...    ...                                                ...
# 97      96     50                      96_fysiek_opeens_heden_straks
# 99      98     45             98_tandarts_tandvlees_kaakchirurg_mond
# 100     99     42             99_betekent_vervolgstappen_stappen_the
# 102    101     36  101_doorgestuurd_picoprep_gestuurd_zorginstelling
# 103    102     34             102_geboortedatum_geboorte_geb_geboren
#
#                                                                                                    Representation  \
# 1             [bloed, prikken, ontlasting, test, laten, slijm, bloedprikken, ingeleverd, geprikt, bloeduitslagen]
# 2             [afspraak, telefonisch, contact, bellen, vandaag, poli, proberen, bereikbaar, gepland, antibiotica]
# 3                                    [pijn, buikpijn, toilet, last, keer, buik, klachten, normaal, soms, diarree]
# 5                [medicatie, gebruik, tabletten, medicijnen, gebruiken, daags, pentasa, tablet, apotheek, recept]
# 6                        [maanden, beter, maand, goed, gaat, gehoord, controle, periodieke, ziekenhuis, vernomen]
# ..                                                                                                            ...
# 97                  [fysiek, opeens, heden, straks, beantwoord, aangegeven, aangevraagd, reactie, nml, ontvangen]
# 99                      [tandarts, tandvlees, kaakchirurg, mond, kies, verwezen, tanden, acute, ontsteking, tong]
# 100       [betekent, vervolgstappen, stappen, the, vervolg, vervolgstap, leukocyten, rapportage, attach, mriscan]
# 102  [doorgestuurd, picoprep, gestuurd, zorginstelling, doorgezet, derrein, recept, apotheek, gram, hartbewaking]
# 103                    [geboortedatum, geboorte, geb, geboren, hpm, afschaffen, inlevering, welkom, datums, woog]
#
#                                                                                                                                                                        Representative_Docs  \
# 1                                               [Ik heb inderdaad bloed laten prikken in het ., en ,  Ik heb woensdag bloed laten prikken., Ik heb afgelopen vrijdag bloed laten prikken.]
# 2                             [Is het mogelijk dat deze afspraak telefonisch word?, Ik zou graag even telefonisch contact hebben!, Ik heb vandaag ook nog telefonisch contact gehad met .]
# 3                                                    [moet nog een afspraak maken bij de dockter heb veel pijn .vink, Ik heb veel pijn in mijn buik., Dit is ondoenlijk van wege de pijn!]
# 5           [Zou dit iets met medicatie te maken kunnen hebben?, Op het recept staat nog steeds 1 x daags 2 tabletten ipv 1 x daags 3 tabletten., Welke medicijnen moet ik nu gebruiken ?]
# 6                                                                                                                        [Ja, het gaat beter., Gaat wat beter nu., Het gaat nu wat beter.]
# ..                                                                                                                                                                                     ...
# 97     [Tot op heden heb ik geen reactie mogen ontvangen., Dit is reeds eerder aangevraagd maar tot op heden nog geen reactie., Tot op vandaag nog geen reactie van de fysiek  ontvangen.]
# 99                               [Morgen ga ik hiervoor naar de tandarts., Afspraak met tandarts is inmiddels gemaakt., 2 juni a.s. krijg ik een wortelkanaalbehandeling bij de tandarts.]
# 100                                                                                                                           [Wat betekent dit?, Wat betekent dit nu?, Wat betekent dit?]
# 102  [Dit mag doorgestuurd worden naar de [APOTHEEK] in ., Dit mag doorgestuurd worden naar de [APOTHEEK] in ., Het recept van de picoprep zou zijn doorgestuurd naar [APOTHEEK]derrein .]
# 103                                                                                                                       [Geboortedatum is, De geboortedatum is ., De geboortedatum is .]
#
#     Label                 Summary
# 1       M        blood/stool test
# 2       A  appointment scheduling
# 3       M                symptoms
# 5       M          medication use
# 6       M           health update
# ..    ...                     ...
# 97      A        physical changes
# 99      M           dental issues
# 100     A              next steps
# 102     A     forwarded documents
# 103     A               birthdate
#
# [84 rows x 7 columns]

# %%
final_meaningful_topic_info.to_excel("/workspace/persistent/mijnidbcoachnlp/data/results/final_meaningful_topics.xlsx", index=False)

# %%
topic_model.save("/workspace/persistent/mijnidbcoachnlp/saved_models/final_st_model", serialization="pytorch", save_ctfidf=True, save_embedding_model=embedding_model)

# %% [markdown]
# ## 4. Visualize the meaningful topics

# %%
import pandas as pd
final_meaningful_topic_info = pd.read_excel("/workspace/persistent/mijnidbcoachnlp/data/results/final_meaningful_topics.xlsx")

# %%
# %matplotlib inline
# %matplotlib widget

# %%
df = final_meaningful_topic_info[["Count", "Summary", "Label"]]

# %%
df = final_meaningful_topic_info[["Count", "Summary", "Label"]]
pivot_df = df.pivot(index='Summary', columns='Label', values='Count').fillna(0)
import pandas as pd
import matplotlib.pyplot as plt

# Add a total count column, which is the sum of counts for each label across both categories
pivot_df['Total'] = pivot_df['A'] + pivot_df['M']

# Sort by the 'Total' column in descending order (highest to lowest)
pivot_df = pivot_df.sort_values(by='Total', ascending=False).head(20)

# Create a figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

# Plot Category M on the left side of the plot (negative values for left-side bars)
bars_m = ax.barh(pivot_df.index, pivot_df['M'], color='#A8D5BA', label='Medical', height=0.6)  # Softer green

# Plot Category A on the right side of the plot (positive values for right-side bars)
bars_a = ax.barh(pivot_df.index, pivot_df['A'], color='#A7C7E7', label='Non-Medical', height=0.6)  # Softer blue

# Add labels and title
ax.set_xlabel('Count')
ax.set_title('Sentence-level topic distribution')
ax.legend()

# Invert y-axis so the highest values are at the top
ax.invert_yaxis()

plt.savefig("/workspace/persistent/mijnidbcoachnlp/data/results/figure1.png")

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt


topic_info = pd.DataFrame(df)

# Create a dictionary where keys are the topic labels and values are their counts
word_freq = dict(zip(topic_info['Summary'], topic_info['Count']))

# Generate the word cloud using the dictionary
wordcloud = WordCloud(width=1200, height=400, background_color='white').generate_from_frequencies(word_freq)

# Plot the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.savefig("/workspace/persistent/mijnidbcoachnlp/data/results/figure2.png")

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Pivot the data to have 'A' and 'M' in separate columns
pivot_df = df.pivot(index='Summary', columns='Label', values='Count').fillna(0)

# Select the top 10 topics for each category, sorted in descending order
top_10_M = pivot_df[['M']].sort_values(by='M', ascending=False).head(10)
top_10_A = pivot_df[['A']].sort_values(by='A', ascending=False).head(10)

# Create figure and axes for two plots
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# Plot Top 10 Medical (M)
axes[0].barh(top_10_M.index[::-1], top_10_M['M'][::-1], color='#A8D5BA', label='Medical')  # Reverse order
axes[0].set_xlabel('Count')
axes[0].set_title('Top 10 Medical Topics', fontsize=20)
axes[0].tick_params(axis='y', labelsize=20)  # Set y-axis tick label font size
axes[0].tick_params(axis='x', labelsize=14)  # Set y-axis tick label font size


# Plot Top 10 Administrative (A)
axes[1].barh(top_10_A.index[::-1], top_10_A['A'][::-1], color='#A7C7E7', label='Non_Medical')  # Reverse order
axes[1].set_xlabel('Count')
axes[1].set_title('Top 10 Non-Medical Topics', fontsize=20)
axes[1].tick_params(axis='y', labelsize=20)  # Set y-axis tick label font size
axes[1].tick_params(axis='x', labelsize=14)  # Set y-axis tick label font size


# Adjust layout and save the figure
plt.tight_layout()
plt.savefig("/workspace/persistent/mijnidbcoachnlp/data/results/plot_sep.png")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
df_m = final_meaningful_topic_info[final_meaningful_topic_info["Label"] == "M"]
df_a = final_meaningful_topic_info[final_meaningful_topic_info["Label"] == "a"]

# %%
annotated_df_new = pd.read_excel("/workspace/persistent/mijnidbcoachnlp/data/analysis_data/new_annotated_df_lg.xlsx")
annotated_df_new.head()
# Out:
#    Message_ID  \
# 0           3
# 1           3
# 2           3
# 3           3
# 4           3
#
#                                                                                                     Sentence  \
# 0  Ik ben 2 weken geleden met spoed opgenomen in het [PERSOON] in [LOCATIE] met verdenking van hartklachten.
# 1                  Ik kreeg acuut een pijnlijke druk op de borst, schouderbladen, uitstralend naar de armen.
# 2                                                                          Het begon 1 uur na het avondeten.
# 3                                                Ik had al de hele dag migraine, had dus ook weinig gegeten.
# 4                    Ik werd heel erg misselijk, braakneigingen, duizelig en oprispingen.En vreselijke pijn.
#
#                                                                               Clean_Sentence  \
# 0    Ik ben 2 weken geleden met spoed opgenomen in het  in  met verdenking van hartklachten.
# 1  Ik kreeg acuut een pijnlijke druk op de borst, schouderbladen, uitstralend naar de armen.
# 2                                                          Het begon 1 uur na het avondeten.
# 3                                Ik had al de hele dag migraine, had dus ook weinig gegeten.
# 4    Ik werd heel erg misselijk, braakneigingen, duizelig en oprispingen.En vreselijke pijn.
#
#    Sentence_ID  \
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
#
#                                                                               Translated_Sentence  \
# 0  I was rushed into the [PRESSION] two weeks ago in [LOCATION] with suspicion of heart problems.
# 1    I was acutely under a painful pressure on the chest, shoulder blades, radiating to the arms.
# 2                                                                 It started 1 hour after dinner.
# 3                                                I had migraines all day, so I hadn't eaten much.
# 4                       I got very nauseous, vomiting, dizzy and rejuvenating, and terrible pain.
#
#   Manual_Category
# 0               M
# 1               M
# 2               M
# 3               M
# 4               M

# %%
# now we need to move the labels of the topic_info to doc_info
# Now perform the merge 
annotated_doc_info = pd.merge( # merging the small annotated set with the document info
    annotated_df_new,
    doc_info[['Sentence_ID', 'Topic', 'Top_n_words']], # notice that we only choose these 3 columns of the doc info df
    on='Sentence_ID',
    how='left'
)

annotated_doc_info.head()
# Out:
#    Message_ID  \
# 0           3
# 1           3
# 2           3
# 3           3
# 4           3
#
#                                                                                                     Sentence  \
# 0  Ik ben 2 weken geleden met spoed opgenomen in het [PERSOON] in [LOCATIE] met verdenking van hartklachten.
# 1                  Ik kreeg acuut een pijnlijke druk op de borst, schouderbladen, uitstralend naar de armen.
# 2                                                                          Het begon 1 uur na het avondeten.
# 3                                                Ik had al de hele dag migraine, had dus ook weinig gegeten.
# 4                    Ik werd heel erg misselijk, braakneigingen, duizelig en oprispingen.En vreselijke pijn.
#
#                                                                               Clean_Sentence  \
# 0    Ik ben 2 weken geleden met spoed opgenomen in het  in  met verdenking van hartklachten.
# 1  Ik kreeg acuut een pijnlijke druk op de borst, schouderbladen, uitstralend naar de armen.
# 2                                                          Het begon 1 uur na het avondeten.
# 3                                Ik had al de hele dag migraine, had dus ook weinig gegeten.
# 4    Ik werd heel erg misselijk, braakneigingen, duizelig en oprispingen.En vreselijke pijn.
#
#    Sentence_ID  \
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
#
#                                                                               Translated_Sentence  \
# 0  I was rushed into the [PRESSION] two weeks ago in [LOCATION] with suspicion of heart problems.
# 1    I was acutely under a painful pressure on the chest, shoulder blades, radiating to the arms.
# 2                                                                 It started 1 hour after dinner.
# 3                                                I had migraines all day, so I hadn't eaten much.
# 4                       I got very nauseous, vomiting, dizzy and rejuvenating, and terrible pain.
#
#   Manual_Category  Topic  \
# 0               M     45
# 1               M      1
# 2               M      1
# 3               M      1
# 4               M      1
#
#                                                                                      Top_n_words
# 0  duurt - ruim - natuurlijk - lang - hoesten - duurde - moedeloos - toegenomen - vroeger - zorg
# 1            pijn - buikpijn - toilet - last - keer - buik - klachten - normaal - soms - diarree
# 2            pijn - buikpijn - toilet - last - keer - buik - klachten - normaal - soms - diarree
# 3            pijn - buikpijn - toilet - last - keer - buik - klachten - normaal - soms - diarree
# 4            pijn - buikpijn - toilet - last - keer - buik - klachten - normaal - soms - diarree

# %%
# now merge the above dataframe with the labeled topic info frame
annotated_doc_info = pd.merge(
    annotated_doc_info,
    topic_info[['Topic', 'Label']],
    on='Topic',
    how='left'
)
annotated_doc_info.head()
# Out:
#    Message_ID  \
# 0           3
# 1           3
# 2           3
# 3           3
# 4           3
#
#                                                                                                     Sentence  \
# 0  Ik ben 2 weken geleden met spoed opgenomen in het [PERSOON] in [LOCATIE] met verdenking van hartklachten.
# 1                  Ik kreeg acuut een pijnlijke druk op de borst, schouderbladen, uitstralend naar de armen.
# 2                                                                          Het begon 1 uur na het avondeten.
# 3                                                Ik had al de hele dag migraine, had dus ook weinig gegeten.
# 4                    Ik werd heel erg misselijk, braakneigingen, duizelig en oprispingen.En vreselijke pijn.
#
#                                                                               Clean_Sentence  \
# 0    Ik ben 2 weken geleden met spoed opgenomen in het  in  met verdenking van hartklachten.
# 1  Ik kreeg acuut een pijnlijke druk op de borst, schouderbladen, uitstralend naar de armen.
# 2                                                          Het begon 1 uur na het avondeten.
# 3                                Ik had al de hele dag migraine, had dus ook weinig gegeten.
# 4    Ik werd heel erg misselijk, braakneigingen, duizelig en oprispingen.En vreselijke pijn.
#
#    Sentence_ID  \
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
#
#                                                                               Translated_Sentence  \
# 0  I was rushed into the [PRESSION] two weeks ago in [LOCATION] with suspicion of heart problems.
# 1    I was acutely under a painful pressure on the chest, shoulder blades, radiating to the arms.
# 2                                                                 It started 1 hour after dinner.
# 3                                                I had migraines all day, so I hadn't eaten much.
# 4                       I got very nauseous, vomiting, dizzy and rejuvenating, and terrible pain.
#
#   Manual_Category  Topic  \
# 0               M     45
# 1               M      1
# 2               M      1
# 3               M      1
# 4               M      1
#
#                                                                                      Top_n_words  \
# 0  duurt - ruim - natuurlijk - lang - hoesten - duurde - moedeloos - toegenomen - vroeger - zorg
# 1            pijn - buikpijn - toilet - last - keer - buik - klachten - normaal - soms - diarree
# 2            pijn - buikpijn - toilet - last - keer - buik - klachten - normaal - soms - diarree
# 3            pijn - buikpijn - toilet - last - keer - buik - klachten - normaal - soms - diarree
# 4            pijn - buikpijn - toilet - last - keer - buik - klachten - normaal - soms - diarree
#
#   Label
# 0     M
# 1     M
# 2     M
# 3     M
# 4     M

# %%
annotated_doc_info[500:600]
# Out:
#      Message_ID  \
# 500         323
# 501         323
# 502         325
# 503         325
# 504         325
# ..          ...
# 595         400
# 596         400
# 597         400
# 598         400
# 599         400
#
#                                                                                                                                                        Sentence  \
# 500                                                                     Ik las trouwens dat ik door de contrast vloeistof de moedermelk die dag moet weggooien.
# 501                                                                                                        Is dat alleen die eerste dag of ook de dag erna nog?
# 502                                                                                                        Afgelopen week een voorhoofdsholte ontsteking gehad.
# 503                                                           Sindsdien alleen maar waterige ontlasting ik voel me heel slap en ben ontzettend veel afgevallen.
# 504                                                                                                              Graag wat advies wat ik nu het beste kan doen.
# ..                                                                                                                                                          ...
# 595                                                                              Verder heb ik vorige week op een nacht veel krampen in mijn maag en rug gehad.
# 596                                                                                                                                Hier kon ik niet van slapen.
# 597  Dit heb ik eerder nog niet zo lang geleden nog een keer precies hetzelfde gehad, maar toen begon het s'ochtends en had ik het de hele dag, avond en nacht.
# 598                                                              Waarschijnlijk had ik de dag voordat het begon bij beide keren te pittig of te vettig gegeten.
# 599                                                                      Ik wilde het toch even aangeven, omdat ik het nu al twee keer achter elkaar gehad heb.
#
#                                                                                                                                                  Clean_Sentence  \
# 500                                                                     Ik las trouwens dat ik door de contrast vloeistof de moedermelk die dag moet weggooien.
# 501                                                                                                        Is dat alleen die eerste dag of ook de dag erna nog?
# 502                                                                                                        Afgelopen week een voorhoofdsholte ontsteking gehad.
# 503                                                           Sindsdien alleen maar waterige ontlasting ik voel me heel slap en ben ontzettend veel afgevallen.
# 504                                                                                                              Graag wat advies wat ik nu het beste kan doen.
# ..                                                                                                                                                          ...
# 595                                                                              Verder heb ik vorige week op een nacht veel krampen in mijn maag en rug gehad.
# 596                                                                                                                                  er kon ik niet van slapen.
# 597  Dit heb ik eerder nog niet zo lang geleden nog een keer precies hetzelfde gehad, maar toen begon het s'ochtends en had ik het de hele dag, avond en nacht.
# 598                                                              Waarschijnlijk had ik de dag voordat het begon bij beide keren te pittig of te vettig gegeten.
# 599                                                                      Ik wilde het toch even aangeven, omdat ik het nu al twee keer achter elkaar gehad heb.
#
#      Sentence_ID  \
# 500          510
# 501          511
# 502          512
# 503          513
# 504          514
# ..           ...
# 595          605
# 596          606
# 597          607
# 598          608
# 599          609
#
#                                                                                                               Translated_Sentence  \
# 500                                By the way, I read that because of the contrast liquid I must throw away breast milk that day.
# 501                                                                                   Is that just the first day or the next day?
# 502                                                                                                Last week, he had a sinusitis.
# 503                                                                    Since then I feel very weak and have lost a lot of weight.
# 504                                                                            I'd like some advice that I can do best right now.
# ..                                                                                                                            ...
# 595                                                          Furthermore, last week I had a lot of cramps in my stomach and back.
# 596                                                                                                    This didn't help me sleep.
# 597  I had the exact same thing not so long ago before, but then it started in the morning and I had it all day, night and night.
# 598                                         Probably I had eaten too spicy or too greasy the day before it started at both times.
# 599                                                     I wanted to report it anyway, because I've already had it twice in a row.
#
#     Manual_Category  Topic  \
# 500               M     83
# 501               M      1
# 502               M      0
# 503               M     10
# 504               M     70
# ..              ...    ...
# 595               M      1
# 596               M      1
# 597               M      1
# 598               M      1
# 599               A     68
#
#                                                                                                          Top_n_words  \
# 500     gestart - entyvio - gevaccineerd - verhuizen - afspraken - trouwens - gemaakt - uitgerekend - gepaard - kwam
# 501                              pijn - buikpijn - toilet - last - keer - buik - klachten - normaal - soms - diarree
# 502       bloed - prikken - ontlasting - test - laten - slijm - bloedprikken - ingeleverd - bloeduitslagen - geprikt
# 503                                voel - gevoel - voelt - voelen - moe - gevoelig - voelde - lekker - goed - slecht
# 504  beste - hey - betreft - aandoen - voorbereiden - plichten - picoprepp - aangetoond - onafhankelijkheid - middel
# ..                                                                                                               ...
# 595                              pijn - buikpijn - toilet - last - keer - buik - klachten - normaal - soms - diarree
# 596                              pijn - buikpijn - toilet - last - keer - buik - klachten - normaal - soms - diarree
# 597                              pijn - buikpijn - toilet - last - keer - buik - klachten - normaal - soms - diarree
# 598                              pijn - buikpijn - toilet - last - keer - buik - klachten - normaal - soms - diarree
# 599                      voorraad - doosje - doos - stuks - zakjes - elkaar - aangeven - pilletjes - buisjes - volle
#
#     Label
# 500     M
# 501     M
# 502     A
# 503     M
# 504     A
# ..    ...
# 595     M
# 596     M
# 597     M
# 598     M
# 599     A
#
# [100 rows x 9 columns]

# %%
accuracy = (annotated_doc_info["Label"] == annotated_doc_info["Manual_Category"]).mean()

print(f"Accuracy: {accuracy:.2%}")
# Out:
# Accuracy: 69.22%

# %%
# Accuracy for "M"
m_accuracy = (annotated_doc_info[annotated_doc_info["Label"] == "M"]["Manual_Category"] == "M").mean()

# Accuracy for "A"
a_accuracy = (annotated_doc_info[annotated_doc_info["Label"] == "A"]["Manual_Category"] == "A").mean()

print(f"Accuracy for M: {m_accuracy:.2%}")
print(f"Accuracy for A: {a_accuracy:.2%}")
# Out:
# Accuracy for M: 61.04%
# Accuracy for A: 74.38%

# %%
topic_info
# Out:
#      Topic  Count                                               Name  \
# 0       -1    259        -1_verstandigst_trant_aangenaam_zenuwachtig
# 1        0   4806                    0_bloed_prikken_ontlasting_test
# 2        1   3651                        1_pijn_buikpijn_toilet_last
# 3        2   3416              2_afspraak_telefonisch_contact_bellen
# 4        3   3130                      3_bedankt_dank_reactie_snelle
# ..     ...    ...                                                ...
# 118    117     42            117_betekent_vervolgstappen_stappen_the
# 119    118     39          118_aangepast_baat_beclometason_tabletjes
# 120    119     37                     119_tegemoet_zie_reactie_graag
# 121    120     36  120_doorgestuurd_picoprep_gestuurd_zorginstelling
# 122    121     34             121_geboortedatum_geboorte_geb_geboren
#
#                                                                                                         Representation  \
# 0         [verstandigst, trant, aangenaam, zenuwachtig, onderwerpen, genegeerd, docter, dexamfetamine, glucose, hogen]
# 1                  [bloed, prikken, ontlasting, test, laten, slijm, bloedprikken, ingeleverd, bloeduitslagen, geprikt]
# 2                                         [pijn, buikpijn, toilet, last, keer, buik, klachten, normaal, soms, diarree]
# 3                      [afspraak, telefonisch, contact, bellen, proberen, bereikbaar, vandaag, poli, gepland, opnemen]
# 4                                [bedankt, dank, reactie, snelle, alvast, bericht, antwoord, dankjewel, fijn, weekend]
# ..                                                                                                                 ...
# 118                [betekent, vervolgstappen, stappen, the, vervolg, vervolgstap, leukocyten, rapportage, attach, far]
# 119           [aangepast, baat, beclometason, tabletjes, middel, nachtrust, weerstand, beviel, concluderen, echinacea]
# 120  [tegemoet, zie, reactie, graag, hieronder, kliniek, papiertje, premievrijstelling, afsprakenbrief, pensioenfonds]
# 121       [doorgestuurd, picoprep, gestuurd, zorginstelling, doorgezet, derrein, recept, apotheek, gram, hartbewaking]
# 122                         [geboortedatum, geboorte, geb, geboren, hpm, afschaffen, inlevering, welkom, datums, woog]
#
#                                                                                                                                                                                          Representative_Docs  \
# 0                                                                                                                          [Of iets in die trant., Wat is voor mij het verstandigst., Of iets in die trant.]
# 1                                      [Ik heb echter nog geen bloed laten prikken., Ik heb overigens gisterenochtend bloed laten prikken., m.v.g. Ben op  in kerkrade geweest voor bloed te laten prikken.]
# 2    [maar ik heb tot nu toe nog steeds last van buikpijn en pijn aan mijn maag als ik het goed heb .. nu is de vraag is dat normaal of niet ., Ik heb veel pijn in mijn buik., Wel wat diarree, maar gee...
# 3                                [Kan een afspraak via u, of neem ik hier zelf contact over op?, 22 november heb ik telefonisch contact gehad met ., Anders moeten we nog even telefonisch contact op nemen]
# 4                                                                                        [Dank u voor de snelle reactie, Alvast dank voor jullie reactie., Bedankt voor uw snelle reactie.dat is heel fijn.]
# ..                                                                                                                                                                                                       ...
# 118                                                                                                                                             [Wat betekent dit nu?, Wat betekent dit?, Wat betekent dit?]
# 119          [Zou dit ook nog aangepast kunnen worden?, De gezondheidspremie wordt aangepast., Ik heb hier toch veel meer baat bij dan bij de Beclometason 3x per week en nu gaat het goed met de klachten.]
# 120                                                                                             [Ik zie graag jullie reactie tegemoet., Graag zie ik u reactie tegemoet., Ik zie je reactie graag tegemoet.]
# 121                    [Dit mag doorgestuurd worden naar de [APOTHEEK] in ., Dit mag doorgestuurd worden naar de [APOTHEEK] in ., Het recept van de picoprep zou zijn doorgestuurd naar [APOTHEEK]derrein .]
# 122                                                                                                                                      [De geboortedatum is ., geboortedatum is: ., De geboortedatum is .]
#
#     Label
# 0       A
# 1       A
# 2       M
# 3       A
# 4       A
# ..    ...
# 118     A
# 119     M
# 120     A
# 121     A
# 122     A
#
# [123 rows x 6 columns]

# %%
# Example DataFrame (replace with your actual data)

df = topic_info[topic_info["Label"] == "M"]
df = df[["Count", "Name", "Label"]][1:]
df.head()
# Out:
#     Count                                      Name Label
# 5    2298  4_medicatie_gebruik_tabletten_medicijnen     M
# 6    1559                5_huisarts_arts_dokter_mdl     M
# 8    1074     7_bekend_calprotectine_uitslag_waarde     M
# 11    558               10_voel_gevoel_voelt_voelen     M
# 12    553      11_corona_vaccinatie_vaccin_positief     M

# %% [markdown]
#  ## 5. Calculate accuracy

# %%
from bertopic import BERTopic
topic_model = BERTopic.load("/workspace/persistent/mijnidbcoachnlp/saved_models/final_st_model", embedding_model=embedding_model)
# Out:
# /workspace/persistent/mijnidbcoachnlp/venv/lib/python3.8/site-packages/bertopic/_save_utils.py:187: FutureWarning:
#
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#
# /workspace/persistent/mijnidbcoachnlp/venv/lib/python3.8/site-packages/bertopic/_save_utils.py:198: FutureWarning:
#
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.

# %%
topic_info = topic_model.get_topic_info()
topic_info.tail(10)
# Out:
#      Topic  Count                                               Name  \
# 94      93     57                   93_wensen_allereerst_gezond_wens
# 95      94     56      94_bijwerking_bijwerkingen_infliximab_innemen
# 96      95     51                 95_problemen_lange_hierdoor_persen
# 97      96     50                      96_fysiek_opeens_heden_straks
# 98      97     49                         97_team_ibd_binnenkort_idb
# 99      98     45             98_tandarts_tandvlees_kaakchirurg_mond
# 100     99     42             99_betekent_vervolgstappen_stappen_the
# 101    100     37                     100_tegemoet_zie_reactie_graag
# 102    101     36  101_doorgestuurd_picoprep_gestuurd_zorginstelling
# 103    102     34             102_geboortedatum_geboorte_geb_geboren
#
#                                         Representation  Representative_Docs
# 94   [wensen, allereerst, gezond, wens, beste, fijn...                  NaN
# 95   [bijwerking, bijwerkingen, infliximab, innemen...                  NaN
# 96   [problemen, lange, hierdoor, persen, onderdruk...                  NaN
# 97   [fysiek, opeens, heden, straks, beantwoord, aa...                  NaN
# 98   [team, ibd, binnenkort, idb, matig, herhaalrec...                  NaN
# 99   [tandarts, tandvlees, kaakchirurg, mond, kies,...                  NaN
# 100  [betekent, vervolgstappen, stappen, the, vervo...                  NaN
# 101  [tegemoet, zie, reactie, graag, hieronder, kli...                  NaN
# 102  [doorgestuurd, picoprep, gestuurd, zorginstell...                  NaN
# 103  [geboortedatum, geboorte, geb, geboren, hpm, a...                  NaN

# %%
topic_info["Category"] = new_labels
topic_info["Label"] = new_topic_summaries
topic_info.head()
# Out:
#    Topic  Count                                         Name  \
# 0     -1    259  -1_verstandigst_trant_aangenaam_zenuwachtig
# 1      0   4854              0_bloed_prikken_ontlasting_test
# 2      1   4109        1_afspraak_telefonisch_contact_bellen
# 3      2   3651                  2_pijn_buikpijn_toilet_last
# 4      3   3130                3_bedankt_dank_reactie_snelle
#
#                                       Representation  Representative_Docs  \
# 0  [verstandigst, trant, aangenaam, zenuwachtig, ...                  NaN
# 1  [bloed, prikken, ontlasting, test, laten, slij...                  NaN
# 2  [afspraak, telefonisch, contact, bellen, vanda...                  NaN
# 3  [pijn, buikpijn, toilet, last, keer, buik, kla...                  NaN
# 4  [bedankt, dank, reactie, snelle, alvast, beric...                  NaN
#
#   Category                   Label
# 0        A                 outlier
# 1        A        blood/stool test
# 2        A  appointment scheduling
# 3        M                symptoms
# 4        A                   other

# %%
topic_info[topic_info["Topic"] == 52]
# Out:
#     Topic  Count                                             Name  \
# 53     52    137  52_coloscopie_endoscopie_darmonderzoek_verhuisd
#
#                                        Representation  Representative_Docs  \
# 53  [coloscopie, endoscopie, darmonderzoek, verhui...                  NaN
#
#    Category                      Label
# 53        M  colonoscopy/darmonderzoek

# %%
annotated_df = pd.read_excel("/workspace/persistent/mijnidbcoachnlp/data/analysis_data/new_annotated_df_lg.xlsx")
print(len(annotated_df))
annotated_df.head()
# Out:
# 3921
#    Message_ID                                           Sentence  \
# 0           3  Ik ben 2 weken geleden met spoed opgenomen in ...
# 1           3  Ik kreeg acuut een pijnlijke druk op de borst,...
# 2           3                  Het begon 1 uur na het avondeten.
# 3           3  Ik had al de hele dag migraine, had dus ook we...
# 4           3  Ik werd heel erg misselijk, braakneigingen, du...
#
#                                       Clean_Sentence  Sentence_ID  \
# 0  Ik ben 2 weken geleden met spoed opgenomen in ...            1
# 1  Ik kreeg acuut een pijnlijke druk op de borst,...            2
# 2                  Het begon 1 uur na het avondeten.            3
# 3  Ik had al de hele dag migraine, had dus ook we...            4
# 4  Ik werd heel erg misselijk, braakneigingen, du...            5
#
#                                  Translated_Sentence Manual_Category
# 0  I was rushed into the [PRESSION] two weeks ago...               M
# 1  I was acutely under a painful pressure on the ...               M
# 2                    It started 1 hour after dinner.               M
# 3   I had migraines all day, so I hadn't eaten much.               M
# 4  I got very nauseous, vomiting, dizzy and rejuv...               M

# %%
doc_info = topic_model.get_document_info(sentences)
doc_info["Sentence_ID"] = doc_info.index + 1
doc_info.head()
# Out:
#                                             Document  Topic  \
# 0  Ik ben 2 weken geleden met spoed opgenomen in ...     39
# 1  Ik kreeg acuut een pijnlijke druk op de borst,...      2
# 2                  Het begon 1 uur na het avondeten.      2
# 3  Ik had al de hele dag migraine, had dus ook we...      2
# 4  Ik werd heel erg misselijk, braakneigingen, du...      2
#
#                             Name  \
# 0  39_duurt_ruim_natuurlijk_lang
# 1    2_pijn_buikpijn_toilet_last
# 2    2_pijn_buikpijn_toilet_last
# 3    2_pijn_buikpijn_toilet_last
# 4    2_pijn_buikpijn_toilet_last
#
#                                       Representation  Representative_Docs  \
# 0  [duurt, ruim, natuurlijk, lang, hoesten, duurd...                  NaN
# 1  [pijn, buikpijn, toilet, last, keer, buik, kla...                  NaN
# 2  [pijn, buikpijn, toilet, last, keer, buik, kla...                  NaN
# 3  [pijn, buikpijn, toilet, last, keer, buik, kla...                  NaN
# 4  [pijn, buikpijn, toilet, last, keer, buik, kla...                  NaN
#
#                                          Top_n_words  Representative_document  \
# 0  duurt - ruim - natuurlijk - lang - hoesten - d...                    False
# 1  pijn - buikpijn - toilet - last - keer - buik ...                    False
# 2  pijn - buikpijn - toilet - last - keer - buik ...                    False
# 3  pijn - buikpijn - toilet - last - keer - buik ...                    False
# 4  pijn - buikpijn - toilet - last - keer - buik ...                    False
#
#    Sentence_ID
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5

# %%
# Now perform the merge 
annotated_df_with_topic = pd.merge( # merging the small annotated set with the document info
    annotated_df,
    doc_info[['Sentence_ID', 'Topic', 'Top_n_words']], # notice that we only choose these 3 columns of the doc info df
    on='Sentence_ID',
    how='left'
)

# %%
annotated_df_with_topic.head()
# Out:
#    Message_ID                                           Sentence  \
# 0           3  Ik ben 2 weken geleden met spoed opgenomen in ...
# 1           3  Ik kreeg acuut een pijnlijke druk op de borst,...
# 2           3                  Het begon 1 uur na het avondeten.
# 3           3  Ik had al de hele dag migraine, had dus ook we...
# 4           3  Ik werd heel erg misselijk, braakneigingen, du...
#
#                                       Clean_Sentence  Sentence_ID  \
# 0  Ik ben 2 weken geleden met spoed opgenomen in ...            1
# 1  Ik kreeg acuut een pijnlijke druk op de borst,...            2
# 2                  Het begon 1 uur na het avondeten.            3
# 3  Ik had al de hele dag migraine, had dus ook we...            4
# 4  Ik werd heel erg misselijk, braakneigingen, du...            5
#
#                                  Translated_Sentence Manual_Category  Topic  \
# 0  I was rushed into the [PRESSION] two weeks ago...               M     39
# 1  I was acutely under a painful pressure on the ...               M      2
# 2                    It started 1 hour after dinner.               M      2
# 3   I had migraines all day, so I hadn't eaten much.               M      2
# 4  I got very nauseous, vomiting, dizzy and rejuv...               M      2
#
#                                          Top_n_words
# 0  duurt - ruim - natuurlijk - lang - hoesten - d...
# 1  pijn - buikpijn - toilet - last - keer - buik ...
# 2  pijn - buikpijn - toilet - last - keer - buik ...
# 3  pijn - buikpijn - toilet - last - keer - buik ...
# 4  pijn - buikpijn - toilet - last - keer - buik ...

# %%
annotated_doc = pd.merge(
    annotated_df_with_topic,
    topic_info[['Topic', 'Label', 'Category']],
    on='Topic',
    how='left'
)

# %%
annotated_doc.head()
# Out:
#    Message_ID                                           Sentence  \
# 0           3  Ik ben 2 weken geleden met spoed opgenomen in ...
# 1           3  Ik kreeg acuut een pijnlijke druk op de borst,...
# 2           3                  Het begon 1 uur na het avondeten.
# 3           3  Ik had al de hele dag migraine, had dus ook we...
# 4           3  Ik werd heel erg misselijk, braakneigingen, du...
#
#                                       Clean_Sentence  Sentence_ID  \
# 0  Ik ben 2 weken geleden met spoed opgenomen in ...            1
# 1  Ik kreeg acuut een pijnlijke druk op de borst,...            2
# 2                  Het begon 1 uur na het avondeten.            3
# 3  Ik had al de hele dag migraine, had dus ook we...            4
# 4  Ik werd heel erg misselijk, braakneigingen, du...            5
#
#                                  Translated_Sentence Manual_Category  Topic  \
# 0  I was rushed into the [PRESSION] two weeks ago...               M     39
# 1  I was acutely under a painful pressure on the ...               M      2
# 2                    It started 1 hour after dinner.               M      2
# 3   I had migraines all day, so I hadn't eaten much.               M      2
# 4  I got very nauseous, vomiting, dizzy and rejuv...               M      2
#
#                                          Top_n_words     Label Category
# 0  duurt - ruim - natuurlijk - lang - hoesten - d...     other        M
# 1  pijn - buikpijn - toilet - last - keer - buik ...  symptoms        M
# 2  pijn - buikpijn - toilet - last - keer - buik ...  symptoms        M
# 3  pijn - buikpijn - toilet - last - keer - buik ...  symptoms        M
# 4  pijn - buikpijn - toilet - last - keer - buik ...  symptoms        M

# %%
# Pring the average accuracy
accuracy_avg = (annotated_doc['Manual_Category'] == annotated_doc['Category']).sum() / len(annotated_doc)
print(f"Average Accuracy for Manual_Label: {accuracy_avg * 100:.2f}%")
# Out:
# Average Accuracy for Manual_Label: 72.00%

# %%
sentence_df = pd.read_excel("/workspace/persistent/mijnidbcoachnlp/data/analysis_data/translated_sentence_data_new.xlsx")
sentence_df
# Out:
#        Message_ID                                           Sentence  \
# 0               3  Ik ben 2 weken geleden met spoed opgenomen in ...
# 1               3  Ik kreeg acuut een pijnlijke druk op de borst,...
# 2               3                  Het begon 1 uur na het avondeten.
# 3               3  Ik had al de hele dag migraine, had dus ook we...
# 4               3  Ik werd heel erg misselijk, braakneigingen, du...
# ...           ...                                                ...
# 41138       32679  Ze hebben de urine op kweek gezet, kan morgenv...
# 41139       32679  Afgelopen jaren is er al vaker bloed in mijn u...
# 41140       32679                   Wat adviseert u hiermee te doen?
# 41141       32681  Hoi [PERSOON], Oke, dat is iig al een gerustst...
# 41142       32681                  Dankjewel voor de snelle reactie!
#
#                                           Clean_Sentence  Sentence_ID  \
# 0      Ik ben 2 weken geleden met spoed opgenomen in ...            1
# 1      Ik kreeg acuut een pijnlijke druk op de borst,...            2
# 2                      Het begon 1 uur na het avondeten.            3
# 3      Ik had al de hele dag migraine, had dus ook we...            4
# 4      Ik werd heel erg misselijk, braakneigingen, du...            5
# ...                                                  ...          ...
# 41138  Ze hebben de urine op kweek gezet, kan morgenv...        41139
# 41139  Afgelopen jaren is er al vaker bloed in mijn u...        41140
# 41140                   Wat adviseert u hiermee te doen?        41141
# 41141  Oke, dat is iig al een geruststelling  ik wach...        41142
# 41142                  Dankjewel voor de snelle reactie!        41143
#
#                                      Translated_Sentence
# 0      I was rushed into the [PRESSION] two weeks ago...
# 1      I was acutely under a painful pressure on the ...
# 2                        It started 1 hour after dinner.
# 3       I had migraines all day, so I hadn't eaten much.
# 4      I got very nauseous, vomiting, dizzy and rejuv...
# ...                                                  ...
# 41138  They've put the urine on culture, can get the ...
# 41139  In recent years, blood has been found in my ur...
# 41140              What do you suggest you do with this?
# 41141  Hi [PRESSON], Okay, that's a relief;) I'll wai...
# 41142                  Thank you for the quick response!
#
# [41143 rows x 5 columns]

# %%
doc_info_labeled = pd.merge(
    doc_info[["Document", "Topic", "Name", "Representation", "Top_n_words", "Sentence_ID"]],
    topic_info[['Topic', 'Label', 'Category']],
    on="Topic",
    how="left"
)

# %%
doc_info_labeled.head(10)
# Out:
#                                             Document  Topic  \
# 0  Ik ben 2 weken geleden met spoed opgenomen in ...     39
# 1  Ik kreeg acuut een pijnlijke druk op de borst,...      2
# 2                  Het begon 1 uur na het avondeten.      2
# 3  Ik had al de hele dag migraine, had dus ook we...      2
# 4  Ik werd heel erg misselijk, braakneigingen, du...      2
# 5  Op de eerste hulp hebben ze het hart de longen...      0
# 6                    er kwamen geen rare dingen uit.      5
# 7  Later op de dag bij het eten van een beschuitj...      2
# 8  Ze hebben een echo van de gal gemaakt ook zond...     47
# 9  Er is nog een aanvullend onderzoek van de slok...     36
#
#                                   Name  \
# 0        39_duurt_ruim_natuurlijk_lang
# 1          2_pijn_buikpijn_toilet_last
# 2          2_pijn_buikpijn_toilet_last
# 3          2_pijn_buikpijn_toilet_last
# 4          2_pijn_buikpijn_toilet_last
# 5      0_bloed_prikken_ontlasting_test
# 6           5_maanden_beter_maand_goed
# 7          2_pijn_buikpijn_toilet_last
# 8         47_keuze_opvlamming_bang_gal
# 9  36_onderzoek_akkoord_melden_meedoen
#
#                                       Representation  \
# 0  [duurt, ruim, natuurlijk, lang, hoesten, duurd...
# 1  [pijn, buikpijn, toilet, last, keer, buik, kla...
# 2  [pijn, buikpijn, toilet, last, keer, buik, kla...
# 3  [pijn, buikpijn, toilet, last, keer, buik, kla...
# 4  [pijn, buikpijn, toilet, last, keer, buik, kla...
# 5  [bloed, prikken, ontlasting, test, laten, slij...
# 6  [maanden, beter, maand, goed, gaat, gehoord, c...
# 7  [pijn, buikpijn, toilet, last, keer, buik, kla...
# 8  [keuze, opvlamming, bang, gal, ervaar, bedoel,...
# 9  [onderzoek, akkoord, melden, meedoen, roesje, ...
#
#                                          Top_n_words  Sentence_ID  \
# 0  duurt - ruim - natuurlijk - lang - hoesten - d...            1
# 1  pijn - buikpijn - toilet - last - keer - buik ...            2
# 2  pijn - buikpijn - toilet - last - keer - buik ...            3
# 3  pijn - buikpijn - toilet - last - keer - buik ...            4
# 4  pijn - buikpijn - toilet - last - keer - buik ...            5
# 5  bloed - prikken - ontlasting - test - laten - ...            6
# 6  maanden - beter - maand - goed - gaat - gehoor...            7
# 7  pijn - buikpijn - toilet - last - keer - buik ...            8
# 8  keuze - opvlamming - bang - gal - ervaar - bed...            9
# 9  onderzoek - akkoord - melden - meedoen - roesj...           10
#
#                     Label Category
# 0                   other        M
# 1                symptoms        M
# 2                symptoms        M
# 3                symptoms        M
# 4                symptoms        M
# 5        blood/stool test        A
# 6           health update        A
# 7                symptoms        M
# 8                flare-up        M
# 9  research participation        A

# %%
doc_info_labeled_translated = pd.merge(
    doc_info_labeled,
    sentence_df[["Message_ID", "Sentence_ID", "Translated_Sentence"]],
    on="Sentence_ID",
    how="left")

# %%
doc_info_labeled_translated
# Out:
#                                                 Document  Topic  \
# 0      Ik ben 2 weken geleden met spoed opgenomen in ...     39
# 1      Ik kreeg acuut een pijnlijke druk op de borst,...      2
# 2                      Het begon 1 uur na het avondeten.      2
# 3      Ik had al de hele dag migraine, had dus ook we...      2
# 4      Ik werd heel erg misselijk, braakneigingen, du...      2
# ...                                                  ...    ...
# 41138  Ze hebben de urine op kweek gezet, kan morgenv...     86
# 41139  Afgelopen jaren is er al vaker bloed in mijn u...      0
# 41140                   Wat adviseert u hiermee te doen?     20
# 41141  Oke, dat is iig al een geruststelling  ik wach...     16
# 41142                  Dankjewel voor de snelle reactie!      3
#
#                                           Name  \
# 0                39_duurt_ruim_natuurlijk_lang
# 1                  2_pijn_buikpijn_toilet_last
# 2                  2_pijn_buikpijn_toilet_last
# 3                  2_pijn_buikpijn_toilet_last
# 4                  2_pijn_buikpijn_toilet_last
# ...                                        ...
# 41138  86_urine_kweek_gecontroleerd_urinekweek
# 41139          0_bloed_prikken_ontlasting_test
# 41140     20_advies_adviseren_graag_overleggen
# 41141           16_hoop_wacht_wachten_hopelijk
# 41142            3_bedankt_dank_reactie_snelle
#
#                                           Representation  \
# 0      [duurt, ruim, natuurlijk, lang, hoesten, duurd...
# 1      [pijn, buikpijn, toilet, last, keer, buik, kla...
# 2      [pijn, buikpijn, toilet, last, keer, buik, kla...
# 3      [pijn, buikpijn, toilet, last, keer, buik, kla...
# 4      [pijn, buikpijn, toilet, last, keer, buik, kla...
# ...                                                  ...
# 41138  [urine, kweek, gecontroleerd, urinekweek, urin...
# 41139  [bloed, prikken, ontlasting, test, laten, slij...
# 41140  [advies, adviseren, graag, overleggen, overleg...
# 41141  [hoop, wacht, wachten, hopelijk, afwachten, ve...
# 41142  [bedankt, dank, reactie, snelle, alvast, beric...
#
#                                              Top_n_words  Sentence_ID  \
# 0      duurt - ruim - natuurlijk - lang - hoesten - d...            1
# 1      pijn - buikpijn - toilet - last - keer - buik ...            2
# 2      pijn - buikpijn - toilet - last - keer - buik ...            3
# 3      pijn - buikpijn - toilet - last - keer - buik ...            4
# 4      pijn - buikpijn - toilet - last - keer - buik ...            5
# ...                                                  ...          ...
# 41138  urine - kweek - gecontroleerd - urinekweek - u...        41139
# 41139  bloed - prikken - ontlasting - test - laten - ...        41140
# 41140  advies - adviseren - graag - overleggen - over...        41141
# 41141  hoop - wacht - wachten - hopelijk - afwachten ...        41142
# 41142  bedankt - dank - reactie - snelle - alvast - b...        41143
#
#                   Label Category  Message_ID  \
# 0                 other        M           3
# 1              symptoms        M           3
# 2              symptoms        M           3
# 3              symptoms        M           3
# 4              symptoms        M           3
# ...                 ...      ...         ...
# 41138        urine test        M       32679
# 41139  blood/stool test        A       32679
# 41140    seeking advice        M       32679
# 41141             other        A       32681
# 41142             other        A       32681
#
#                                      Translated_Sentence
# 0      I was rushed into the [PRESSION] two weeks ago...
# 1      I was acutely under a painful pressure on the ...
# 2                        It started 1 hour after dinner.
# 3       I had migraines all day, so I hadn't eaten much.
# 4      I got very nauseous, vomiting, dizzy and rejuv...
# ...                                                  ...
# 41138  They've put the urine on culture, can get the ...
# 41139  In recent years, blood has been found in my ur...
# 41140              What do you suggest you do with this?
# 41141  Hi [PRESSON], Okay, that's a relief;) I'll wai...
# 41142                  Thank you for the quick response!
#
# [41143 rows x 10 columns]

# %%
message_category_df = doc_info_labeled_translated[["Category", "Message_ID"]]
message_category_df
# Out:
#       Category  Message_ID
# 0            M           3
# 1            M           3
# 2            M           3
# 3            M           3
# 4            M           3
# ...        ...         ...
# 41138        M       32679
# 41139        A       32679
# 41140        M       32679
# 41141        A       32681
# 41142        A       32681
#
# [41143 rows x 2 columns]

# %%
import pandas as pd
# Count occurrences of "A" and "M" for each Message ID
result = message_category_df.groupby("Message_ID")["Category"].value_counts().unstack(fill_value=0)

# Rename columns for clarity
result.columns.name = None  # Remove category name
result = result.rename(columns={"A": "Count_A", "M": "Count_M"})

# %%
result = result.reset_index()
result[10:30]
# Out:
#     index  Message_ID  Count_A  Count_M
# 10     10          35        3        0
# 11     11          37        0        1
# 12     12          38        2        0
# 13     13          40        2        1
# 14     14          42        2        0
# 15     15          44        2        0
# 16     16          46        2        0
# 17     17          47        0        3
# 18     18          49        1        1
# 19     19          51        3        0
# 20     20          55        1        0
# 21     21          56        3        1
# 22     22          58        1        0
# 23     23          59        5        0
# 24     24          61        2        0
# 25     25          64        5        2
# 26     26          66        1        1
# 27     27          68        2        0
# 28     28          69        7        0
# 29     29          71        4        1

# %%
sentence_df[sentence_df["Message_ID"] == 35]
# Out:
#     Message_ID                                           Sentence  \
# 62          35   Hallo [PERSOON], Bedankt voor de snelle reactie.
# 63          35  Ik heb bij mijn oproep voor morgen ook 2 papie...
# 64          35  Zal ik dit vandaag doen of kan dit ook morgen ...
#
#                                        Clean_Sentence  Sentence_ID  \
# 62                    Bedankt voor de snelle reactie.           63
# 63  Ik heb bij mijn oproep voor morgen ook 2 papie...           64
# 64  Zal ik dit vandaag doen of kan dit ook morgen ...           65
#
#                                   Translated_Sentence
# 62    Hello [PERSOON], Thanks for the quick response.
# 63  I also got two papers on my call for tomorrow....
# 64  Shall I do this today or can I do this tomorro...

# %%
result.to_excel("/workspace/persistent/mijnidbcoachnlp/data/results/message_categories.xlsx", index=False)

# %%
nr_no_med_messages = len(result[result["Count_M"] == 0])
proportion = nr_no_med_messages / len(result)
print(f"Number of non-medical messages: {nr_no_med_messages}")
print(f"Proportion of non-medical messages: {proportion * 100:.2f}%")
# Out:
# Number of non-medical messages: 5287
# Proportion of non-medical messages: 43.83%
