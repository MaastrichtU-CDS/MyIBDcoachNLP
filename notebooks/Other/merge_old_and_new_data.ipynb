# %%
import pandas as pd
# import the large annotated set
annotated_df_lg = pd.read_excel("/workspace/persistent/mijnidbcoachnlp/data/analysis_data/Labeling_sentences_Tom_Sinsel.xlsx", index_col=0)
# check the head of lg set
annotated_df_lg = annotated_df_lg.loc[:, ~annotated_df_lg.columns.str.contains('^Unnamed')]
annotated_df_lg = annotated_df_lg[annotated_df_lg['Manual_label_Tom'].notna()]
len(annotated_df_lg)
# Out:
# 4204

# %%
annotated_df_lg['Sentence_ID'] = annotated_df_lg['Sentence_ID'].astype(str)
# Also add the category of the manual label
annotated_df_lg["Manual_Category"] = None
annotated_df_lg.loc[annotated_df_lg["Manual_label_Tom"].str.contains("A"), "Manual_Category"] = "A"
annotated_df_lg.loc[annotated_df_lg["Manual_label_Tom"].str.contains("M"), "Manual_Category"] = "M"

# %%
annotated_df_lg
# Out:
#       Message_ID                                           Sentence  \
# 0              3  Ik ben 2 weken geleden met spoed opgenomen in ...
# 1              3  Ik kreeg acuut een pijnlijke druk op de borst,...
# 2              3                  Het begon 1 uur na het avondeten.
# 3              3  Ik had al de hele dag migraine, had dus ook we...
# 4              3  Ik werd heel erg misselijk, braakneigingen, du...
# ...          ...                                                ...
# 4199        3020  Ik heb op 25 mei een CT Thoraxscan gehad en zo...
# 4200        3022        Hallo, Dit is de mail die ik heb ontvangen.
# 4201        3023  Goedemorgen, Volgens mijn gegevens en navraag ...
# 4202        3023  Helaas heb ik geen telefoontje van haar gekregen.
# 4203        3023  Is bij jullie bekend wanneer ze dan wel zou be...
#
#                                          Clean_Sentence Sentence_ID  \
# 0     Ik ben 2 weken geleden met spoed opgenomen in ...           0
# 1     Ik kreeg acuut een pijnlijke druk op de borst,...           1
# 2                     Het begon 1 uur na het avondeten.           2
# 3     Ik had al de hele dag migraine, had dus ook we...           3
# 4     Ik werd heel erg misselijk, braakneigingen, du...           4
# ...                                                 ...         ...
# 4199  Ik heb op 25 mei een CT Thoraxscan gehad en zo...        4199
# 4200               Dit is de mail die ik heb ontvangen.        4200
# 4201  Volgens mijn gegevens en navraag bij de MDL po...        4201
# 4202  Helaas heb ik geen telefoontje van haar gekregen.        4202
# 4203  Is bij jullie bekend wanneer ze dan wel zou be...        4203
#
#      Manual_label_Tom Manual_Category
# 0                  M8               M
# 1                  M8               M
# 2                  A5               A
# 3                  M8               M
# 4                  M8               M
# ...               ...             ...
# 4199               M5               M
# 4200               A1               A
# 4201               A2               A
# 4202               A2               A
# 4203               A2               A
#
# [4204 rows x 6 columns]

# %%
import pandas as pd
# read the sentence data 
new_sentence_df =  pd.read_excel("/workspace/persistent/mijnidbcoachnlp/data/analysis_data/translated_sentence_data_new.xlsx")
# check the head
len(new_sentence_df)
# Out:
# 41143

# %%
new_sentence_df
# Out:
#        Message_ID                                           Sentence  \
# 0               3  Ik ben 2 weken geleden met spoed opgenomen in ...
# 1               3  Ik kreeg acuut een pijnlijke druk op de borst,...
# 2               3                  Het begon 1 uur na het avondeten.
# 3               3  Ik had al de hele dag migraine, had dus ook we...
# 4               3  Ik werd heel erg misselijk, braakneigingen, du...
# ...           ...                                                ...
# 41138       32679  Ze hebben de urine op kweek gezet, kan morgenv...
# 41139       32679  Afgelopen jaren is er al vaker bloed in mijn u...
# 41140       32679                   Wat adviseert u hiermee te doen?
# 41141       32681  Hoi [PERSOON], Oke, dat is iig al een gerustst...
# 41142       32681                  Dankjewel voor de snelle reactie!
#
#                                           Clean_Sentence  Sentence_ID  \
# 0      Ik ben 2 weken geleden met spoed opgenomen in ...            1
# 1      Ik kreeg acuut een pijnlijke druk op de borst,...            2
# 2                      Het begon 1 uur na het avondeten.            3
# 3      Ik had al de hele dag migraine, had dus ook we...            4
# 4      Ik werd heel erg misselijk, braakneigingen, du...            5
# ...                                                  ...          ...
# 41138  Ze hebben de urine op kweek gezet, kan morgenv...        41139
# 41139  Afgelopen jaren is er al vaker bloed in mijn u...        41140
# 41140                   Wat adviseert u hiermee te doen?        41141
# 41141  Oke, dat is iig al een geruststelling  ik wach...        41142
# 41142                  Dankjewel voor de snelle reactie!        41143
#
#                                      Translated_Sentence
# 0      I was rushed into the [PRESSION] two weeks ago...
# 1      I was acutely under a painful pressure on the ...
# 2                        It started 1 hour after dinner.
# 3       I had migraines all day, so I hadn't eaten much.
# 4      I got very nauseous, vomiting, dizzy and rejuv...
# ...                                                  ...
# 41138  They've put the urine on culture, can get the ...
# 41139  In recent years, blood has been found in my ur...
# 41140              What do you suggest you do with this?
# 41141  Hi [PRESSON], Okay, that's a relief;) I'll wai...
# 41142                  Thank you for the quick response!
#
# [41143 rows x 5 columns]

# %%
import pandas as pd

# Sample old and new dataframes (replace with your actual dataframes)
old_df = annotated_df_lg
new_df = new_sentence_df

# Function to assign Manual_Category from old_df to new_df
def assign_manual_category(new_df, old_df, max_index=5000):
    manual_categories = []  # List to store the assigned categories
    
    # Iterate through each new sentence (stop at max_index or end of new_df)
    for i, new_sentence in enumerate(new_df['Sentence']):
        if i >= max_index:  # Stop processing after the max_index
            break
        
        matching_category = None
        
        # Loop through old_df to find a match
        for _, old_row in old_df.iterrows():
            # Check if the beginning of the old sentence matches the new sentence's start
            if new_sentence.startswith(old_row['Sentence']):  # Only compare the first 10 characters
                matching_category = old_row['Manual_Category']
                
                # Print the matched sentences (for debugging)
                print(f"iteration: {i}")
                print(f"The following two sentences are matched: \n{new_sentence}\n{old_row['Sentence']}")
                break  # Stop once a match is found
        
        # Append the matched category (or None if no match found)
        manual_categories.append(matching_category)
    
    # Fill remaining manual_categories with None if we didn't reach max_index
    while len(manual_categories) < len(new_df):
        manual_categories.append(None)
    
    # Add the Manual_Category to the new_df
    new_df['Manual_Category'] = manual_categories
    return new_df

# Assign the Manual_Category from old_df to new_df based on the starting sentence match
new_df = assign_manual_category(new_df, old_df, max_index=5000)

# Display the updated new_df
print(new_df)
# Out:
# iteration: 0
# The following two sentences are matched:
# Ik ben 2 weken geleden met spoed opgenomen in het [PERSOON] in [LOCATIE] met verdenking van hartklachten.
# Ik ben 2 weken geleden met spoed opgenomen in het [PERSOON] in [LOCATIE] met verdenking van hartklachten.
# iteration: 1
# The following two sentences are matched:
# Ik kreeg acuut een pijnlijke druk op de borst, schouderbladen, uitstralend naar de armen.
# Ik kreeg acuut een pijnlijke druk op de borst, schouderbladen, uitstralend naar de armen.
# iteration: 2
# The following two sentences are matched:
# Het begon 1 uur na het avondeten.
# Het begon 1 uur na het avondeten.
# iteration: 3
# The following two sentences are matched:
# Ik had al de hele dag migraine, had dus ook weinig gegeten.
# Ik had al de hele dag migraine, had dus ook weinig gegeten.
# iteration: 4
# The following two sentences are matched:
# Ik werd heel erg misselijk, braakneigingen, duizelig en oprispingen.En vreselijke pijn.
# Ik werd heel erg misselijk, braakneigingen, duizelig en oprispingen.En vreselijke pijn.
# iteration: 5
# The following two sentences are matched:
# Op de eerste hulp hebben ze het hart de longen en de bloedvaten onderzocht.
# Op de eerste hulp hebben ze het hart de longen en de bloedvaten onderzocht.
# iteration: 6
# The following two sentences are matched:
# hier kwamen geen rare dingen uit.
# hier kwamen geen rare dingen uit.
# iteration: 7
# The following two sentences are matched:
# Later op de dag bij het eten van een beschuitje begon het weer.
# Later op de dag bij het eten van een beschuitje begon het weer.
# iteration: 8
# The following two sentences are matched:
# Ze hebben een echo van de gal gemaakt ook zonder resultaat.
# Ze hebben een echo van de gal gemaakt ook zonder resultaat.
# iteration: 9
# The following two sentences are matched:
# Er is nog een aanvullend onderzoek van de slokdarm en de maag gedaan, ook geen resultaat.
# Er is nog een aanvullend onderzoek van de slokdarm en de maag gedaan, ook geen resultaat.
# iteration: 10
# The following two sentences are matched:
# Ik heb nog altijd last van oprispingen, hoofdpijn en gevoelig rond de maagstreek.
# Ik heb nog altijd last van oprispingen, hoofdpijn en gevoelig rond de maagstreek.
# iteration: 11
# The following two sentences are matched:
# die enorme pijn heb ik gelukkig niet meer gehad.
# die enorme pijn heb ik gelukkig niet meer gehad.
# iteration: 12
# The following two sentences are matched:
# Morgen moet ik bij jullie bloedprikken, en ontlasting inleveren.
# Morgen moet ik bij jullie bloedprikken, en ontlasting inleveren.
# iteration: 13
# The following two sentences are matched:
# Toch voelt het niet helemaal oke.
# Toch voelt het niet helemaal oke.
# iteration: 14
# The following two sentences are matched:
# Mijn bloeduitslagen zijn goed hoor ik.
# Mijn bloeduitslagen zijn goed hoor ik.
# iteration: 15
# The following two sentences are matched:
# Daar ben ik blij mee.
# Daar ben ik blij mee.
# iteration: 16
# The following two sentences are matched:
# Toch blijven mijn klachten aanhouden.
# Toch blijven mijn klachten aanhouden.
# iteration: 17
# The following two sentences are matched:
# Opboeren, branderige pijn in de maagstreek na het eten.
# Opboeren, branderige pijn in de maagstreek na het eten.
# iteration: 18
# The following two sentences are matched:
# Opgeblazen gevoel.
# Opgeblazen gevoel.
# iteration: 19
# The following two sentences are matched:
# Soms pijnscheuten die aanvalsgewijs komen rond het borstbeen.
# Soms pijnscheuten die aanvalsgewijs komen rond het borstbeen.
# iteration: 20
# The following two sentences are matched:
# In [LOCATIE] hebben ze bij Slokdarm en maagonderzoek niets gezien.
# In [LOCATIE] hebben ze bij Slokdarm en maagonderzoek niets gezien.
# iteration: 21
# The following two sentences are matched:
# Toch is dit plots ontstaan.
# Toch is dit plots ontstaan.
# iteration: 22
# The following two sentences are matched:
# Ik heb hier eerder nooit last van gehad.
# Ik heb hier eerder nooit last van gehad.
# iteration: 23
# The following two sentences are matched:
# Ik ben dinsdagavond op de eerste hulp bij jullie geweest iom [PERSOON].
# Ik ben dinsdagavond op de eerste hulp bij jullie geweest iom [PERSOON].
# iteration: 24
# The following two sentences are matched:
# Na aanvullend onderzoek naar huis gestuurd.
# Na aanvullend onderzoek naar huis gestuurd.
# iteration: 25
# The following two sentences are matched:
# ik lig nu al de hele dag met een stekende buikpijn.
# ik lig nu al de hele dag met een stekende buikpijn.
# iteration: 26
# The following two sentences are matched:
# Rommelende buik, geen eetlust en nog altijd misselijk.
# Rommelende buik, geen eetlust en nog altijd misselijk.
# iteration: 27
# The following two sentences are matched:
# `paracetamol helpt niiet.
# `paracetamol helpt niiet.
# iteration: 28
# The following two sentences are matched:
# Ik weet niet meer wat te doen.
# Ik weet niet meer wat te doen.
# iteration: 29
# The following two sentences are matched:
# De pijn zit rond de navel bovenbuik meer aan de bovenkant.
# De pijn zit rond de navel bovenbuik meer aan de bovenkant.
# iteration: 30
# The following two sentences are matched:
# Komt aanvalsgewijs.
# Komt aanvalsgewijs.
# iteration: 31
# The following two sentences are matched:
# Ik voel mij niet goed.
# Ik voel mij niet goed.
# iteration: 32
# The following two sentences are matched:
# Er zou aanvullend onderzoek komen poliklinisch, maar zo hou ik dat niet vol.
# Er zou aanvullend onderzoek komen poliklinisch, maar zo hou ik dat niet vol.
# iteration: 33
# The following two sentences are matched:
# Op de spoedeisende hulp ben ik geweest.
# Op de spoedeisende hulp ben ik geweest.
# iteration: 34
# The following two sentences are matched:
# Daar ben ik naar huis gestuurd met paracetamol.
# Daar ben ik naar huis gestuurd met paracetamol.
# iteration: 35
# The following two sentences are matched:
# Omdat er geen levensbedreigende dingen waren.
# Omdat er geen levensbedreigende dingen waren.
# iteration: 36
# The following two sentences are matched:
# Dat heeft dus niet veel zin.
# Dat heeft dus niet veel zin.
# iteration: 37
# The following two sentences are matched:
# En paracetamol helpt niet.
# En paracetamol helpt niet.
# iteration: 38
# The following two sentences are matched:
# Zouden ze dat kunnen leveren?
# Zouden ze dat kunnen leveren?
# iteration: 40
# The following two sentences are matched:
# Ik heb morgen een afspraak om 8.30 uur.
# Ik heb morgen een afspraak om 8.30 uur.
# iteration: 41
# The following two sentences are matched:
# in verband met het corona virus en mijn werk wil ik deze afspraak graag verzetten naar een later tijdstip.
# in verband met het corona virus en mijn werk wil ik deze afspraak graag verzetten naar een later tijdstip.
# iteration: 42
# The following two sentences are matched:
# Ik heb geen last van de ontsteking.
# Ik heb geen last van de ontsteking.
# iteration: 43
# The following two sentences are matched:
# Heb zelf het idee dat het rustig is.
# Heb zelf het idee dat het rustig is.
# iteration: 44
# The following two sentences are matched:
# Ik slik momenteel geen medicatie.
# Ik slik momenteel geen medicatie.
# iteration: 45
# The following two sentences are matched:
# Als er nog vragen zijn hoor ik dit graag.
# Als er nog vragen zijn hoor ik dit graag.
# iteration: 46
# The following two sentences are matched:
# Hoi [PERSOON],  Bedankt voor de reactie.
# Hoi [PERSOON],  Bedankt voor de reactie.
# iteration: 47
# The following two sentences are matched:
# De maagklachten zijn ook gestopt.
# De maagklachten zijn ook gestopt.
# iteration: 48
# The following two sentences are matched:
# Verder heb ik geen klachten.
# Verder heb ik geen klachten.
# iteration: 49
# The following two sentences are matched:
# Wel zou ik graag het onderzoek doen maar ben niet in bezit van de app waar ik dit op kan invullen.
# Wel zou ik graag het onderzoek doen maar ben niet in bezit van de app waar ik dit op kan invullen.
# iteration: 50
# The following two sentences are matched:
# Ik heb [PERSOON] ook een mail gestuurd.
# Ik heb [PERSOON] ook een mail gestuurd.
# iteration: 51
# The following two sentences are matched:
# Hallo,  Als eerste mijn excuses dat ik nu pas reageer.
# Hallo,  Als eerste mijn excuses dat ik nu pas reageer.
# iteration: 52
# The following two sentences are matched:
# De klachten komen en gaan.
# De klachten komen en gaan.
# iteration: 53
# The following two sentences are matched:
# Ze zijn midden maart weer begonnen.
# Ze zijn midden maart weer begonnen.
# iteration: 54
# The following two sentences are matched:
# Moet wel zeggen dat ik er nu alweer zeker een week geen last meer van heb gehad.
# Moet wel zeggen dat ik er nu alweer zeker een week geen last meer van heb gehad.
# iteration: 55
# The following two sentences are matched:
# Is dus erg wisselvallig.
# Is dus erg wisselvallig.
# iteration: 56
# The following two sentences are matched:
# Maar dan laat ik het zo en ga er niet verder mee.
# Maar dan laat ik het zo en ga er niet verder mee.
# iteration: 57
# The following two sentences are matched:
# Als terug opspeelt dan meld ik het hier wel.
# Als terug opspeelt dan meld ik het hier wel.
# iteration: 58
# The following two sentences are matched:
# Hallo, Ik heb een vragen lijst hier gekregen over het medicijn, Biological.
# Hallo, Ik heb een vragen lijst hier gekregen over het medicijn, Biological.
# iteration: 59
# The following two sentences are matched:
# Ik heb geen medicijn ontvangen, mijn vraag is moet ik deze vragen toch invullen, zover als mogelijk?
# Ik heb geen medicijn ontvangen, mijn vraag is moet ik deze vragen toch invullen, zover als mogelijk?
# iteration: 60
# The following two sentences are matched:
# de test QuanOn Cal geeft aan 286 en als ik de vragen ga beantwoorden geven ze aan dat het 0 is .
# de test QuanOn Cal geeft aan 286 en als ik de vragen ga beantwoorden geven ze aan dat het 0 is .
# iteration: 61
# The following two sentences are matched:
# Ik kom dinsdag misschien dat ik dan ook antwoorden krijg op mijn vragen.
# Ik kom dinsdag misschien dat ik dan ook antwoorden krijg op mijn vragen.
# iteration: 62
# The following two sentences are matched:
# Hallo [PERSOON], Bedankt voor de snelle reactie.
# Hallo [PERSOON], Bedankt voor de snelle reactie.
# iteration: 63
# The following two sentences are matched:
# Ik heb bij mijn oproep voor morgen ook 2 papieren gekregen.Ik denk dat dit bloedafname formulieren zijn.
# Ik heb bij mijn oproep voor morgen ook 2 papieren gekregen.Ik denk dat dit bloedafname formulieren zijn.
# iteration: 64
# The following two sentences are matched:
# Zal ik dit vandaag doen of kan dit ook morgen als ik kom ?
# Zal ik dit vandaag doen of kan dit ook morgen als ik kom ?
# iteration: 65
# The following two sentences are matched:
# Geen probleem ga ik regelen.
# Geen probleem ga ik regelen.
# iteration: 66
# The following two sentences are matched:
# Hallo,  Ik zou na een week contact met jullie opnemen, over de uitslag van het bloed.
# Hallo,  Ik zou na een week contact met jullie opnemen, over de uitslag van het bloed.
# iteration: 67
# The following two sentences are matched:
# Om te horen of ik kan/mag starten met de medicatie.
# Om te horen of ik kan/mag starten met de medicatie.
# iteration: 68
# The following two sentences are matched:
# Ja prima doe ik dat.
# Ja prima doe ik dat.
# iteration: 69
# The following two sentences are matched:
# Hoe zit met met de 3 vragenlijsten hier?
# Hoe zit met met de 3 vragenlijsten hier?
# iteration: 70
# The following two sentences are matched:
# moet ik deze nu wel of niet invullen ?
# moet ik deze nu wel of niet invullen ?
# iteration: 71
# The following two sentences are matched:
# Hallo, Ik zou na een week contact met jullie opnemen, over de uitslag van het bloed.
# Hallo, Ik zou na een week contact met jullie opnemen, over de uitslag van het bloed.
# iteration: 72
# The following two sentences are matched:
# Om te horen of ik kan/mag starten met de medicatie.
# Om te horen of ik kan/mag starten met de medicatie.
# iteration: 73
# The following two sentences are matched:
# Prima, dan haal ik het recept straks op en zal vanaf morgen starten.
# Prima, dan haal ik het recept straks op en zal vanaf morgen starten.
# iteration: 74
# The following two sentences are matched:
# Volgende week vrijdag zal ik de eerste keer gaan bloed prikken.
# Volgende week vrijdag zal ik de eerste keer gaan bloed prikken.
# iteration: 75
# The following two sentences are matched:
# Hoi [PERSOON],  Bedankt voor de reactie.
# Hoi [PERSOON],  Bedankt voor de reactie.
# iteration: 76
# The following two sentences are matched:
# Wachten komende vrijdag weer af :)   Gr [PERSOON]
# Wachten komende vrijdag weer af :)   Gr [PERSOON]
# iteration: 77
# The following two sentences are matched:
# Hoi, ik heb vanaf vanonrgen erg veel jeuk over mijn lichaam.
# Hoi, ik heb vanaf vanonrgen erg veel jeuk over mijn lichaam.
# iteration: 78
# The following two sentences are matched:
# Kan het zijn dat dit door de medicijnen komt?
# Kan het zijn dat dit door de medicijnen komt?
# iteration: 79
# The following two sentences are matched:
# En wat kan ik er tegen doen ?
# En wat kan ik er tegen doen ?
# iteration: 80
# The following two sentences are matched:
# Hallo [PERSOON],   De heftige klachten heb ik maar een dag gehad.
# Hallo [PERSOON],   De heftige klachten heb ik maar een dag gehad.
# iteration: 81
# The following two sentences are matched:
# Ik zal mijn huis meer insmeren hopelijk dat het dan minder zal voorkomen.
# Ik zal mijn huis meer insmeren hopelijk dat het dan minder zal voorkomen.
# iteration: 82
# The following two sentences are matched:
# Hoi [PERSOON],  Bedankt voor je bericht.
# Hoi [PERSOON],  Bedankt voor je bericht.
# iteration: 83
# The following two sentences are matched:
# Volgende week zou geen probleem moeten zijn om de test te doen.
# Volgende week zou geen probleem moeten zijn om de test te doen.
# iteration: 84
# The following two sentences are matched:
# Ik heb geen test in huis, dus die zul je mij moeten opsturen.
# Ik heb geen test in huis, dus die zul je mij moeten opsturen.
# iteration: 85
# The following two sentences are matched:
# Hallo,  Bedankt voor de terugkoppeling.
# Hallo,  Bedankt voor de terugkoppeling.
# iteration: 86
# The following two sentences are matched:
# Hallo,  Ik wil via deze weg aangeven, mijn tabletten Puri-Nethol zijn bijna op.
# Hallo,  Ik wil via deze weg aangeven, mijn tabletten Puri-Nethol zijn bijna op.
# iteration: 87
# The following two sentences are matched:
# Kan ik deze via jullie bij krijgen.
# Kan ik deze via jullie bij krijgen.
# iteration: 88
# The following two sentences are matched:
# Of moet ik dit via mijn huisarts bij bestellen.
# Of moet ik dit via mijn huisarts bij bestellen.
# iteration: 89
# The following two sentences are matched:
# Makt mij niets uit.
# Makt mij niets uit.
# iteration: 90
# The following two sentences are matched:
# Goedemorgen,  Fijn bedankt voor snelle reactie   [PERSOON]
# Goedemorgen,  Fijn bedankt voor snelle reactie   [PERSOON]
# iteration: 91
# The following two sentences are matched:
# Hallo, Ik heb de vragenlijst ingevuld.
# Hallo, Ik heb de vragenlijst ingevuld.
# iteration: 92
# The following two sentences are matched:
# Nou geeft deze aan dat ik weer een test moet doen.
# Nou geeft deze aan dat ik weer een test moet doen.
# iteration: 93
# The following two sentences are matched:
# Ik heb helaas geen test in huis en ook geen papieren op bloed te prikken.
# Ik heb helaas geen test in huis en ook geen papieren op bloed te prikken.
# iteration: 94
# The following two sentences are matched:
# Als het goed is heb ik 8 dec om 11 uur een afspraak?
# Als het goed is heb ik 8 dec om 11 uur een afspraak?
# iteration: 95
# The following two sentences are matched:
# Mijn vraag is ontvang ik nog formulieren om bloed te prikken, en de test te doen, en klopt de datum 8 dec. om 11 uur.
# Mijn vraag is ontvang ik nog formulieren om bloed te prikken, en de test te doen, en klopt de datum 8 dec. om 11 uur.
# iteration: 96
# The following two sentences are matched:
# Goedemorgen,  Bedankt voor de reactie.
# Goedemorgen,  Bedankt voor de reactie.
# iteration: 97
# The following two sentences are matched:
# Ik zal de test en prikken doen.
# Ik zal de test en prikken doen.
# iteration: 98
# The following two sentences are matched:
# Hallo,  Ja ik heb geen klachten eer.
# Hallo,  Ja ik heb geen klachten eer.
# iteration: 99
# The following two sentences are matched:
# Ik ben wel 13 dec. gevallen en heb 2 vingers gebroken links gelukkig.
# Ik ben wel 13 dec. gevallen en heb 2 vingers gebroken links gelukkig.
# iteration: 100
# The following two sentences are matched:
# 3 weken gips gehad en nu 3 weken rust.
# 3 weken gips gehad en nu 3 weken rust.
# iteration: 101
# The following two sentences are matched:
# binnenkort terug voor foto of de ringvinger in orde is.
# binnenkort terug voor foto of de ringvinger in orde is.
# iteration: 102
# The following two sentences are matched:
# Dit heeft in dec. ook stress gegeven, maar nu gaat het beter.
# Dit heeft in dec. ook stress gegeven, maar nu gaat het beter.
# iteration: 103
# The following two sentences are matched:
# Misschien een idee om volgende maand weer testen en kijken hoe het dan staat.
# Misschien een idee om volgende maand weer testen en kijken hoe het dan staat.
# iteration: 104
# The following two sentences are matched:
# Hoor graag hoe jullie erover denken.
# Hoor graag hoe jullie erover denken.
# iteration: 105
# The following two sentences are matched:
# [PERSOON],  Ik heb nog 1 test, deze zal ik dan gebruiken begin februari.
# [PERSOON],  Ik heb nog 1 test, deze zal ik dan gebruiken begin februari.
# iteration: 106
# The following two sentences are matched:
# Als ik nieuwe klachten krijg zal ik dit zeker aangeven.
# Als ik nieuwe klachten krijg zal ik dit zeker aangeven.
# iteration: 107
# The following two sentences are matched:
# Beste [PERSOON],  Goed ik zal de test volgende week doen.
# Beste [PERSOON],  Goed ik zal de test volgende week doen.
# iteration: 108
# The following two sentences are matched:
# Ik heb er hier nog een liggen.
# Ik heb er hier nog een liggen.
# iteration: 109
# The following two sentences are matched:
# Beste [PERSOON],   Ik heb vanmorgen de test willen doen.
# Beste [PERSOON],   Ik heb vanmorgen de test willen doen.
# iteration: 110
# The following two sentences are matched:
# Ik had gewacht tot vanmorgen omdat ik vandaag mijn vrije dag heb.
# Ik had gewacht tot vanmorgen omdat ik vandaag mijn vrije dag heb.
# iteration: 111
# The following two sentences are matched:
# Helaas pakte de app de scan op het hoesje niet.
# Helaas pakte de app de scan op het hoesje niet.
# iteration: 112
# The following two sentences are matched:
# Het fototoestel bleef foto's maken en stopte het programma dan en moest ik weer opnieuw pincode invoeren.
# Het fototoestel bleef foto's maken en stopte het programma dan en moest ik weer opnieuw pincode invoeren.
# iteration: 113
# The following two sentences are matched:
# Ik had de ontlasting al in spuitje zitten dus heb dat test setje helaas kunnen weggooien.
# Ik had de ontlasting al in spuitje zitten dus heb dat test setje helaas kunnen weggooien.
# iteration: 114
# The following two sentences are matched:
# Zou ik graag een nieuwe kunnen krijgen en wat kan ik doen zodat het fototoestel in mijn telefoon wel de code leest ?
# Zou ik graag een nieuwe kunnen krijgen en wat kan ik doen zodat het fototoestel in mijn telefoon wel de code leest ?
# iteration: 115
# The following two sentences are matched:
# Weet jij misschien wat er mis gaat?
# Weet jij misschien wat er mis gaat?
# iteration: 116
# The following two sentences are matched:
# Hallo [PERSOON],  Ik zal zorgen dat veel licht is,en de telefoon het meeste licht geeft.
# Hallo [PERSOON],  Ik zal zorgen dat veel licht is,en de telefoon het meeste licht geeft.
# iteration: 117
# The following two sentences are matched:
# Het was inderdaad de code die op de cassette stond.
# Het was inderdaad de code die op de cassette stond.
# iteration: 118
# The following two sentences are matched:
# Ik zal eerst deze start maken.
# Ik zal eerst deze start maken.
# iteration: 119
# The following two sentences are matched:
# Zodra hij de code van de cassetten leest dan doe ik de test pas.
# Zodra hij de code van de cassetten leest dan doe ik de test pas.
# iteration: 120
# The following two sentences are matched:
# Lukt het niet bel ik de leverancier wel.
# Lukt het niet bel ik de leverancier wel.
# iteration: 121
# The following two sentences are matched:
# Hallo [PERSOON], Bedankt voor het bericht.
# Hallo [PERSOON], Bedankt voor het bericht.
# iteration: 122
# The following two sentences are matched:
# Op deze manier kan ik het vooruit plannen.
# Op deze manier kan ik het vooruit plannen.
# iteration: 123
# The following two sentences are matched:
# Ik heb geen thuistest meer en ook geen bloedprikformulier.
# Ik heb geen thuistest meer en ook geen bloedprikformulier.
# iteration: 124
# The following two sentences are matched:
# ALvast bedankt voor het opsturen.
# ALvast bedankt voor het opsturen.
# iteration: 125
# The following two sentences are matched:
# Hallo [PERSOON],  Het wil maar niet lukken op de app te downloaden.
# Hallo [PERSOON],  Het wil maar niet lukken op de app te downloaden.
# iteration: 126
# The following two sentences are matched:
# Ik heb het op meerdere telefoons geprobeerd.
# Ik heb het op meerdere telefoons geprobeerd.
# iteration: 127
# The following two sentences are matched:
# Maar de app vraagt direct een wachtwoord.
# Maar de app vraagt direct een wachtwoord.
# iteration: 128
# The following two sentences are matched:
# Als we dat aanmaken dan vraagt hij meteen om een foto van he doosje te maken?
# Als we dat aanmaken dan vraagt hij meteen om een foto van he doosje te maken?
# iteration: 129
# The following two sentences are matched:
# Is dat de bedoeling.
# Is dat de bedoeling.
# iteration: 130
# The following two sentences are matched:
# Heb dan nog geen gegevens van mij ingevoerd.
# Heb dan nog geen gegevens van mij ingevoerd.
# iteration: 131
# The following two sentences are matched:
# Toch een foto proberen te maken van het doosje wat de app vraagt maar dat lukt niet.
# Toch een foto proberen te maken van het doosje wat de app vraagt maar dat lukt niet.
# iteration: 132
# The following two sentences are matched:
# De app gaat normaal uit zichtzelf foto's maken en dat doet hij nu niet.
# De app gaat normaal uit zichtzelf foto's maken en dat doet hij nu niet.
# iteration: 133
# The following two sentences are matched:
# Eind conclusie ik kom dan ook niet meer verder.
# Eind conclusie ik kom dan ook niet meer verder.
# iteration: 134
# The following two sentences are matched:
# Hallo [PERSOON],  Ik zal de test nog eenmaal proberen.
# Hallo [PERSOON],  Ik zal de test nog eenmaal proberen.
# iteration: 135
# The following two sentences are matched:
# Lukt dit niet zal ik bij mijn dokter een potje halen en deze afgeven bij het ziekenhuis.
# Lukt dit niet zal ik bij mijn dokter een potje halen en deze afgeven bij het ziekenhuis.
# iteration: 136
# The following two sentences are matched:
# Kun je mij wel aangeven waar ik dit in het ziekenhuis moet afgeven.
# Kun je mij wel aangeven waar ik dit in het ziekenhuis moet afgeven.
# iteration: 137
# The following two sentences are matched:
# Of is het ook mogelijk om het af te geven of op te sturen via de [LOCATIE].
# Of is het ook mogelijk om het af te geven of op te sturen via de [LOCATIE].
# iteration: 138
# The following two sentences are matched:
# Hoi, Ik ben bezig met een hypotheek en moet een medisch dossier overdragen.
# Hoi, Ik ben bezig met een hypotheek en moet een medisch dossier overdragen.
# iteration: 139
# The following two sentences are matched:
# Nou heb ik in 2019 een kline periode een paar maanden last gehad en daarvoor 1999 het laatste wat ik weet.
# Nou heb ik in 2019 een kline periode een paar maanden last gehad en daarvoor 1999 het laatste wat ik weet.
# iteration: 140
# The following two sentences are matched:
# Waar kan ik gegevens vinden om dit verder uit te leggen, en aan te geven.
# Waar kan ik gegevens vinden om dit verder uit te leggen, en aan te geven.
# iteration: 141
# The following two sentences are matched:
# [PERSOON],   Deze brief heb ik.
# [PERSOON],   Deze brief heb ik.
# iteration: 142
# The following two sentences are matched:
# Kan ik deze afgeven op de afdeling bij jullie en dan tav jou ?
# Kan ik deze afgeven op de afdeling bij jullie en dan tav jou ?
# iteration: 143
# The following two sentences are matched:
# Er staat een e-mailadres bij waar de antwoorden heen moeten.
# Er staat een e-mailadres bij waar de antwoorden heen moeten.
# iteration: 144
# The following two sentences are matched:
# Jullie weten namelijk het beste wat mijn status is.
# Jullie weten namelijk het beste wat mijn status is.
# iteration: 145
# The following two sentences are matched:
# Dat ik erg lichte mate heb.
# Dat ik erg lichte mate heb.
# iteration: 146
# The following two sentences are matched:
# Beste [PERSOON],   Ik heb een reactie van de verzekering ontvangen.
# Beste [PERSOON],   Ik heb een reactie van de verzekering ontvangen.
# iteration: 147
# The following two sentences are matched:
# Er is tot op heden nog niets ontvangen van jullie uit.
# Er is tot op heden nog niets ontvangen van jullie uit.
# iteration: 148
# The following two sentences are matched:
# Mijn  vraag is nu of jullie het al verzonden hebben of dat ik nog iets moet doen?
# Mijn  vraag is nu of jullie het al verzonden hebben of dat ik nog iets moet doen?
# iteration: 149
# The following two sentences are matched:
# Bedankt voor de snelle reactie.
# Bedankt voor de snelle reactie.
# iteration: 150
# The following two sentences are matched:
# Ik wacht dan nog even af.
# Ik wacht dan nog even af.
# iteration: 151
# The following two sentences are matched:
# Hallo,  Ik heb een herrinering ontvangen dat er nog steeds niet is ontvangen.
# Hallo,  Ik heb een herrinering ontvangen dat er nog steeds niet is ontvangen.
# iteration: 152
# The following two sentences are matched:
# Graag met spoed nu regelen, bank begint namelijk moeilijk te doen.
# Graag met spoed nu regelen, bank begint namelijk moeilijk te doen.
# iteration: 153
# The following two sentences are matched:
# [PERSOON],  Reageer hier maar, ik zal de melding in de gaten houden.
# [PERSOON],  Reageer hier maar, ik zal de melding in de gaten houden.
# iteration: 154
# The following two sentences are matched:
# Fijn weekend, [PERSOON] weekend,
# Fijn weekend, [PERSOON] weekend,
# iteration: 155
# The following two sentences are matched:
# Goedemiddag,  Is er al duidelijkheid van [PERSOON].
# Goedemiddag,  Is er al duidelijkheid van [PERSOON].
# iteration: 156
# The following two sentences are matched:
# Ik heb de laatste tijd dat de darmen die rammelt nogal erg hard overdag en dan naar de wc
# Ik heb de laatste tijd dat de darmen die rammelt nogal erg hard overdag en dan naar de wc
# iteration: 157
# The following two sentences are matched:
# En ik heb ook wel eens de laatste tijd ook meer een water scheet daarom dan ben ik elke keer te laat,
# En ik heb ook wel eens de laatste tijd ook meer een water scheet daarom dan ben ik elke keer te laat,
# iteration: 158
# The following two sentences are matched:
# Ik moet ook nog van [PERSOON] naar [ZIEKENHUIS] brengen Calprotectine in ontlasting maar in niet welke afdeling dat moet ik nog uitzoeken of weten jullie het dan hoor ik het wel
# Ik moet ook nog van [PERSOON] naar [ZIEKENHUIS] brengen Calprotectine in ontlasting maar in niet welke afdeling dat moet ik nog uitzoeken of weten jullie het dan hoor ik het wel
# iteration: 159
# The following two sentences are matched:
# Ik had maandag [DATUM] een Afspraak bij [PERSOON]
# Ik had maandag [DATUM] een Afspraak bij [PERSOON]
# iteration: 160
# The following two sentences are matched:
# Ik heb een Afspraken dinsdag [DATUM] om 11:00 uur bij [PERSOON]
# Ik heb een Afspraken dinsdag [DATUM] om 11:00 uur bij [PERSOON]
# iteration: 161
# The following two sentences are matched:
# Ik heb een Afspraken maandag 13-4 2015 om 16:15 uur bij [PERSOON]
# Ik heb een Afspraken maandag 13-4 2015 om 16:15 uur bij [PERSOON]
# iteration: 162
# The following two sentences are matched:
# Ik heb al jaren er last van dat weten ze mij maar ik gebruik DURATEARS OOGDRUPPELS voor droge ogen en VIDISIC CARBOGEL OOGGEL TUBE voor droge ogen ik moet toch nog een keer oogarts, dat was nog van plan,
# Ik heb al jaren er last van dat weten ze mij maar ik gebruik DURATEARS OOGDRUPPELS voor droge ogen en VIDISIC CARBOGEL OOGGEL TUBE voor droge ogen ik moet toch nog een keer oogarts, dat was nog van plan,
# iteration: 163
# The following two sentences are matched:
# Ik kon rechtstreeks bij de oogarts terecht ik chronische ziekte heb dat zeg [PERSOON]
# Ik kon rechtstreeks bij de oogarts terecht ik chronische ziekte heb dat zeg [PERSOON]
# iteration: 164
# The following two sentences are matched:
# Ik moet nog voor een nieuwe boven en ondergebit en ik moet er ook 7 tanden laten treken dat weten de Dokters in [ZIEKENHUIS]
# Ik moet nog voor een nieuwe boven en ondergebit en ik moet er ook 7 tanden laten treken dat weten de Dokters in [ZIEKENHUIS]
# iteration: 165
# The following two sentences are matched:
# Ik ga de volgende tocht even naar [ZIEKENHUIS] brengen Calprotectine in ontlasting maar dan hoor ik pas in april of jullie moeten het mij laten weten  [PERSOON]
# Ik ga de volgende tocht even naar [ZIEKENHUIS] brengen Calprotectine in ontlasting maar dan hoor ik pas in april of jullie moeten het mij laten weten  [PERSOON]
# iteration: 166
# The following two sentences are matched:
# Hoi [PERSOON]  Ik ben op dinsdag [DATUM] toch even naar [ZIEKENHUIS] ontlasting gaan brengen voor Calprotectine maar dan hoor ik pas in april of jullie moeten het eerder mij laten weten  [PERSOON]
# Hoi [PERSOON]  Ik ben op dinsdag [DATUM] toch even naar [ZIEKENHUIS] ontlasting gaan brengen voor Calprotectine maar dan hoor ik pas in april of jullie moeten het eerder mij laten weten  [PERSOON]
# iteration: 167
# The following two sentences are matched:
# Hoi dan wacht ik nog even dan hoor je het nog [PERSOON]
# Hoi dan wacht ik nog even dan hoor je het nog [PERSOON]
# iteration: 168
# The following two sentences are matched:
# ik kijk wel wat jullie doen ik doe overal aan mee dat heb ik altijd  gedaan  dan hoor ik het wel [PERSOON]
# ik kijk wel wat jullie doen ik doe overal aan mee dat heb ik altijd  gedaan  dan hoor ik het wel [PERSOON]
# iteration: 169
# The following two sentences are matched:
# dank je wel ik ga het lezen dan hoor je het  [PERSOON]
# dank je wel ik ga het lezen dan hoor je het  [PERSOON]
# iteration: 170
# The following two sentences are matched:
# Hoi [PERSOON] Hebben jullie al de uitslag over Calprotectine in ontlasting al binnen, Dan hoor ik het wel
# Hoi [PERSOON] Hebben jullie al de uitslag over Calprotectine in ontlasting al binnen, Dan hoor ik het wel
# iteration: 171
# The following two sentences are matched:
# Maar het reuma is ook erger geworden mijn handen doen heel veel pijn,
# Maar het reuma is ook erger geworden mijn handen doen heel veel pijn,
# iteration: 172
# The following two sentences are matched:
# Ik ben de van de week ook door mijn knie rechts gegaan die doet pijn en links is al kapot die Reuma is al erg genoeg pijn maar daar gaat mij ook een beetje lang duren [PERSOON] daar kom
# Ik ben de van de week ook door mijn knie rechts gegaan die doet pijn en links is al kapot die Reuma is al erg genoeg pijn maar daar gaat mij ook een beetje lang duren [PERSOON] daar kom
# iteration: 173
# The following two sentences are matched:
# Ik pas in juli als ik een brief krijg over een half jaar terug komen [PERSOON]
# Ik pas in juli als ik een brief krijg over een half jaar terug komen [PERSOON]
# iteration: 174
# The following two sentences are matched:
# Ik moet op [DATUM] bij [PERSOON] zijn en ook bij  [PERSOON] dan vraag ik ook over de Pijn van mijn benen en knieën en heupen daar heb ik ook veel last van Reuma alles doet pijn lopen gaat moeilijk,
# Ik moet op [DATUM] bij [PERSOON] zijn en ook bij  [PERSOON] dan vraag ik ook over de Pijn van mijn benen en knieën en heupen daar heb ik ook veel last van Reuma alles doet pijn lopen gaat moeilijk,
# iteration: 175
# The following two sentences are matched:
# Ik kom bij een nieuwe dr. voor de Reuma
# Ik kom bij een nieuwe dr. voor de Reuma
# iteration: 176
# The following two sentences are matched:
# Ik heb een brief gekregen,
# Ik heb een brief gekregen,
# iteration: 177
# The following two sentences are matched:
# En ik moet ook voor een nieuw gebit dat was niet goed meer [DATUM] er worden 5 tanden getrokken in
# En ik moet ook voor een nieuw gebit dat was niet goed meer [DATUM] er worden 5 tanden getrokken in
# iteration: 178
# The following two sentences are matched:
# Het Reinaert Kliniek,
# Het Reinaert Kliniek,
# iteration: 179
# The following two sentences are matched:
# Hoi [PERSOON]  Ik moest van [PERSOON] toch nog opnieuw naar [ZIEKENHUIS] ontlasting gaan brengen voor Calprotectine  op [DATUM]  maar daar heb nog niets van gehoord dat moet ik vragen aan jullie mij laten weten dan hoor ik wel.
# Hoi [PERSOON]  Ik moest van [PERSOON] toch nog opnieuw naar [ZIEKENHUIS] ontlasting gaan brengen voor Calprotectine  op [DATUM]  maar daar heb nog niets van gehoord dat moet ik vragen aan jullie mij laten weten dan hoor ik wel.
# iteration: 180
# The following two sentences are matched:
# Heb elke keer wat water in onderbroek, De darmen die rammelt nogal erg hard overdag en avonds nog erger Wat ken ik er nog aan doen  Gr.
# Heb elke keer wat water in onderbroek, De darmen die rammelt nogal erg hard overdag en avonds nog erger Wat ken ik er nog aan doen  Gr.
# iteration: 181
# The following two sentences are matched:
# Ik heb een probleem met mijn arm spierbal een hele dikke bult bloeduitstorting
# Ik heb een probleem met mijn arm spierbal een hele dikke bult bloeduitstorting
# iteration: 182
# The following two sentences are matched:
# En ben bij de huisarts geweest die zeg daar kunnen wij niks aan doen en ik heb veel Pijn in mijn arm
# En ben bij de huisarts geweest die zeg daar kunnen wij niks aan doen en ik heb veel Pijn in mijn arm
# iteration: 183
# The following two sentences are matched:
# En ik weet het niet meer kan ik dat aan de reumatoloog vragen daar moet ik [DATUM] zijn het is Vandaag moet ik daar zijn om 14:00 uur is wel bij een nieuwe Dr.
# En ik weet het niet meer kan ik dat aan de reumatoloog vragen daar moet ik [DATUM] zijn het is Vandaag moet ik daar zijn om 14:00 uur is wel bij een nieuwe Dr.
# iteration: 184
# The following two sentences are matched:
# En ik ben ook bloed gaan prikken op maandag 1 juni   [PERSOON]
# En ik ben ook bloed gaan prikken op maandag 1 juni   [PERSOON]
# iteration: 185
# The following two sentences are matched:
# Ja dat ga ik proberen leuk ik hen een iphone 4s dat gaat wel dat hoor je nog als ik hem er op heb zitten [PERSOON]
# Ja dat ga ik proberen leuk ik hen een iphone 4s dat gaat wel dat hoor je nog als ik hem er op heb zitten [PERSOON]
# iteration: 186
# The following two sentences are matched:
# Het zet op mobiel en het werkt Gr [PERSOON]
# Het zet op mobiel en het werkt Gr [PERSOON]
# iteration: 187
# The following two sentences are matched:
# Oke Ik moet vanmiddag toch naar het [ZIEKENHUIS] mijn arm staat een bult op daar moet ook naar laten kijken spier gescheurd  [PERSOON]
# Oke Ik moet vanmiddag toch naar het [ZIEKENHUIS] mijn arm staat een bult op daar moet ook naar laten kijken spier gescheurd  [PERSOON]
# iteration: 188
# The following two sentences are matched:
# dinsdag [DATUM]  Hoi [PERSOON]  Ik heb een vraag hoelang duurt een afspraak bij een cardiologie ik heb het aan mijn hart Maar ik hoor maar niks of moet ik nog wachten ik ben zenuwachtig ze hebben mij onderzoek gedaan  Bij polikliniek anesthesiologie voor een totaal nieuwe knie operatie ik ben daar geweest op 7 juli ’15  nu gaan al bloed onderzoeken doen daar moet ik lab boven zijn op afd.
# dinsdag [DATUM]  Hoi [PERSOON]  Ik heb een vraag hoelang duurt een afspraak bij een cardiologie ik heb het aan mijn hart Maar ik hoor maar niks of moet ik nog wachten ik ben zenuwachtig ze hebben mij onderzoek gedaan  Bij polikliniek anesthesiologie voor een totaal nieuwe knie operatie ik ben daar geweest op 7 juli ’15  nu gaan al bloed onderzoeken doen daar moet ik lab boven zijn op afd.
# iteration: 189
# The following two sentences are matched:
# 5 boven komen mijn zus dan bel je de Afd.
# 5 boven komen mijn zus dan bel je de Afd.
# iteration: 190
# The following two sentences are matched:
# op   dan hoor ik het wel Gr.
# op   dan hoor ik het wel Gr.
# iteration: 191
# The following two sentences are matched:
# Hoi dan wacht ik wel ik toch wat vragen  je hoort mij wel weer Gr [PERSOON]
# Hoi dan wacht ik wel ik toch wat vragen  je hoort mij wel weer Gr [PERSOON]
# iteration: 192
# The following two sentences are matched:
# Ik wordt opgenomen/behandeld Orthopedie voor een Nieuwe Totale knie op [DATUM] Nu ben ik moeten stoppen met Humira al 5 weken voor de knie ik heb nu Heftig borrelen in de buik last van darmen ik ben ook gaan Bloedprikken voor een paar dokters maar daar heb nog niks gehoord
# Ik wordt opgenomen/behandeld Orthopedie voor een Nieuwe Totale knie op [DATUM] Nu ben ik moeten stoppen met Humira al 5 weken voor de knie ik heb nu Heftig borrelen in de buik last van darmen ik ben ook gaan Bloedprikken voor een paar dokters maar daar heb nog niks gehoord
# iteration: 193
# The following two sentences are matched:
# Ik heb ook Calprotectine in ontlasting voor onderzoek ook nog niks gehoord  dan hoor ik het wel Gr.
# Ik heb ook Calprotectine in ontlasting voor onderzoek ook nog niks gehoord  dan hoor ik het wel Gr.
# iteration: 194
# The following two sentences are matched:
# Hoi ik lig in [ZIEKENHUIS] Herstelzorg ze hebben een nieuwe knie geplaatst  ik weet niet dat de Humira gestart mag dan hoor ik het wel Gr [PERSOON]
# Hoi ik lig in [ZIEKENHUIS] Herstelzorg ze hebben een nieuwe knie geplaatst  ik weet niet dat de Humira gestart mag dan hoor ik het wel Gr [PERSOON]
# iteration: 195
# The following two sentences are matched:
# Hoi ik heb toch borstkanker nu zijn ze met een Paclitaxel en Herceptin bezig nu hebben weer een brief vragenlijst gestuurd nu heb ik even geen zin in wat moet ik doen Gr [PERSOON]
# Hoi ik heb toch borstkanker nu zijn ze met een Paclitaxel en Herceptin bezig nu hebben weer een brief vragenlijst gestuurd nu heb ik even geen zin in wat moet ik doen Gr [PERSOON]
# iteration: 196
# The following two sentences are matched:
# Hoi [PERSOON] Als er iets dan stuur wel E-mail bedankt Gr [PERSOON]
# Hoi [PERSOON] Als er iets dan stuur wel E-mail bedankt Gr [PERSOON]
# iteration: 197
# The following two sentences are matched:
# Beste [PERSOON],  Ik dacht dat ik de uitslag van de bloed test via mijn IBD coach zou krijgen, maar heb tot heden nog geen bericht ontvangen.
# Beste [PERSOON],  Ik dacht dat ik de uitslag van de bloed test via mijn IBD coach zou krijgen, maar heb tot heden nog geen bericht ontvangen.
# iteration: 198
# The following two sentences are matched:
# Hoe kan ik zien of ik de uitslag heb gekregen?
# Hoe kan ik zien of ik de uitslag heb gekregen?
# iteration: 199
# The following two sentences are matched:
# Hi [PERSOON],  bedankt, goed nieuws!
# Hi [PERSOON],  bedankt, goed nieuws!
# iteration: 200
# The following two sentences are matched:
# Geachte Dame/Heer,  ik heb in mijn agenda geen nieuwe afspraak staan met [PERSOON].
# Geachte Dame/Heer,  ik heb in mijn agenda geen nieuwe afspraak staan met [PERSOON].
# iteration: 201
# The following two sentences are matched:
# Hi [PERSOON],  dank voor je antwoord.
# Hi [PERSOON],  dank voor je antwoord.
# iteration: 202
# The following two sentences are matched:
# Ik maak dan een afspraak halverwege 2016.
# Ik maak dan een afspraak halverwege 2016.
# iteration: 203
# The following two sentences are matched:
# Ik blijf dus wel regelmatig bloedprikken en krijg dan de uitslag via de website.
# Ik blijf dus wel regelmatig bloedprikken en krijg dan de uitslag via de website.
# iteration: 204
# The following two sentences are matched:
# Hi [PERSOON],  dank voor je bericht.
# Hi [PERSOON],  dank voor je bericht.
# iteration: 205
# The following two sentences are matched:
# Jij was dus de anonieme beller rond 14.30... Ik was in een meeting en drukte je weg; het was even ontschoten dat jullie zouden kunnen bellen.
# Jij was dus de anonieme beller rond 14.30... Ik was in een meeting en drukte je weg; het was even ontschoten dat jullie zouden kunnen bellen.
# iteration: 206
# The following two sentences are matched:
# Ik denk dat het goed is om nog eens te prikken.
# Ik denk dat het goed is om nog eens te prikken.
# iteration: 207
# The following two sentences are matched:
# Zouden jullie mij nieuwe formulieren kunnen sturen?
# Zouden jullie mij nieuwe formulieren kunnen sturen?
# iteration: 208
# The following two sentences are matched:
# Beste [PERSOON],  ik heb afgelopen maandag bloed laten prikken.
# Beste [PERSOON],  ik heb afgelopen maandag bloed laten prikken.
# iteration: 209
# The following two sentences are matched:
# Ik ben benieuwd naar de uitslag, want ik herken een aantal symptomen wel goed (vermoeidheid, onverklaarbare hoofdpijn).
# Ik ben benieuwd naar de uitslag, want ik herken een aantal symptomen wel goed (vermoeidheid, onverklaarbare hoofdpijn).
# iteration: 210
# The following two sentences are matched:
# Dit kan natuurlijk ook altijd andere oorzaken hebben, maar door extra ijzer zou het of beter gaan of een mogelijke oorzaak weggestreept kunnen worden.
# Dit kan natuurlijk ook altijd andere oorzaken hebben, maar door extra ijzer zou het of beter gaan of een mogelijke oorzaak weggestreept kunnen worden.
# iteration: 211
# The following two sentences are matched:
# [PERSOON] of [PERSOON], mijn pillen Azathiopirine zijn weer op.
# [PERSOON] of [PERSOON], mijn pillen Azathiopirine zijn weer op.
# iteration: 212
# The following two sentences are matched:
# Zou ik weer een herhaalrecept kunnen krijgen?
# Zou ik weer een herhaalrecept kunnen krijgen?
# iteration: 213
# The following two sentences are matched:
# Ik haal ze het liefst op bij apotheek [LOCATIE],   Alvast bedankt!
# Ik haal ze het liefst op bij apotheek [LOCATIE],   Alvast bedankt!
# iteration: 214
# The following two sentences are matched:
# [PERSOON] of [PERSOON], mijn pillen Azathiopirine zijn bijna op.
# [PERSOON] of [PERSOON], mijn pillen Azathiopirine zijn bijna op.
# iteration: 215
# The following two sentences are matched:
# Zou ik weer een herhaalrecept kunnen krijgen?
# Zou ik weer een herhaalrecept kunnen krijgen?
# iteration: 216
# The following two sentences are matched:
# Ik haal ze het liefst op bij apotheek [LOCATIE],   Zouden jullie mij ook nieuwe bloedafname formulieren kunnen sturen?
# Ik haal ze het liefst op bij apotheek [LOCATIE],   Zouden jullie mij ook nieuwe bloedafname formulieren kunnen sturen?
# iteration: 217
# The following two sentences are matched:
# Beste [PERSOON] en [PERSOON],  ik heb volgens mij komende maandag 8 april een afspraak.
# Beste [PERSOON] en [PERSOON],  ik heb volgens mij komende maandag 8 april een afspraak.
# iteration: 218
# The following two sentences are matched:
# Ik wil graag maandag bloed prikken maar zie nu dat ik geen formulieren heb.
# Ik wil graag maandag bloed prikken maar zie nu dat ik geen formulieren heb.
# iteration: 219
# The following two sentences are matched:
# Zouden jullie deze mij kunnen sturen?
# Zouden jullie deze mij kunnen sturen?
# iteration: 220
# The following two sentences are matched:
# Beste [PERSOON],  het gaat zo goed, ik ben het helemaal vergeten.
# Beste [PERSOON],  het gaat zo goed, ik ben het helemaal vergeten.
# iteration: 221
# The following two sentences are matched:
# Ik zal de spullen gaan zoeken en deze maand nog wat inleveren.
# Ik zal de spullen gaan zoeken en deze maand nog wat inleveren.
# iteration: 222
# The following two sentences are matched:
# Geachte Dame/Heer,  allereerst enorm bedankt voor al het werk dat jullie team en jullie collega's verzetten in deze moeilijke tijden.
# Geachte Dame/Heer,  allereerst enorm bedankt voor al het werk dat jullie team en jullie collega's verzetten in deze moeilijke tijden.
# iteration: 223
# The following two sentences are matched:
# Ik vroeg me af of mijn afspraak op 20 april door gaat, gezien de huidige situatie.
# Ik vroeg me af of mijn afspraak op 20 april door gaat, gezien de huidige situatie.
# iteration: 224
# The following two sentences are matched:
# Zo ja, zouden jullie mij dan svp de papieren kunnen sturen voor een bloedafname?
# Zo ja, zouden jullie mij dan svp de papieren kunnen sturen voor een bloedafname?
# iteration: 225
# The following two sentences are matched:
# Geachte dame/heer,  de laatste 10 dagen krijg ik meer last van mijn colitis na jaren van rust.
# Geachte dame/heer,  de laatste 10 dagen krijg ik meer last van mijn colitis na jaren van rust.
# iteration: 226
# The following two sentences are matched:
# Ik moet sinds 10 dagen vaker naar het toilet waarbij de darmen vol lucht zitten en de stoelgang moeizaam is.
# Ik moet sinds 10 dagen vaker naar het toilet waarbij de darmen vol lucht zitten en de stoelgang moeizaam is.
# iteration: 227
# The following two sentences are matched:
# Afgelopen donderdag was het minst goed met 5x naar het toilet waarvan 2x echt dringend.
# Afgelopen donderdag was het minst goed met 5x naar het toilet waarvan 2x echt dringend.
# iteration: 228
# The following two sentences are matched:
# Er kwam ook een spoortje bloed bij.
# Er kwam ook een spoortje bloed bij.
# iteration: 229
# The following two sentences are matched:
# Vrijdag en in het weekend ging het weer aanmerkelijk beter.
# Vrijdag en in het weekend ging het weer aanmerkelijk beter.
# iteration: 230
# The following two sentences are matched:
# Ik ben sinds vorig jaar van de medicijnen af en dat bevalt mij prima.
# Ik ben sinds vorig jaar van de medicijnen af en dat bevalt mij prima.
# iteration: 231
# The following two sentences are matched:
# Ik wil dit graag zo houden maar ook graag van de huidige situatie af.
# Ik wil dit graag zo houden maar ook graag van de huidige situatie af.
# iteration: 232
# The following two sentences are matched:
# Wat kan ik het beste doen?
# Wat kan ik het beste doen?
# iteration: 233
# The following two sentences are matched:
# Hi [PERSOON],  de ontlasting is meer zachte keutels van 1-3cm doorsnede als ik zo mag uitdrukken.
# Hi [PERSOON],  de ontlasting is meer zachte keutels van 1-3cm doorsnede als ik zo mag uitdrukken.
# iteration: 234
# The following two sentences are matched:
# Het bloed is niet helder rood en komt ook weinig voor.
# Het bloed is niet helder rood en komt ook weinig voor.
# iteration: 235
# The following two sentences are matched:
# Het is meer waterig, dus vermengd.
# Het is meer waterig, dus vermengd.
# iteration: 236
# The following two sentences are matched:
# Slijm weet ik zo niet, zal ik op letten.
# Slijm weet ik zo niet, zal ik op letten.
# iteration: 237
# The following two sentences are matched:
# Hi [PERSOON],  ik heb de app geinstalleerd en alles voorbereid.
# Hi [PERSOON],  ik heb de app geinstalleerd en alles voorbereid.
# iteration: 238
# The following two sentences are matched:
# Vanochtend was de opgevangen stoelgang aanzienlijk slechter dan de dagen hiervoor; een mengeling van dunne ontlasting, slijm en bloed.
# Vanochtend was de opgevangen stoelgang aanzienlijk slechter dan de dagen hiervoor; een mengeling van dunne ontlasting, slijm en bloed.
# iteration: 239
# The following two sentences are matched:
# Ik heb besloten om de test niet te doen op deze ontlasting.
# Ik heb besloten om de test niet te doen op deze ontlasting.
# iteration: 240
# The following two sentences are matched:
# Ik heb dus nog opvang materiaal voor één test en verder alle materialen voor twee testen.
# Ik heb dus nog opvang materiaal voor één test en verder alle materialen voor twee testen.
# iteration: 241
# The following two sentences are matched:
# Zouden jullie mij nog wat extra opvang materiaal en/of testen kunnen sturen?
# Zouden jullie mij nog wat extra opvang materiaal en/of testen kunnen sturen?
# iteration: 242
# The following two sentences are matched:
# Ik probeer vanavond een nieuwe test te doen.
# Ik probeer vanavond een nieuwe test te doen.
# iteration: 243
# The following two sentences are matched:
# Hi [PERSOON],  Helder, dank voor snelle antwoord.
# Hi [PERSOON],  Helder, dank voor snelle antwoord.
# iteration: 244
# The following two sentences are matched:
# Als huishoudfolie ook werkt dan gebruik ik deze.
# Als huishoudfolie ook werkt dan gebruik ik deze.
# iteration: 245
# The following two sentences are matched:
# Ik zal vanavond proberen een nieuwe test te doen.
# Ik zal vanavond proberen een nieuwe test te doen.
# iteration: 246
# The following two sentences are matched:
# Het is altijd weer een beetje afwachten wat de ontlasting is; deze is heel wisselvallig.
# Het is altijd weer een beetje afwachten wat de ontlasting is; deze is heel wisselvallig.
# iteration: 247
# The following two sentences are matched:
# Beste [PERSOON],   het gaat weer iets beter en ik heb gisteren de test proberen te doen.
# ...
# Sorry er ging iets verkeerd, ook heb ik voor de oorontsteking Sofrades oordruppels 3 x daags 3 druppels en de Mometason sprau, 1 x daags 2 sprays in beide  neusgaten.
# iteration: 3969
# The following two sentences are matched:
# Moet ik me zorgen maken of gewoon even afwachten, voel me verder buiten erg moe momenteel goed.
# Moet ik me zorgen maken of gewoon even afwachten, voel me verder buiten erg moe momenteel goed.
# iteration: 3970
# The following two sentences are matched:
# Goedemiddag,  in vervolg op vorige mail wil ik graag mijn verhaal kwijt van de afgelopen weken.
# Goedemiddag,  in vervolg op vorige mail wil ik graag mijn verhaal kwijt van de afgelopen weken.
# iteration: 3971
# The following two sentences are matched:
# Op 18 oktober ben ik op advies van mijn huisarts naar het [ZIEKENHUIS] verwezen voor een longfoto omdat ik al ruim 2 maanden aan het hoesten was.
# Op 18 oktober ben ik op advies van mijn huisarts naar het [ZIEKENHUIS] verwezen voor een longfoto omdat ik al ruim 2 maanden aan het hoesten was.
# iteration: 3972
# The following two sentences are matched:
# Diverse medicatie mocht echter niet helpen.
# Diverse medicatie mocht echter niet helpen.
# iteration: 3973
# The following two sentences are matched:
# In de avond werd ik gebeld door mijn huisarts met de mededeling dat er vlekken op mijn longen te zien waren.
# In de avond werd ik gebeld door mijn huisarts met de mededeling dat er vlekken op mijn longen te zien waren.
# iteration: 3974
# The following two sentences are matched:
# Diverse onderzoeken zoals een CT-Pet scan, bloedonderzoek, longfunctie en uiteindelijk een longpunctie waren het gevolg.
# Diverse onderzoeken zoals een CT-Pet scan, bloedonderzoek, longfunctie en uiteindelijk een longpunctie waren het gevolg.
# iteration: 3975
# The following two sentences are matched:
# Als mogelijke oorzaak voor de vlekken werd genoemd dat het kwaadaardige cellen konden zijn maar er werd ook niet uitgesloten dat het infecties of eventueel ook bijwerkingen konden zijn van de medicatie voor de ziekte van Crohn.
# Als mogelijke oorzaak voor de vlekken werd genoemd dat het kwaadaardige cellen konden zijn maar er werd ook niet uitgesloten dat het infecties of eventueel ook bijwerkingen konden zijn van de medicatie voor de ziekte van Crohn.
# iteration: 3976
# The following two sentences are matched:
# Dinsdag 12 november kreeg ik de uitslag, longkanker kon uitgesloten worden, wel werd verteld dat het ontstekingen waren in de longen die volgens de longarts afkomstig konden zijn van de medicatie voor de ziekte van Crohn.
# Dinsdag 12 november kreeg ik de uitslag, longkanker kon uitgesloten worden, wel werd verteld dat het ontstekingen waren in de longen die volgens de longarts afkomstig konden zijn van de medicatie voor de ziekte van Crohn.
# iteration: 3977
# The following two sentences are matched:
# De longarts zou hierover contact met jullie opnemen.
# De longarts zou hierover contact met jullie opnemen.
# iteration: 3978
# The following two sentences are matched:
# Waarom ik dan toch even mail is om te vragen hoe nu verder, door die ontstekingen in mijn longen worden deze geirriteerd waardoor ik constant aan het hoesten ben.
# Waarom ik dan toch even mail is om te vragen hoe nu verder, door die ontstekingen in mijn longen worden deze geirriteerd waardoor ik constant aan het hoesten ben.
# iteration: 3979
# The following two sentences are matched:
# Is het mogelijk dat dit inderdaad mogelijke bijwerkingen zijn, wat kunnen we dan doen om zo snel mogelijk van deze ontstekingen af te komen waardoor ook het hoesten minder is.
# Is het mogelijk dat dit inderdaad mogelijke bijwerkingen zijn, wat kunnen we dan doen om zo snel mogelijk van deze ontstekingen af te komen waardoor ook het hoesten minder is.
# iteration: 3980
# The following two sentences are matched:
# Ik ben me bewust van het feit dat deze ontstekingen littekens gaan achterlaten in mijn longen waardoor er misschien uiteindelijk ongemakken gaan komen met mijn luchtwegen.
# Ik ben me bewust van het feit dat deze ontstekingen littekens gaan achterlaten in mijn longen waardoor er misschien uiteindelijk ongemakken gaan komen met mijn luchtwegen.
# iteration: 3981
# The following two sentences are matched:
# Graag ontvang ik een reactie, ik ben bereid om eventuele andere medicatie die deze bijwerkingen niet heeft te voorkomen.
# Graag ontvang ik een reactie, ik ben bereid om eventuele andere medicatie die deze bijwerkingen niet heeft te voorkomen.
# iteration: 3982
# The following two sentences are matched:
# Dank je wel voor de reactie,
# Dank je wel voor de reactie,
# iteration: 3983
# The following two sentences are matched:
# Goedemorgen, op 20 november heb ik bloed laten prikken en mijn vraag is of deze uitslagen al binnen zijn en hoe het ervoor staat dit ivm met longen.
# Goedemorgen, op 20 november heb ik bloed laten prikken en mijn vraag is of deze uitslagen al binnen zijn en hoe het ervoor staat dit ivm met longen.
# iteration: 3984
# The following two sentences are matched:
# Ik heb inmiddels twee afspraken  via de poli interne geneeskunde gekregen en zag op beide afspraken dat deze niet met [PERSOON] waren al had ik in dit geval wel eentje verwacht.
# Ik heb inmiddels twee afspraken  via de poli interne geneeskunde gekregen en zag op beide afspraken dat deze niet met [PERSOON] waren al had ik in dit geval wel eentje verwacht.
# iteration: 3985
# The following two sentences are matched:
# Vooral ook omdat ik wil weten wat het verloop zal zijn in de ontstekingen die ontdekt zijn in mijn longen en op mijn stemband.
# Vooral ook omdat ik wil weten wat het verloop zal zijn in de ontstekingen die ontdekt zijn in mijn longen en op mijn stemband.
# iteration: 3986
# The following two sentences are matched:
# Waarom zijn er twee afspraken in opeenvolgende maanden gemaakt, was het bloed toch niet helemaal in orde?
# Waarom zijn er twee afspraken in opeenvolgende maanden gemaakt, was het bloed toch niet helemaal in orde?
# iteration: 3987
# The following two sentences are matched:
# Als de uitslagen van het bloed binnen zijn is het dan mogelijk mij hiervan in te lichten?
# Als de uitslagen van het bloed binnen zijn is het dan mogelijk mij hiervan in te lichten?
# iteration: 3988
# The following two sentences are matched:
# Hallo [PERSOON], Bijgesloten de formulieren voor het bloedprikken zoals ik ze heb gekregen.
# Hallo [PERSOON], Bijgesloten de formulieren voor het bloedprikken zoals ik ze heb gekregen.
# iteration: 3989
# The following two sentences are matched:
# Zijn hier de formulieren bij om de bloedspiegel te controleren?
# Zijn hier de formulieren bij om de bloedspiegel te controleren?
# iteration: 3990
# The following two sentences are matched:
# Hallo,  Zie Uw mail van 29 november jl.
# Hallo,  Zie Uw mail van 29 november jl.
# iteration: 3991
# The following two sentences are matched:
# De afspraak van 13 januari gaat die door of is die inmiddels geannuleerd geworden gezien ik niets meer gehoord heb hiervan.
# De afspraak van 13 januari gaat die door of is die inmiddels geannuleerd geworden gezien ik niets meer gehoord heb hiervan.
# iteration: 3992
# The following two sentences are matched:
# Goedemorgen, Kunt U mij vertellen wanneer ik de laatste keer bloed geprikt heb, ik heb hier nog briefjes liggen en weet eigenlijk niet of dit nu moet of later.
# Goedemorgen, Kunt U mij vertellen wanneer ik de laatste keer bloed geprikt heb, ik heb hier nog briefjes liggen en weet eigenlijk niet of dit nu moet of later.
# iteration: 3993
# The following two sentences are matched:
# Het betreft de formulieren zoals aangegeven in de mail van 10 december Met vriendelijke groet.
# Het betreft de formulieren zoals aangegeven in de mail van 10 december Met vriendelijke groet.
# iteration: 3994
# The following two sentences are matched:
# Goedemorgen, Op 9 december ben ik op de Poli geweest voor een afspraak met [PERSOON] waarbij [PERSOON] eveneens is aangesloten.
# Goedemorgen, Op 9 december ben ik op de Poli geweest voor een afspraak met [PERSOON] waarbij [PERSOON] eveneens is aangesloten.
# iteration: 3995
# The following two sentences are matched:
# [PERSOON] heeft toen de afspraak gemaakt te zullen informeren bij collega's artsen of er meer bekend was van bijwerkingen van de Ustekinumab op de longen, ik had vlekken op de longen en volgens de longarts afkomstig van de medicatie voor de Crohn.Is hier al iets meer van bekend?
# [PERSOON] heeft toen de afspraak gemaakt te zullen informeren bij collega's artsen of er meer bekend was van bijwerkingen van de Ustekinumab op de longen, ik had vlekken op de longen en volgens de longarts afkomstig van de medicatie voor de Crohn.Is hier al iets meer van bekend?
# iteration: 3996
# The following two sentences are matched:
# Ook heb ik bloed laten prikken om de bloedspiegel te bepalen, is hier al meer van bekend?
# Ook heb ik bloed laten prikken om de bloedspiegel te bepalen, is hier al meer van bekend?
# iteration: 3997
# The following two sentences are matched:
# Graag hoor ik van jullie.
# Graag hoor ik van jullie.
# iteration: 3998
# The following two sentences are matched:
# Goedemorgen, is er inmiddels een uitslag van de spiegel van de Ustekinumab?
# Goedemorgen, is er inmiddels een uitslag van de spiegel van de Ustekinumab?
# iteration: 3999
# The following two sentences are matched:
# Heeft [PERSOON] ook eventueel al een antwoord ontvangen op haar navraag in verband met de bijwerkingen van de Ustekinumab?
# Heeft [PERSOON] ook eventueel al een antwoord ontvangen op haar navraag in verband met de bijwerkingen van de Ustekinumab?
# iteration: 4000
# The following two sentences are matched:
# Goedenavond, op 31 januari jl.
# Goedenavond, op 31 januari jl.
# iteration: 4001
# The following two sentences are matched:
# heb ik faeces ingeleverd om de waarde van de calprotectine te meten, is de uitslag hiervan al binnen en hoeveel bedraagt deze.
# heb ik faeces ingeleverd om de waarde van de calprotectine te meten, is de uitslag hiervan al binnen en hoeveel bedraagt deze.
# iteration: 4002
# The following two sentences are matched:
# Goedemiddag,  op  [DATUM] k reeg ik van jullie een mail met een bevestiging voor een Beeldbel-afspraak voor vandaag, [DATUM] om 08:00 uur.
# Goedemiddag,  op  [DATUM] k reeg ik van jullie een mail met een bevestiging voor een Beeldbel-afspraak voor vandaag, [DATUM] om 08:00 uur.
# iteration: 4003
# The following two sentences are matched:
# Ik zou nog een link krijgen om dit te kunnen doen.
# Ik zou nog een link krijgen om dit te kunnen doen.
# iteration: 4004
# The following two sentences are matched:
# Ik heb op 14:30 uur naar de poli Interne gebeld maar hier konden ze de afspraak niet terugvinden.
# Ik heb op 14:30 uur naar de poli Interne gebeld maar hier konden ze de afspraak niet terugvinden.
# iteration: 4005
# The following two sentences are matched:
# Is deze geannuleerd geworden en is wijziging niet doorgegeven geworden?
# Is deze geannuleerd geworden en is wijziging niet doorgegeven geworden?
# iteration: 4006
# The following two sentences are matched:
# Ik heb op 25 mei een CT Thoraxscan gehad en zou daarover worden teruggebeld door [PERSOON].
# Ik heb op 25 mei een CT Thoraxscan gehad en zou daarover worden teruggebeld door [PERSOON].
# iteration: 4007
# The following two sentences are matched:
# Hallo, Dit is de mail die ik heb ontvangen.
# Hallo, Dit is de mail die ik heb ontvangen.
# iteration: 4008
# The following two sentences are matched:
# Goedemorgen, Volgens mijn gegevens en navraag bij de MDL poli, zou [PERSOON] gisteren telefonisch contact met mij opnemen om de uitslag van de CT-scan te bespreken.
# Goedemorgen, Volgens mijn gegevens en navraag bij de MDL poli, zou [PERSOON] gisteren telefonisch contact met mij opnemen om de uitslag van de CT-scan te bespreken.
# iteration: 4009
# The following two sentences are matched:
# Helaas heb ik geen telefoontje van haar gekregen.
# Helaas heb ik geen telefoontje van haar gekregen.
# iteration: 4010
# The following two sentences are matched:
# Is bij jullie bekend wanneer ze dan wel zou bellen, ik wacht vol spanning op de uitslag van de scan.
# Is bij jullie bekend wanneer ze dan wel zou bellen, ik wacht vol spanning op de uitslag van de scan.
# iteration: 4130
# The following two sentences are matched:
# Wat adviseren jullie?
# Wat adviseren jullie?
# iteration: 4273
# The following two sentences are matched:
# Ik hoor het graag.
# Ik hoor het graag.
# iteration: 4289
# The following two sentences are matched:
# [ZORGINSTELLING].
# [ZORGINSTELLING].
# iteration: 4305
# The following two sentences are matched:
# Alles gaat goed.
# Alles gaat goed.
# iteration: 4406
# The following two sentences are matched:
# Dank voor uw snelle reactie.
# Dank voor uw snelle reactie.
# iteration: 4421
# The following two sentences are matched:
# Dank voor uw snelle reactie.
# Dank voor uw snelle reactie.
# iteration: 4779
# The following two sentences are matched:
# Ik hoor het wel.
# Ik hoor het wel.
# iteration: 4803
# The following two sentences are matched:
# Bedankt voor uw reactie.
# Bedankt voor uw reactie.
# iteration: 4852
# The following two sentences are matched:
# Ik hoor het wel.
# Ik hoor het wel.
# iteration: 4918
# The following two sentences are matched:
# Ik hoor het graag van u.
# Ik hoor het graag van u.
# iteration: 4952
# The following two sentences are matched:
# Bedankt voor uw reactie.
# Bedankt voor uw reactie.
# iteration: 4963
# The following two sentences are matched:
# Ik hoor het wel.
# Ik hoor het wel.
#        Message_ID                                           Sentence  \
# 0               3  Ik ben 2 weken geleden met spoed opgenomen in ...
# 1               3  Ik kreeg acuut een pijnlijke druk op de borst,...
# 2               3                  Het begon 1 uur na het avondeten.
# 3               3  Ik had al de hele dag migraine, had dus ook we...
# 4               3  Ik werd heel erg misselijk, braakneigingen, du...
# ...           ...                                                ...
# 41138       32679  Ze hebben de urine op kweek gezet, kan morgenv...
# 41139       32679  Afgelopen jaren is er al vaker bloed in mijn u...
# 41140       32679                   Wat adviseert u hiermee te doen?
# 41141       32681  Hoi [PERSOON], Oke, dat is iig al een gerustst...
# 41142       32681                  Dankjewel voor de snelle reactie!
#
#                                           Clean_Sentence  Sentence_ID  \
# 0      Ik ben 2 weken geleden met spoed opgenomen in ...            1
# 1      Ik kreeg acuut een pijnlijke druk op de borst,...            2
# 2                      Het begon 1 uur na het avondeten.            3
# 3      Ik had al de hele dag migraine, had dus ook we...            4
# 4      Ik werd heel erg misselijk, braakneigingen, du...            5
# ...                                                  ...          ...
# 41138  Ze hebben de urine op kweek gezet, kan morgenv...        41139
# 41139  Afgelopen jaren is er al vaker bloed in mijn u...        41140
# 41140                   Wat adviseert u hiermee te doen?        41141
# 41141  Oke, dat is iig al een geruststelling  ik wach...        41142
# 41142                  Dankjewel voor de snelle reactie!        41143
#
#                                      Translated_Sentence Manual_Category
# 0      I was rushed into the [PRESSION] two weeks ago...               M
# 1      I was acutely under a painful pressure on the ...               M
# 2                        It started 1 hour after dinner.               A
# 3       I had migraines all day, so I hadn't eaten much.               M
# 4      I got very nauseous, vomiting, dizzy and rejuv...               M
# ...                                                  ...             ...
# 41138  They've put the urine on culture, can get the ...            None
# 41139  In recent years, blood has been found in my ur...            None
# 41140              What do you suggest you do with this?            None
# 41141  Hi [PRESSON], Okay, that's a relief;) I'll wai...            None
# 41142                  Thank you for the quick response!            None
#
# [41143 rows x 6 columns]

# %%
len(new_df)
# Out:
# 41143

# %%
new_df
# Out:
#        Message_ID                                           Sentence  \
# 0               3  Ik ben 2 weken geleden met spoed opgenomen in ...
# 1               3  Ik kreeg acuut een pijnlijke druk op de borst,...
# 2               3                  Het begon 1 uur na het avondeten.
# 3               3  Ik had al de hele dag migraine, had dus ook we...
# 4               3  Ik werd heel erg misselijk, braakneigingen, du...
# ...           ...                                                ...
# 41138       32679  Ze hebben de urine op kweek gezet, kan morgenv...
# 41139       32679  Afgelopen jaren is er al vaker bloed in mijn u...
# 41140       32679                   Wat adviseert u hiermee te doen?
# 41141       32681  Hoi [PERSOON], Oke, dat is iig al een gerustst...
# 41142       32681                  Dankjewel voor de snelle reactie!
#
#                                           Clean_Sentence  Sentence_ID  \
# 0      Ik ben 2 weken geleden met spoed opgenomen in ...            1
# 1      Ik kreeg acuut een pijnlijke druk op de borst,...            2
# 2                      Het begon 1 uur na het avondeten.            3
# 3      Ik had al de hele dag migraine, had dus ook we...            4
# 4      Ik werd heel erg misselijk, braakneigingen, du...            5
# ...                                                  ...          ...
# 41138  Ze hebben de urine op kweek gezet, kan morgenv...        41139
# 41139  Afgelopen jaren is er al vaker bloed in mijn u...        41140
# 41140                   Wat adviseert u hiermee te doen?        41141
# 41141  Oke, dat is iig al een geruststelling  ik wach...        41142
# 41142                  Dankjewel voor de snelle reactie!        41143
#
#                                      Translated_Sentence Manual_Category
# 0      I was rushed into the [PRESSION] two weeks ago...               M
# 1      I was acutely under a painful pressure on the ...               M
# 2                        It started 1 hour after dinner.               A
# 3       I had migraines all day, so I hadn't eaten much.               M
# 4      I got very nauseous, vomiting, dizzy and rejuv...               M
# ...                                                  ...             ...
# 41138  They've put the urine on culture, can get the ...            None
# 41139  In recent years, blood has been found in my ur...            None
# 41140              What do you suggest you do with this?            None
# 41141  Hi [PRESSON], Okay, that's a relief;) I'll wai...            None
# 41142                  Thank you for the quick response!            None
#
# [41143 rows x 6 columns]

# %%
new_df.drop_na(new_df["Manual_Category"])

# %%
new_df_annotated = new_df.dropna(subset=["Manual_Category"])

# %%
len(new_df_annotated)
# Out:
# 3921

# %%
new_df_annotated
# Out:
#       Message_ID                                           Sentence  \
# 0              3  Ik ben 2 weken geleden met spoed opgenomen in ...
# 1              3  Ik kreeg acuut een pijnlijke druk op de borst,...
# 2              3                  Het begon 1 uur na het avondeten.
# 3              3  Ik had al de hele dag migraine, had dus ook we...
# 4              3  Ik werd heel erg misselijk, braakneigingen, du...
# ...          ...                                                ...
# 4803        3578                           Bedankt voor uw reactie.
# 4852        3595                                   Ik hoor het wel.
# 4918        3622                           Ik hoor het graag van u.
# 4952        3641                           Bedankt voor uw reactie.
# 4963        3644                                   Ik hoor het wel.
#
#                                          Clean_Sentence  Sentence_ID  \
# 0     Ik ben 2 weken geleden met spoed opgenomen in ...            1
# 1     Ik kreeg acuut een pijnlijke druk op de borst,...            2
# 2                     Het begon 1 uur na het avondeten.            3
# 3     Ik had al de hele dag migraine, had dus ook we...            4
# 4     Ik werd heel erg misselijk, braakneigingen, du...            5
# ...                                                 ...          ...
# 4803                           Bedankt voor uw reactie.         4804
# 4852                                   Ik hoor het wel.         4853
# 4918                           Ik hoor het graag van u.         4919
# 4952                           Bedankt voor uw reactie.         4953
# 4963                                   Ik hoor het wel.         4964
#
#                                     Translated_Sentence Manual_Category
# 0     I was rushed into the [PRESSION] two weeks ago...               M
# 1     I was acutely under a painful pressure on the ...               M
# 2                       It started 1 hour after dinner.               A
# 3      I had migraines all day, so I hadn't eaten much.               M
# 4     I got very nauseous, vomiting, dizzy and rejuv...               M
# ...                                                 ...             ...
# 4803                        Thank you for your comment.               A
# 4852                                      I'll hear it.               A
# 4918                      I'd love to hear it from you.               A
# 4952                        Thank you for your comment.               A
# 4963                                      I'll hear it.               A
#
# [3921 rows x 6 columns]

# %%
new_df_annotated.to_excel("/workspace/persistent/mijnidbcoachnlp/data/analysis_data/new_annotated_df_lg.xlsx", index=False)
