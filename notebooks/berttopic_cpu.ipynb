# %%
# %pip install bertopic
# Out:
# Collecting bertopic
#   Using cached bertopic-0.16.3-py3-none-any.whl.metadata (23 kB)
# Collecting hdbscan>=0.8.29 (from bertopic)
#   Using cached hdbscan-0.8.38.post1.tar.gz (5.8 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting numpy>=1.20.0 (from bertopic)
#   Using cached numpy-2.1.1-cp312-cp312-win_amd64.whl.metadata (59 kB)
# Collecting pandas>=1.1.5 (from bertopic)
#   Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting plotly>=4.7.0 (from bertopic)
#   Using cached plotly-5.24.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting scikit-learn>=0.22.2.post1 (from bertopic)
#   Using cached scikit_learn-1.5.1-cp312-cp312-win_amd64.whl.metadata (12 kB)
# Collecting sentence-transformers>=0.4.1 (from bertopic)
#   Using cached sentence_transformers-3.0.1-py3-none-any.whl.metadata (10 kB)
# Collecting tqdm>=4.41.1 (from bertopic)
#   Using cached tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# Collecting umap-learn>=0.5.0 (from bertopic)
#   Using cached umap_learn-0.5.6-py3-none-any.whl.metadata (21 kB)
# Collecting scipy>=1.0 (from hdbscan>=0.8.29->bertopic)
#   Using cached scipy-1.14.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.0 (from hdbscan>=0.8.29->bertopic)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\p70092940\onedrive - maastricht university\desktop\projects\myibdcoach-nlp\mijnidbcoachnlp\.venv\lib\site-packages (from pandas>=1.1.5->bertopic) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas>=1.1.5->bertopic)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.1.5->bertopic)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting tenacity>=6.2.0 (from plotly>=4.7.0->bertopic)
#   Using cached tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: packaging in c:\users\p70092940\onedrive - maastricht university\desktop\projects\myibdcoach-nlp\mijnidbcoachnlp\.venv\lib\site-packages (from plotly>=4.7.0->bertopic) (24.1)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=0.22.2.post1->bertopic)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting transformers<5.0.0,>=4.34.0 (from sentence-transformers>=0.4.1->bertopic)
#   Using cached transformers-4.44.2-py3-none-any.whl.metadata (43 kB)
# Collecting torch>=1.11.0 (from sentence-transformers>=0.4.1->bertopic)
#   Using cached torch-2.4.1-cp312-cp312-win_amd64.whl.metadata (27 kB)
# Collecting huggingface-hub>=0.15.1 (from sentence-transformers>=0.4.1->bertopic)
#   Using cached huggingface_hub-0.24.6-py3-none-any.whl.metadata (13 kB)
# Collecting Pillow (from sentence-transformers>=0.4.1->bertopic)
#   Using cached pillow-10.4.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Requirement already satisfied: colorama in c:\users\p70092940\onedrive - maastricht university\desktop\projects\myibdcoach-nlp\mijnidbcoachnlp\.venv\lib\site-packages (from tqdm>=4.41.1->bertopic) (0.4.6)
# Collecting numba>=0.51.2 (from umap-learn>=0.5.0->bertopic)
#   Using cached numba-0.60.0-cp312-cp312-win_amd64.whl.metadata (2.8 kB)
# Collecting pynndescent>=0.5 (from umap-learn>=0.5.0->bertopic)
#   Using cached pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Collecting filelock (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic)
#   Using cached filelock-3.16.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic)
#   Using cached fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Collecting pyyaml>=5.1 (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic)
#   Using cached PyYAML-6.0.2-cp312-cp312-win_amd64.whl.metadata (2.1 kB)
# Collecting requests (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting typing-extensions>=3.7.4.3 (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting llvmlite<0.44,>=0.43.0dev0 (from numba>=0.51.2->umap-learn>=0.5.0->bertopic)
#   Using cached llvmlite-0.43.0-cp312-cp312-win_amd64.whl.metadata (4.9 kB)
# Collecting numpy>=1.20.0 (from bertopic)
#   Using cached numpy-2.0.2-cp312-cp312-win_amd64.whl.metadata (59 kB)
# Requirement already satisfied: six>=1.5 in c:\users\p70092940\onedrive - maastricht university\desktop\projects\myibdcoach-nlp\mijnidbcoachnlp\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic) (1.16.0)
# Collecting sympy (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Using cached sympy-1.13.2-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Using cached networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Collecting jinja2 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting setuptools (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Using cached setuptools-74.1.2-py3-none-any.whl.metadata (6.7 kB)
# Collecting regex!=2019.12.17 (from transformers<5.0.0,>=4.34.0->sentence-transformers>=0.4.1->bertopic)
#   Using cached regex-2024.7.24-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Collecting safetensors>=0.4.1 (from transformers<5.0.0,>=4.34.0->sentence-transformers>=0.4.1->bertopic)
#   Using cached safetensors-0.4.5-cp312-none-win_amd64.whl.metadata (3.9 kB)
# Collecting tokenizers<0.20,>=0.19 (from transformers<5.0.0,>=4.34.0->sentence-transformers>=0.4.1->bertopic)
#   Using cached tokenizers-0.19.1-cp312-none-win_amd64.whl.metadata (6.9 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Using cached MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl.metadata (3.1 kB)
# Collecting charset-normalizer<4,>=2 (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic)
#   Using cached charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic)
#   Using cached idna-3.8-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic)
#   Using cached urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic)
#   Using cached certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Using cached bertopic-0.16.3-py3-none-any.whl (143 kB)
# Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl (11.5 MB)
# Using cached plotly-5.24.0-py3-none-any.whl (19.0 MB)
# Using cached scikit_learn-1.5.1-cp312-cp312-win_amd64.whl (10.9 MB)
# Using cached sentence_transformers-3.0.1-py3-none-any.whl (227 kB)
# Using cached tqdm-4.66.5-py3-none-any.whl (78 kB)
# Using cached umap_learn-0.5.6-py3-none-any.whl (85 kB)
# Using cached huggingface_hub-0.24.6-py3-none-any.whl (417 kB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached numba-0.60.0-cp312-cp312-win_amd64.whl (2.7 MB)
# Using cached numpy-2.0.2-cp312-cp312-win_amd64.whl (15.6 MB)
# Using cached pynndescent-0.5.13-py3-none-any.whl (56 kB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached scipy-1.14.1-cp312-cp312-win_amd64.whl (44.5 MB)
# Using cached tenacity-9.0.0-py3-none-any.whl (28 kB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Using cached torch-2.4.1-cp312-cp312-win_amd64.whl (199.4 MB)
# Using cached transformers-4.44.2-py3-none-any.whl (9.5 MB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Using cached pillow-10.4.0-cp312-cp312-win_amd64.whl (2.6 MB)
# Using cached fsspec-2024.9.0-py3-none-any.whl (179 kB)
# Using cached llvmlite-0.43.0-cp312-cp312-win_amd64.whl (28.1 MB)
# Using cached PyYAML-6.0.2-cp312-cp312-win_amd64.whl (156 kB)
# Using cached regex-2024.7.24-cp312-cp312-win_amd64.whl (269 kB)
# Using cached safetensors-0.4.5-cp312-none-win_amd64.whl (286 kB)
# Using cached tokenizers-0.19.1-cp312-none-win_amd64.whl (2.2 MB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Using cached filelock-3.16.0-py3-none-any.whl (16 kB)
# Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Using cached networkx-3.3-py3-none-any.whl (1.7 MB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached setuptools-74.1.2-py3-none-any.whl (1.3 MB)
# Using cached sympy-1.13.2-py3-none-any.whl (6.2 MB)
# Using cached certifi-2024.8.30-py3-none-any.whl (167 kB)
# Using cached charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl (100 kB)
# Using cached idna-3.8-py3-none-any.whl (66 kB)
# Using cached MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl (17 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached urllib3-2.2.2-py3-none-any.whl (121 kB)
# Building wheels for collected packages: hdbscan
#   Building wheel for hdbscan (pyproject.toml): started
#   Building wheel for hdbscan (pyproject.toml): finished with status 'error'
# Failed to build hdbscan
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Building wheel for hdbscan (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [34 lines of output]
#       C:\Users\p70092940\AppData\Local\Temp\pip-build-env-dy0m4n1f\overlay\Lib\site-packages\setuptools\_distutils\dist.py:261: UserWarning: Unknown distribution option: 'test_suite'
#         warnings.warn(msg)
#       C:\Users\p70092940\AppData\Local\Temp\pip-build-env-dy0m4n1f\overlay\Lib\site-packages\setuptools\_distutils\dist.py:261: UserWarning: Unknown distribution option: 'tests_require'
#         warnings.warn(msg)
#       C:\Users\p70092940\AppData\Local\Temp\pip-build-env-dy0m4n1f\overlay\Lib\site-packages\setuptools\dist.py:294: InformationOnly: Normalizing '0.8.38-1' to '0.8.38.post1'
#         self.metadata.version = self._normalize_version(self.metadata.version)
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build\lib.win-amd64-cpython-312
#       creating build\lib.win-amd64-cpython-312\hdbscan
#       copying hdbscan\branches.py -> build\lib.win-amd64-cpython-312\hdbscan
#       copying hdbscan\flat.py -> build\lib.win-amd64-cpython-312\hdbscan
#       copying hdbscan\hdbscan_.py -> build\lib.win-amd64-cpython-312\hdbscan
#       copying hdbscan\plots.py -> build\lib.win-amd64-cpython-312\hdbscan
#       copying hdbscan\prediction.py -> build\lib.win-amd64-cpython-312\hdbscan
#       copying hdbscan\robust_single_linkage_.py -> build\lib.win-amd64-cpython-312\hdbscan
#       copying hdbscan\validity.py -> build\lib.win-amd64-cpython-312\hdbscan
#       copying hdbscan\__init__.py -> build\lib.win-amd64-cpython-312\hdbscan
#       creating build\lib.win-amd64-cpython-312\hdbscan\tests
#       copying hdbscan\tests\test_branches.py -> build\lib.win-amd64-cpython-312\hdbscan\tests
#       copying hdbscan\tests\test_flat.py -> build\lib.win-amd64-cpython-312\hdbscan\tests
#       copying hdbscan\tests\test_hdbscan.py -> build\lib.win-amd64-cpython-312\hdbscan\tests
#       copying hdbscan\tests\test_prediction_utils.py -> build\lib.win-amd64-cpython-312\hdbscan\tests
#       copying hdbscan\tests\test_rsl.py -> build\lib.win-amd64-cpython-312\hdbscan\tests
#       copying hdbscan\tests\__init__.py -> build\lib.win-amd64-cpython-312\hdbscan\tests
#       running build_ext
#       Compiling hdbscan/_hdbscan_tree.pyx because it changed.
#       [1/1] Cythonizing hdbscan/_hdbscan_tree.pyx
#       C:\Users\p70092940\AppData\Local\Temp\pip-build-env-dy0m4n1f\overlay\Lib\site-packages\Cython\Compiler\Main.py:381: FutureWarning: Cython directive 'language_level' not set, using '3str' for now (Py3). This has changed from earlier releases! File: C:\Users\p70092940\AppData\Local\Temp\pip-install-63yr03t3\hdbscan_d217d688ec2b4be18fa52d56fe11a1d1\hdbscan\_hdbscan_tree.pyx
#         tree = Parsing.p_module(s, pxd, full_module_name)
#       building 'hdbscan._hdbscan_tree' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for hdbscan
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (hdbscan)

# %%
# %pip install -U pip setuptools wheel

#CPU OPTION
# %pip install -U spacy
# GPU option
#!pip install tf-keras
#!pip install -U 'spacy[cuda11x]' 
#!python -m spacy download nl_core_news_sm
# Out:
# Requirement already satisfied: pip in c:\users\p70092940\onedrive - maastricht university\desktop\projects\myibdcoach-nlp\mijnidbcoachnlp\.venv\lib\site-packages (24.2)
# Collecting setuptools
#   Using cached setuptools-74.1.2-py3-none-any.whl.metadata (6.7 kB)
# Collecting wheel
#   Using cached wheel-0.44.0-py3-none-any.whl.metadata (2.3 kB)
# Using cached setuptools-74.1.2-py3-none-any.whl (1.3 MB)
# Using cached wheel-0.44.0-py3-none-any.whl (67 kB)
# Installing collected packages: wheel, setuptools
# Successfully installed setuptools-74.1.2 wheel-0.44.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting spacy
#   Using cached spacy-3.7.6-cp312-cp312-win_amd64.whl.metadata (27 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Using cached murmurhash-1.0.10-cp312-cp312-win_amd64.whl.metadata (2.0 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Using cached cymem-2.0.8-cp312-cp312-win_amd64.whl.metadata (8.6 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Using cached preshed-3.0.9-cp312-cp312-win_amd64.whl.metadata (2.2 kB)
# Collecting thinc<8.3.0,>=8.2.2 (from spacy)
#   Using cached thinc-8.2.5-cp312-cp312-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Using cached wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy)
#   Using cached srsly-2.4.8-cp312-cp312-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Using cached catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.1.0 (from spacy)
#   Using cached weasel-0.4.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting typer<1.0.0,>=0.3.0 (from spacy)
#   Using cached typer-0.12.5-py3-none-any.whl.metadata (15 kB)
# Collecting tqdm<5.0.0,>=4.38.0 (from spacy)
#   Using cached tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# Collecting requests<3.0.0,>=2.13.0 (from spacy)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 (from spacy)
#   Using cached pydantic-2.9.1-py3-none-any.whl.metadata (146 kB)
# Collecting jinja2 (from spacy)
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: setuptools in c:\users\p70092940\onedrive - maastricht university\desktop\projects\myibdcoach-nlp\mijnidbcoachnlp\.venv\lib\site-packages (from spacy) (74.1.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\p70092940\onedrive - maastricht university\desktop\projects\myibdcoach-nlp\mijnidbcoachnlp\.venv\lib\site-packages (from spacy) (24.1)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy)
#   Using cached langcodes-3.4.0-py3-none-any.whl.metadata (29 kB)
# Collecting numpy>=1.19.0 (from spacy)
#   Using cached numpy-2.1.1-cp312-cp312-win_amd64.whl.metadata (59 kB)
# Collecting language-data>=1.2 (from langcodes<4.0.0,>=3.2.0->spacy)
#   Using cached language_data-1.2.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.23.3 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Using cached pydantic_core-2.23.3-cp312-none-win_amd64.whl.metadata (6.7 kB)
# Collecting typing-extensions>=4.6.1 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting charset-normalizer<4,>=2 (from requests<3.0.0,>=2.13.0->spacy)
#   Using cached charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests<3.0.0,>=2.13.0->spacy)
#   Using cached idna-3.8-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0.0,>=2.13.0->spacy)
#   Using cached urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests<3.0.0,>=2.13.0->spacy)
#   Using cached certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# Collecting blis<0.8.0,>=0.7.8 (from thinc<8.3.0,>=8.2.2->spacy)
#   Using cached blis-0.7.11-cp312-cp312-win_amd64.whl.metadata (7.6 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.3.0,>=8.2.2->spacy)
#   Using cached confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Collecting numpy>=1.19.0 (from spacy)
#   Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Requirement already satisfied: colorama in c:\users\p70092940\onedrive - maastricht university\desktop\projects\myibdcoach-nlp\mijnidbcoachnlp\.venv\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Collecting click>=8.0.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting shellingham>=1.3.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=10.11.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Using cached rich-13.8.0-py3-none-any.whl.metadata (18 kB)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.1.0->spacy)
#   Using cached cloudpathlib-0.19.0-py3-none-any.whl.metadata (14 kB)
# Collecting smart-open<8.0.0,>=5.2.1 (from weasel<0.5.0,>=0.1.0->spacy)
#   Using cached smart_open-7.0.4-py3-none-any.whl.metadata (23 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->spacy)
#   Using cached MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl.metadata (3.1 kB)
# Collecting marisa-trie>=0.7.7 (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy)
#   Using cached marisa_trie-1.2.0-cp312-cp312-win_amd64.whl.metadata (9.0 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\p70092940\onedrive - maastricht university\desktop\projects\myibdcoach-nlp\mijnidbcoachnlp\.venv\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Collecting wrapt (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy)
#   Using cached wrapt-1.16.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Using cached spacy-3.7.6-cp312-cp312-win_amd64.whl (11.7 MB)
# Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# Using cached cymem-2.0.8-cp312-cp312-win_amd64.whl (39 kB)
# Using cached langcodes-3.4.0-py3-none-any.whl (182 kB)
# Using cached murmurhash-1.0.10-cp312-cp312-win_amd64.whl (25 kB)
# Using cached preshed-3.0.9-cp312-cp312-win_amd64.whl (122 kB)
# Using cached pydantic-2.9.1-py3-none-any.whl (434 kB)
# Using cached pydantic_core-2.23.3-cp312-none-win_amd64.whl (1.9 MB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Using cached spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Using cached srsly-2.4.8-cp312-cp312-win_amd64.whl (478 kB)
# Using cached thinc-8.2.5-cp312-cp312-win_amd64.whl (1.4 MB)
# Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
# Using cached tqdm-4.66.5-py3-none-any.whl (78 kB)
# Using cached typer-0.12.5-py3-none-any.whl (47 kB)
# Using cached wasabi-1.1.3-py3-none-any.whl (27 kB)
# Using cached weasel-0.4.1-py3-none-any.whl (50 kB)
# Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached blis-0.7.11-cp312-cp312-win_amd64.whl (6.6 MB)
# Using cached certifi-2024.8.30-py3-none-any.whl (167 kB)
# Using cached charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl (100 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached cloudpathlib-0.19.0-py3-none-any.whl (49 kB)
# Using cached confection-0.1.5-py3-none-any.whl (35 kB)
# Using cached idna-3.8-py3-none-any.whl (66 kB)
# Using cached language_data-1.2.0-py3-none-any.whl (5.4 MB)
# Using cached MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl (17 kB)
# Using cached rich-13.8.0-py3-none-any.whl (241 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached smart_open-7.0.4-py3-none-any.whl (61 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Using cached urllib3-2.2.2-py3-none-any.whl (121 kB)
# Using cached marisa_trie-1.2.0-cp312-cp312-win_amd64.whl (151 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached wrapt-1.16.0-cp312-cp312-win_amd64.whl (37 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: cymem, wrapt, wasabi, urllib3, typing-extensions, tqdm, spacy-loggers, spacy-legacy, shellingham, numpy, murmurhash, mdurl, MarkupSafe, marisa-trie, idna, cloudpathlib, click, charset-normalizer, certifi, catalogue, annotated-types, srsly, smart-open, requests, pydantic-core, preshed, markdown-it-py, language-data, jinja2, blis, rich, pydantic, langcodes, typer, confection, weasel, thinc, spacy
# Successfully installed MarkupSafe-2.1.5 annotated-types-0.7.0 blis-0.7.11 catalogue-2.0.10 certifi-2024.8.30 charset-normalizer-3.3.2 click-8.1.7 cloudpathlib-0.19.0 confection-0.1.5 cymem-2.0.8 idna-3.8 jinja2-3.1.4 langcodes-3.4.0 language-data-1.2.0 marisa-trie-1.2.0 markdown-it-py-3.0.0 mdurl-0.1.2 murmurhash-1.0.10 numpy-1.26.4 preshed-3.0.9 pydantic-2.9.1 pydantic-core-2.23.3 requests-2.32.3 rich-13.8.0 shellingham-1.5.4 smart-open-7.0.4 spacy-3.7.6 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 thinc-8.2.5 tqdm-4.66.5 typer-0.12.5 typing-extensions-4.12.2 urllib3-2.2.2 wasabi-1.1.3 weasel-0.4.1 wrapt-1.16.0
# Note: you may need to restart the kernel to use updated packages.

# %%
spacy_model = "nl_core_news_sm"

# %%
import spacy
from bertopic import BERTopic
from sklearn.datasets import fetch_20newsgroups

docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))['data']
nlp = spacy.load(spacy_model, exclude=['tagger', 'parser', 'ner', 'attribute_ruler', 'lemmatizer'])

topic_model = BERTopic(embedding_model=nlp)
topics, probs = topic_model.fit_transform(docs)

fig = topic_model.visualize_topics()
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 2
#       1 import spacy
# ----> 2 from bertopic import BERTopic
#       3 from sklearn.datasets import fetch_20newsgroups
#       5 docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))['data']
#
# ModuleNotFoundError: No module named 'bertopic'

# %%
docs[:10]
# Out:
# ["\n\nI am sure some bashers of Pens fans are pretty confused about the lack\nof any kind of posts about the recent Pens massacre of the Devils. Actually,\nI am  bit puzzled too and a bit relieved. However, I am going to put an end\nto non-PIttsburghers' relief with a bit of praise for the Pens. Man, they\nare killing those Devils worse than I thought. Jagr just showed you why\nhe is much better than his regular season stats. He is also a lot\nfo fun to watch in the playoffs. Bowman should let JAgr have a lot of\nfun in the next couple of games since the Pens are going to beat the pulp out of Jersey anyway. I was very disappointed not to see the Islanders lose the final\nregular season game.          PENS RULE!!!\n\n",
#  'My brother is in the market for a high-performance video card that supports\nVESA local bus with 1-2MB RAM.  Does anyone have suggestions/ideas on:\n\n  - Diamond Stealth Pro Local Bus\n\n  - Orchid Farenheit 1280\n\n  - ATI Graphics Ultra Pro\n\n  - Any other high-performance VLB card\n\n\nPlease post or email.  Thank you!\n\n  - Matt\n',
#  '\n\n\n\n\tFinally you said what you dream about. Mediterranean???? That was new....\n\tThe area will be "greater" after some years, like your "holocaust" numbers......\n\n\n\n\n\t\t*****\n\tIs\'t July in USA now????? Here in Sweden it\'s April and still cold.\n\tOr have you changed your calendar???\n\n\n\t\t\t\t\t\t    ****************\n\t\t\t\t\t\t    ******************\n\t\t\t    ***************\n\n\n\tNOTHING OF THE MENTIONED IS TRUE, BUT LET SAY IT\'s TRUE.\n\t\n\tSHALL THE AZERI WOMEN AND CHILDREN GOING TO PAY THE PRICE WITH\n\t\t\t\t\t\t    **************\n\tBEING RAPED, KILLED AND TORTURED BY THE ARMENIANS??????????\n\t\n\tHAVE YOU HEARDED SOMETHING CALLED: "GENEVA CONVENTION"???????\n\tYOU FACIST!!!!!\n\n\n\n\tOhhh i forgot, this is how Armenians fight, nobody has forgot\n\tyou killings, rapings and torture against the Kurds and Turks once\n\tupon a time!\n      \n       \n\n\nOhhhh so swedish RedCross workers do lie they too? What ever you say\n"regional killer", if you don\'t like the person then shoot him that\'s your policy.....l\n\n\n\t\t\t\t\t\t\t\t\t\ti\n\t\t\t\t\t\t\t\t\t\ti\n\t\t\t\t\t\t\t\t\t\ti\n\tConfused?????\t\t\t\t\t\t\t\ti\n\t\t\t\t\t\t\t\t\t\ti\n        Search Turkish planes? You don\'t know what you are talking about.\ti\n        Turkey\'s government has announced that it\'s giving weapons  <-----------i\n        to Azerbadjan since Armenia started to attack Azerbadjan\t\t\n        it self, not the Karabag province. So why search a plane for weapons\t\n        since it\'s content is announced to be weapons?   \n\n\tIf there is one that\'s confused then that\'s you! We have the right (and we do)\n\tto give weapons to the Azeris, since Armenians started the fight in Azerbadjan!\n \n\n\n\tShoot down with what? Armenian bread and butter? Or the arms and personel \n\tof the Russian army?\n\n\n',
#  "\nThink!\n\nIt's the SCSI card doing the DMA transfers NOT the disks...\n\nThe SCSI card can do DMA transfers containing data from any of the SCSI devices\nit is attached when it wants to.\n\nAn important feature of SCSI is the ability to detach a device. This frees the\nSCSI bus for other devices. This is typically used in a multi-tasking OS to\nstart transfers on several devices. While each device is seeking the data the\nbus is free for other commands and data transfers. When the devices are\nready to transfer the data they can aquire the bus and send the data.\n\nOn an IDE bus when you start a transfer the bus is busy until the disk has seeked\nthe data and transfered it. This is typically a 10-20ms second lock out for other\nprocesses wanting the bus irrespective of transfer time.\n",
#  '1)    I have an old Jasmine drive which I cannot use with my new system.\n My understanding is that I have to upsate the driver with a more modern\none in order to gain compatability with system 7.0.1.  does anyone know\nof an inexpensive program to do this?  ( I have seen formatters for <$20\nbuit have no idea if they will work)\n \n2)     I have another ancient device, this one a tape drive for which\nthe back utility freezes the system if I try to use it.  THe drive is a\njasmine direct tape (bought used for $150 w/ 6 tapes, techmar\nmechanism).  Essentially I have the same question as above, anyone know\nof an inexpensive beckup utility I can use with system 7.0.1',
#  '\n\nBack in high school I worked as a lab assistant for a bunch of experimental\npsychologists at Bell Labs.  When they were doing visual perception and\nmemory experiments, they used vector-type displays, with 1-millisecond\nrefresh rates common.\n\nSo your case of 1/200th sec is quite practical, and the experimenters were\nprobably sure that it was 5 milliseconds, not 4 or 6 either.\n\n\nSteve',
#  '\n\nAE is in Dallas...try 214/241-6060 or 214/241-0055.  Tech support may be on\ntheir own line, but one of these should get you started.',
#  "\n[stuff deleted]\n\nOk, here's the solution to your problem.  Move to Canada.  Yesterday I was able\nto watch FOUR games...the NJ-PITT at 1:00 on ABC, LA-CAL at 3:00 (CBC), \nBUFF-BOS at 7:00 (TSN and FOX), and MON-QUE at 7:30 (CBC).  I think that if\neach series goes its max I could be watching hockey playoffs for 40-some odd\nconsecutive nights (I haven't counted so that's a pure guess).\n\nI have two tv's in my house, and I set them up side-by-side to watch MON-QUE\nand keep an eye on BOS-BUFF at the same time.  I did the same for the two\nafternoon games.\n\nBtw, those ABC commentaters were great!  I was quite impressed; they seemed\nto know that their audience wasn't likely to be well-schooled in hockey lore\nand they did an excellent job.  They were quite impartial also, IMO.\n\n",
#  "\n\n\nYeah, it's the second one.  And I believe that price too.  I've been trying\nto get a good look at it on the Bruin-Sabre telecasts, and wow! does it ever\nlook good.  Whoever did that paint job knew what they were doing.  And given\nFuhr's play since he got it, I bet the Bruins are wishing he didn't have it:)\n",
#  '\nIf a Christian means someone who believes in the divinity of Jesus, it is safe\nto say that Jesus was a Christian.\n--\n"On the first day after Christmas my truelove served to me...  Leftover Turkey!\nOn the second day after Christmas my truelove served to me...  Turkey Casserole\n    that she made from Leftover Turkey.\n[days 3-4 deleted] ...  Flaming Turkey Wings! ...\n   -- Pizza Hut commercial (and M*tlu/A*gic bait)']

# %%
path = "./../dataset/Dataset_mijnIBDcoach_NLP_tekstberichten_20240722_Berichten_anonymized_fully.xlsx"

import pandas as pd
df = pd.read_excel(path)
df.head(10)
# Out:
#          ProviderName      ProgramName                              UserGUID  \
# 0        ProviderName      ProgramName                              UserGUID
# 1                 NaN              NaN                                   NaN
# 2  MUMC MijnIBDcoach   MijnIBDcoach4.0  72BF6AE2-1568-4843-A234-51A9F5598B80
# 3  MUMC MijnIBDcoach   MijnIBDcoach4.0  72BF6AE2-1568-4843-A234-51A9F5598B80
# 4  MUMC MijnIBDcoach   MijnIBDcoach4.0  72BF6AE2-1568-4843-A234-51A9F5598B80
# 5  MUMC MijnIBDcoach   MijnIBDcoach4.0  72BF6AE2-1568-4843-A234-51A9F5598B80
# 6  MUMC MijnIBDcoach   MijnIBDcoach4.0  72BF6AE2-1568-4843-A234-51A9F5598B80
# 7  MUMC MijnIBDcoach   MijnIBDcoach4.0  72BF6AE2-1568-4843-A234-51A9F5598B80
# 8  MUMC MijnIBDcoach   MijnIBDcoach4.0  72BF6AE2-1568-4843-A234-51A9F5598B80
# 9  MUMC MijnIBDcoach   MijnIBDcoach4.0  72BF6AE2-1568-4843-A234-51A9F5598B80
#
#                 Datum/tijd                                            Message  \
# 0               Datum/tijd                                            Message
# 1                      NaN                                                NaN
# 2  2020-01-14 16:34:16.323  Goedemiddag,  Dank voor uw aanmelding en het i...
# 3  2020-02-10 12:46:36.230  Beste gebruikers van mijnIBDcoach,   Van 11 fe...
# 4  2020-03-02 08:38:01.253  Beste gebruiker van mijnIBDcoach,   In verband...
# 5  2020-07-28 15:49:29.733  Ik ben 2 weken geleden met spoed opgenomen in ...
# 6  2020-07-28 16:23:42.457  Goedemiddag,   Bedankt voor uw bericht. We zul...
# 7  2020-07-30 09:35:01.573  Goedemorgen,   De bloedwaarden zien er prima u...
# 8  2020-07-31 13:24:08.020  Mijn bloeduitslagen zijn goed hoor ik. Daar be...
# 9  2020-08-03 09:07:30.850  Goedemorgen,   We hebben uw klachten genoteerd...
#
#    richting (van of naar cliënt)  Verzender indien naar cliënt
# 0  richting (van of naar cliënt)  Verzender indien naar cliënt
# 1                            NaN                           NaN
# 2                      To client                   miacilissen
# 3                      To client                   isour1_mumc
# 4                      To client                   isour1_mumc
# 5                    From client                           NaN
# 6                      To client                   isour1_mumc
# 7                      To client                   isour1_mumc
# 8                    From client                           NaN
# 9                      To client                   isour1_mumc

# %%
messages = df["Message"].tolist()
messages = messages[2:]
messages[:10]
# Out:
# ['Goedemiddag,  Dank voor uw aanmelding en het invullen van de eerste vragenlijst.  De eerste 3 maanden ontvangt u deze maandelijks. Daarna mag u zelf aangeven of u deze interval wil verlengen naar 4 maanden.  Wanneer u gebruik wilt maken van de App, ga dan met behulp van de smartphone naar de site [URL-1]. Daar kan de App worden gedownload.  Kijkt u ook eens naar de kenniskuren? Hierin vindt u nog extra informatie. Indien u nog vragen en/of opmerkingen hebt horen we het graag via deze weg.  Vriendelijke groeten, [PERSOON-1]  ',
#  'Beste gebruikers van mijnIBDcoach,   Van 11 februari t/m 16 februari is het mogelijk dat uw berichten met enige vertraging worden beantwoord. In geval van dringende zaken gelieve contact op te nemen met de poli interne geneeskunde: telefoonnummer [TELEFOONNUMMER-1].   Met vriendelijke groet, Het IBDteam ',
#  'Beste gebruiker van mijnIBDcoach,   In verband met de vele vragen over het Coronavirus, sturen we u deze informatie mail.   Standpunt NVR inzake Coronavirus en IBD medicatie Wij volgen het standpunt van de RIVM Stop niet zonder overleg met uw arts met de IBD medicatie, gezien de risico’s van een opvlamming. Het is vooral van belang om het risico op besmetting zoveel mogelijk te beperken door:  (1) hygiëne maatregelen in acht te nemen: – was de handen regelmatig – hoest en nies in de binnenkant van de ellenboog – gebruik papieren zakdoekjes en gooi deze na gebruik weg.  (2) mogelijke risicomomenten op contact met virus infecties te vermijden, dat wil zeggen: – Niet reizen naar gebieden waar het virus is vastgesteld – Niet op bezoek gaan bij mensen die recent (&lt; 2 weken geleden) in gebieden zijn geweest waar het virus is vastgesteld – Niet op bezoek gaan bij mensen met klachten van koorts, hoesten en kortademigheid – Bezoek aan evenementen waar veel mensen zijn zoals concerten of beurzen vermijden.  Bij nieuwe klachten die kunnen passen bij een luchtweginfectie zoals hoesten of toenemende kortademigheid is het verstandig laagdrempelig de temperatuur te meten en bij temperatuurverhoging (&gt;38 graden) in eerste instantie de huisarts telefonisch te raadplegen. Informeer uw huisarts of andere zorgverlener altijd over welke medicatie (naam en dosering) u gebruikt.   Als u voor uw Crohn of colitis ulcerosa  biologische medicatie gebruikt raden wij u aan bij temperatuurverhoging de volgende injectie / infuus  uit te stellen totdat u heeft overlegd met uw arts. Voor meer informatie kan u de RIVM website raadplegen: [URL-1]  Met vriendelijke groet, het IBD-Team.  ',
#  'Ik ben 2 weken geleden met spoed opgenomen in het [PERSOON-1] in [LOCATIE-1] met verdenking van hartklachten. Ik kreeg acuut een pijnlijke druk op de borst, schouderbladen, uitstralend naar de armen. Het begon 1 uur na het avondeten. Ik had al de hele dag migraine, had dus ook weinig gegeten. Ik werd heel erg misselijk, braakneigingen, duizelig en oprispingen.En vreselijke pijn. Op de eerste hulp hebben ze het hart de longen en de bloedvaten onderzocht. hier kwamen geen rare dingen uit. Later op de dag bij het eten van een beschuitje begon het weer. Ze hebben een echo van de gal gemaakt ook zonder resultaat. Er is nog een aanvullend onderzoek van de slokdarm en de maag gedaan, ook geen resultaat. Ik heb nog altijd last van oprispingen, hoofdpijn en gevoelig rond de maagstreek. die enorme pijn heb ik gelukkig niet meer gehad. Morgen moet ik bij jullie bloedprikken, en ontlasting inleveren. Toch voelt het niet helemaal oke.',
#  'Goedemiddag,   Bedankt voor uw bericht. We zullen de bloeduitslagen en calprotectine bepaling opvolgen, misschien kan een van deze resultaten uw klachten verklaren.   met vriendelijke groet, [PERSOON-1] MDL/IBD verpleegkundige ',
#  'Goedemorgen,   De bloedwaarden zien er prima uit. Geen tekenen van te korten of infectie. Het calprotectine (ontlastingsonderzoek) is nog niet bekend. Deze uitslag laat gemiddeld 10 dagen op zich wachten.   Met vriendelijke groet, [PERSOON-1] ',
#  'Mijn bloeduitslagen zijn goed hoor ik. Daar ben ik blij mee. Toch blijven mijn klachten aanhouden. Opboeren, branderige pijn in de maagstreek na het eten. Opgeblazen gevoel. Soms pijnscheuten die aanvalsgewijs komen rond het borstbeen. In [LOCATIE-1] hebben ze bij Slokdarm en maagonderzoek niets gezien. Toch is dit plots ontstaan. Ik heb hier eerder nooit last van gehad.',
#  'Goedemorgen,   We hebben uw klachten genoteerd in uw dossier. In het bloedonderzoek zien we ook geen aanwijzing die deze klachten kunnen verklaren. Het calprotectine (ontlastingsonderzoek) is nog niet bekend.  We zien dat u volgende week een poli afspraak heeft staan bij [PERSOON-1]. Indien de klachten nog niet verdwenen zijn, kan [PERSOON-1] eventueel aanvullend onderzoek aanvragen.   Met vriendelijke groet, [PERSOON-2] ',
#  'Ik ben dinsdagavond op de eerste hulp bij jullie geweest iom [PERSOON-1]. Na aanvullend onderzoek naar huis gestuurd. ik lig nu al de hele dag met een stekende buikpijn. Rommelende buik, geen eetlust en nog altijd misselijk. `paracetamol helpt niiet. Ik weet niet meer wat te doen. De pijn zit rond de navel bovenbuik meer aan de bovenkant. Komt aanvalsgewijs. Ik voel mij niet goed. Er zou aanvullend onderzoek komen poliklinisch, maar zo hou ik dat niet vol.',
#  'Goedemorgen,   Bedankt voor uw bericht. De metoclopramide lijkt dus niet te helpen?  Wij zullen met [PERSOON-1] overleggen welke vervolg stappen er moeten worden genomen en laten u zo spoedig mogelijk iets weten.   Met vriendelijke groet, [PERSOON-2] ']

# %%
nlp = spacy.load(spacy_model, exclude=['tagger', 'parser', 'ner', 'attribute_ruler', 'lemmatizer'])

topic_model = BERTopic(embedding_model=nlp)
topics, probs = topic_model.fit_transform(messages)

fig = topic_model.visualize_topics()
fig.show()
# Out:
# <div>                            <div id="fceb07c0-71bc-429a-88df-6a4480b08cfd" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fceb07c0-71bc-429a-88df-6a4480b08cfd")) {                    Plotly.newPlot(                        "fceb07c0-71bc-429a-88df-6a4480b08cfd",                        [{"customdata":[[0,"nbsp | br | persoon | vriendelijke | goedemorgen",2848],[1,"ik | heb | mijn | maar | ben",1427],[2,"br | onderzoek | uit | dagelijks | onderzochten",773],[3,"factoren | vragenlijst | leven | je | aanpassen",773],[4,"downloaden | app | via | appstore | apple",740],[5,"gevuld | gegevens | onder | problemen | mocht",733],[6,"vernieuwing | grootste | zo | uw | avatar",732],[7,"mijnzorg | afspraken | alle | folders | nalezen",731],[8,"datum | verzenden | vorm | toegang | betekent",723],[9,"daarin | vernieuwingen | nieuwe | mijnibdcoach | overgang",634],[10,"virus | bezoek | medicatie | waar | gebieden",594],[11,"vaccins | nvmdl | vaccinatie | corona | vereniging",582],[12,"februari | dringende | vertraging | beantwoord | zaken",477],[13,"laten | prikken | goedemorgen | zullen | we",233],[14,"poliklinische | polikliniek | berichtenfunctie | verdenking | vallen",193],[15,"waarde | calprotectine | tekenen | tekorten | infectie",174],[16,"fax | apotheek | recept | dank | mail",157],[17,"snelle | reactie | dank | bedankt | groet",147],[18,"installeren | interesse | vindt | bijlage | handleiding",135],[19,"ibdcoach | server | werkzaamheid | overlast | snelheid",130],[20,"bloeduitslagen | meest | recente | uitslag | heer",105],[21,"gefaxt | recept | apotheek | zojuist | groeten",102],[22,"afwijkende | prima | vragenlijsten | groeten | invullen",97],[23,"zorgplan | behandeldoelen | individueel | ziekteactiviteit | vanaf",96],[24,"goedemorgen | bedankt | vaccin | voor | invullen",94],[25,"bijlage | abuis | verzonden | alsnog | gisteren",93],[26,"groeten | persoon | stuur | post | geef",89],[27,"mg | locatie | persoon | datum | afspraak",83],[28,"installeren | interesse | onderzoeker | vindt | bijlage",83],[29,"persoon | ik | heb | hallo | hoi",78],[30,"zullen | faxen | bedankt | goedemorgen | recept",77],[31,"vragenlijsten | frequentie | voortaan | gewijzigd | maanden",72],[32,"bedankt | oke | ok\u00e9 | fijn | hartelijk",72],[33,"dank | persoon | heer | groet | vriendelijke",68],[34,"lijkt | het | dank | te | zwangerschap",64],[35,"maanden | eerste | kijkt | gedownload | smartphone",59],[36,"apotheek | locatie | recept | granu | stix",59],[37,"faxen | zullen | apotheek | recept | persoon",58],[38,"mijn | buik | gevoel | last | ontlasting",58],[39,"gemaild | zojuist | apotheek | recept | br",57],[40,"dank | wel | prima | persoon | je",56],[41,"gefaxt | recept | zojuist | apotheek | gemaild",56],[42,"the | to | you | it | and",55],[43,"person | jullie | id | locatie | hallo",54],[44,"ik | heb | hallo | jullie | gebeld",53],[45,"afspraak | mijn | dermatoloog | poli | vakantie",52],[46,"bloeduitslagen | orde | heer | uitstekend | beste",52],[47,"orde | dank | persoon | uitslag | beste",49],[48,"ik | heb | moet | mijn | ben",49],[49,"dankjewel | hoi | bedankt | persoon | mvg",49],[50,"prikken | laten | bloed | mij | heb",47],[51,"afwijkende | bloeduitslagen | waarden | prima | groeten",47],[52,"dank | wel | ok | oke | fijn",43],[53,"laboratoriumbriefjes | heeft | gewrichtsklachten | inleveren | mdl",43],[54,"snelle | persoon | ik | person | zal",42],[55,"tekenen | tekorten | infectie | bloedwaarden | zien",42],[56,"maanden | eerste | kijkt | smartphone | gedownload",41],[57,"risico | verhoogd | voork\u00f3men | oploopt | blaasontsteking",40],[58,"afspraak | magnesiumhydroxide | het | mijn | per",40],[59,"merci | foto | dankje | danke | thanx",39],[60,"maanden | eerste | kijk | je | ontvang",39],[61,"dank ...
