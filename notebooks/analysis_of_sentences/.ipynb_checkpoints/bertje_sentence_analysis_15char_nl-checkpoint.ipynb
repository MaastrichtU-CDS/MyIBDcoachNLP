# %% [markdown]
# ## 1. Read data

# %% [markdown]
# ### 1.1. The dataset of sentences

# %%
import pandas as pd
sentence_df = pd.read_excel("/workspace/mijnidbcoachnlp/data/analysis_datasets/sentence_data.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /usr/local/lib/python3.8/dist-packages/pandas/compat/_optional.py:141, in import_optional_dependency(name, extra, errors, min_version)
#     140 try:
# --> 141     module = importlib.import_module(name)
#     142 except ImportError:
#
# File /usr/lib/python3.8/importlib/__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1014, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:991, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:973, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 sentence_df = pd.read_excel("/workspace/mijnidbcoachnlp/data/analysis_datasets/sentence_data.xlsx")
#
# File /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /usr/local/lib/python3.8/dist-packages/pandas/io/excel/_base.py:482, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     480 if not isinstance(io, ExcelFile):
#     481     should_close = True
# --> 482     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     483 elif engine and engine != io.engine:
#     484     raise ValueError(
#     485         "Engine should not be specified when passing "
#     486         "an ExcelFile - ExcelFile already has the engine set"
#     487     )
#
# File /usr/local/lib/python3.8/dist-packages/pandas/io/excel/_base.py:1695, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1692 self.engine = engine
#    1693 self.storage_options = storage_options
# -> 1695 self._reader = self._engines[engine](self._io, storage_options=storage_options)
#
# File /usr/local/lib/python3.8/dist-packages/pandas/io/excel/_openpyxl.py:556, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options)
#     541 @doc(storage_options=_shared_docs["storage_options"])
#     542 def __init__(
#     543     self,
#     544     filepath_or_buffer: FilePath | ReadBuffer[bytes],
#     545     storage_options: StorageOptions = None,
#     546 ) -> None:
#     547     """
#     548     Reader using openpyxl engine.
#     549
#    (...)
#     554     {storage_options}
#     555     """
# --> 556     import_optional_dependency("openpyxl")
#     557     super().__init__(filepath_or_buffer, storage_options=storage_options)
#
# File /usr/local/lib/python3.8/dist-packages/pandas/compat/_optional.py:144, in import_optional_dependency(name, extra, errors, min_version)
#     142 except ImportError:
#     143     if errors == "raise":
# --> 144         raise ImportError(msg)
#     145     else:
#     146         return None
#
# ImportError: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.

# %%
sentences = sentence_df["Clean_Sentence"].to_list()

# %% [markdown]
# ### 1.2. Import list of stopwords

# %%
### Importing the list of Dutch stopwords (note that there are customized dutch words in there)

with open('/workspace/mijnidbcoachnlp/data/analysis_datasets/stopwords.txt', 'r') as file:
    lines = [line.strip() for line in file.readlines()]

dutch_stopwords = lines

extra_list = [
    'maandag', 'dinsdag', 'woensdag', 'donderdag', 'vrijdag', 'zaterdag', 'zondag',
    'januari', 'februari', 'maart', 'april', 'mei', 'juni', 'juli', 'augustus', 'september', 'oktober', 'november', 'december',
    'jan', 'feb', 'mrt', 'apr', 'mei', 'jun', 'jul', 'aug', 'sep', 'okt', 'nov', 'dec', "jl", "weken", "week", "dagen", "dag", "mg"
]

dutch_stopwords.extend(extra_list)

# %% [markdown]
# ## 2. Download the embedding model BERTje

# %% [markdown]
# ### 2.1 Download BERTje

# %%
from transformers.pipelines import pipeline
from transformers import AutoTokenizer, AutoModel, TFAutoModel
embedding_model = pipeline("feature-extraction", model="GroNLP/bert-base-dutch-cased")
# Out:
# Some weights of BertModel were not initialized from the model checkpoint at GroNLP/bert-base-dutch-cased and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ### 2.2 Pre-calculate and save sentence embeddings (skip if there are saved embeddings and go to 2.3)

# %%
# pre-calculate the embeddings of the dutch sentences
import numpy as np

embeddings_nl = embedding_model(sentences, truncation=True, padding=True)
sentence_embeddings_nl = np.array([np.mean(embedding, axis=1).flatten() for embedding in embeddings_nl])

# %%
from tqdm import tqdm 
# Initialize an empty list to store embeddings
sentence_embeddings_nl = []

# Use tqdm to track progress
for sentence in tqdm(sentences, desc="Processing Embeddings", unit="sentence"):
    # Compute embedding for the sentence
    embedding = embedding_model(sentence)
    # Average token embeddings to create a sentence-level embedding
    sentence_embedding = np.mean(embedding[0], axis=0)
    # Append to the list
    sentence_embeddings_nl.append(sentence_embedding)

# Convert the list to a NumPy array
sentence_embeddings_nl = np.array(sentence_embeddings_nl)

# Check the shape of the resulting embeddings
print(f"Shape of sentence embeddings: {sentence_embeddings_nl.shape}")

# %%
# save the sentence embeddings
import numpy as np
np.save('/workspace/mijnidbcoachnlp/data/embeddings/sentence_embeddings_bertje_nl_new.npy', sentence_embeddings_nl)

# %% [markdown]
# ### 2.3 Load saved embeddings

# %%
# load the save model
import numpy as np

loaded_embeddings_nl = np.load('/workspace/mijnidbcoachnlp/data/embeddings/sentence_embeddings_bertje_nl_new.npy')

# %%
embeddings=loaded_embeddings_nl

# %% [markdown]
# ## 3. Preparation for Model Evaluation

# %% [markdown]
# ### 3.1 Import the annotated sample set

# %%
annotated_df = pd.read_excel("/workspace/mijnidbcoachnlp/data/analysis_datasets/sample_sentences_for_labeling_100.xlsx", index_col=0)

# %%
annotated_df.head()
# Out:
#      Message_ID  \
# 269         173
# 270         173
# 271         173
# 272         173
# 273         173
#
#                                                                                        Sentence  \
# 269  Beste [PERSOON-1],   het gaat weer iets beter en ik heb gisteren de test proberen te doen.
# 270                    Het liep goed totdat ik probeerde de onderkant van het buisje te breken.
# 271                             Ik kreeg het niet voor elkaar en heb toen meer kracht gebruikt.
# 272                                   Hij lijkt me nu op de verkeerde plek gebroken (zie foto).
# 273                                             De test is uiteindelijk mislukt volgens de app.
#
#                                                                Clean_Sentence  \
# 269     het gaat weer iets beter en ik heb gisteren de test proberen te doen.
# 270  Het liep goed totdat ik probeerde de onderkant van het buisje te breken.
# 271           Ik kreeg het niet voor elkaar en heb toen meer kracht gebruikt.
# 272                   j lijkt me nu op de verkeerde plek gebroken (zie foto).
# 273                           De test is uiteindelijk mislukt volgens de app.
#
#      Sentence_ID  \
# 269          269
# 270          270
# 271          271
# 272          272
# 273          273
#
#                                                                    Translated_Sentence  \
# 269  Dear [PERSOON-1], things are getting better and I tried to do the test yesterday.
# 270                        It went well until I tried to break the bottom of the tube.
# 271                                       I couldn't do it and then I used more power.
# 272                        It looks like it's broken in the wrong place (see picture).
# 273                                   The test ultimately failed according to the app.
#
#     Manual_Label
# 269           A4
# 270           A4
# 271           A5
# 272           A5
# 273           A4

# %% [markdown]
# ### 3.2 Function to build model with different clustering methods

# %%
# set the vectorizer model
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import KMeans
from umap import UMAP
from hdbscan import HDBSCAN
from bertopic.vectorizers import ClassTfidfTransformer
from bertopic.representation import KeyBERTInspired


kmeans_model = KMeans(n_clusters=100)
agglo_model = AgglomerativeClustering(n_clusters=100)
# dimension reduction
ctfidf_model = ClassTfidfTransformer(reduce_frequent_words=True)
representation_model = KeyBERTInspired()

# %%
# function to build the model with different selection of clustering method
# build the BERTopic model
from bertopic import BERTopic
from umap import UMAP
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer

def build_bertopic():
    # Initialize BERTopic with UMAP and HDBSCAN models
    topic_model = BERTopic(
        embedding_model=embedding_model,
        umap_model=UMAP(n_neighbors=10, n_components=2, metric='cosine', random_state=42),
        hdbscan_model=HDBSCAN(min_cluster_size=20, min_samples=10, metric='euclidean', cluster_selection_method='eom', prediction_data=True),
        vectorizer_model=CountVectorizer(stop_words=dutch_stopwords, min_df=2, ngram_range=(1, 2), token_pattern=r'\b[a-zA-Z]{3,}\b'),
        top_n_words=10,
        verbose=True
    )

    # Fit-transform to get document topics and probabilities
    topics, probs = topic_model.fit_transform(sentences, embeddings)
    

    # Return only essential results
    return topic_model

# %% [markdown]
# ## 4. BERTje-HDBSCAN model

# %%
topic_model = build_bertopic()
# Out:
# 2024-11-18 22:17:57,711 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-11-18 22:18:48,173 - BERTopic - Dimensionality - Completed ✓
# 2024-11-18 22:18:48,177 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-11-18 22:18:50,734 - BERTopic - Cluster - Completed ✓
# 2024-11-18 22:18:50,750 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-11-18 22:18:52,110 - BERTopic - Representation - Completed ✓

# %%
# save topic model 
topic_model.save("/workspace/mijnidbcoachnlp/data/result_data/saved_BERTje_model", serialization="pytorch", save_ctfidf=True, save_embedding_model=embedding_model)

# %%
loaded_topic_model = BERTopic.load("/workspace/mijnidbcoachnlp/data/result_data/saved_BERTje_model", embedding_model=embedding_model)

# %%
topic_model.get_topic_info()[:10]
# Out:
#    Topic  Count  \
# 0     -1  19884
# 1      0    474
# 2      1    471
# 3      2    406
# 4      3    381
# 5      4    333
# 6      5    329
# 7      6    265
# 8      7    258
# 9      8    254
#
#                                                                          Name  \
# 0                                           -1_afspraak_ontlasting_bloed_goed
# 1                      0_sturen_recept sturen_apotheek sturen_recept apotheek
# 2  1_ziekenhuis_apotheek ziekenhuis_ziekenhuis ziekenhuis_ziekenhuis apotheek
# 3                                             2_dankjewel_dank_bedankt_alvast
# 4                                              3_roesje_ivm_betalen_griepprik
# 5                                             4_infusie_vraag_overleg_nadelen
# 6                                                      5_buik_rug_pijn_gevoel
# 7                                     6_prima_wacht_helemaal prima_goed wacht
# 8                7_afspraak_afspraak afspraak_afspraak staan_afspraak gepland
# 9                                      8_gestart_ustekinumab_begonnen_gestopt
#
#                                                                                                                                                                            Representation  \
# 0                                                                                                           [afspraak, ontlasting, bloed, goed, keer, gaan, gaat, last, vandaag, laatste]
# 1                                                                       [sturen, recept sturen, apotheek sturen, recept apotheek, wilt, vertellen, nakijken, recept, apotheek, doorgeven]
# 2  [ziekenhuis, apotheek ziekenhuis, ziekenhuis ziekenhuis, ziekenhuis apotheek, prikken ziekenhuis, apotheek, ziekenhuis recept, zorginstelling, afspraak ziekenhuis, ziekenhuis sturen]
# 3                                                                    [dankjewel, dank, bedankt, alvast, fijn dankjewel, fijn dank, dankjewel bedankt, fijn, bedankt dankjewel, dank dank]
# 4                                                                                                   [roesje, ivm, betalen, griepprik, ivm crohn, crohn, waarde, entyvio, kwaad, huiverig]
# 5                                                           [infusie, vraag, overleg, nadelen, omgaand reactie, schrijven, zaken, ter, ontvangen bevolkingsonderzoek, adviseerde contact]
# 6                                                                                                            [buik, rug, pijn, gevoel, krampen, onderbuik, benen, last, buikpijn, handen]
# 7                                                                                    [prima, wacht, helemaal prima, goed wacht, weet voldoende, helemaal, goed, probleem, jazeker, klopt]
# 8                                                     [afspraak, afspraak afspraak, afspraak staan, afspraak gepland, gepland, staan, staat afspraak, poli afspraak, staan afspraak, uur]
# 9                                                                             [gestart, ustekinumab, begonnen, gestopt, bezig, waarde, calprotectine waarde, zakjes, pantazol, zetpillen]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Representative_Docs
# 0                                                                                                                                                                                                                                                                                                                             [En moet ik van te voren echt zo’n vies laxeerdrank drinken aangezien ik geen  Dikke darm meer heb, de vorige keer toen ik opgenomen was hoefde dat niet., ( ik weet dat bijv een tandartsafspraak niet mag 2 weken voor/ na het infuus.), Ok, dan ga ik deze week nog bloed laten prikken.]
# 1                                                                                                                                                                                                                                                                                                                                                                                                                        [Zou u voor mij een nieuw recept naar mijn apotheek kunnen sturen?, Kunt u een nieuw recept naar apotheek voor mij sturen?, Zouden jullie een nieuw recept naar mijn apotheek in  willen sturen?]
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [Gewoon in het [ZIEKENHUIS]., Het was in het [ZIEKENHUIS]., Dit ga ik nu doen in het [ZIEKENHUIS].]
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [is het nog steeds, dankjewel!, Dankjewel dat zal ik doen ., Dan doe ik dat :) dankjewel.]
# 4  [Ik heb donderdag mijn tweemaandelijks  entyvio infuus gehad ,  voorheen heb ik nooit zulke plekken gehad  Vandaar mijn vraag of het door medicatie komt of door de ziekte zelf (CU )  Ook is mijn vraag , moet ik hier even mee naar de huisarts of weet u hoe en wat ik erop mag smeren om het branden weg te nemen  Alvast bedankt    narinx, MDL verpleegkundigen, ik wil even laten weten dat ik een tweede terugplaatsing van een embryo heb gehad vandaag heb ik een zwangerschapstest mogen doen en ben hernieuwd zwanger , hopelijk gaat de zwangerschap deze keer goed lopen en zien we over een paar weke...
# 5                                                                                                                                                                                                                                                                                                                                                               [Ter info voor het overleg v.w.b., Ik heb vandaag terugkoppeling ontvangen van bevolkingsonderzoek en wordt opgeroepen voor een intake n.a.v., Ik heb vandaag terugkoppeling ontvangen van bevolkingsonderzoek en wordt opgeroepen voor een intake n.a.v.]
# 6                                                                                                                                                    [Ik slik nu ander halve week cortiment en ik merk dat ik buikpijn heb links boven in mijn buik ter hoogte van de alvleesklier wat naar mijn rug trekt., Ik slik nu ander halve week cortiment en ik merk dat ik buikpijn heb links boven in mijn buik ter hoogte van de alvleesklier wat naar mijn rug trekt., Ik slik nu ander halve week cortiment en ik merk dat ik buikpijn heb links boven in mijn buik ter hoogte van de alvleesklier wat naar mijn rug trekt.]
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [Dat is prima voor mij., Is prima, zal ik doen., Dat is prima, ik zal deze zo maken.]
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [Op 1 september staat voor mij een afspraak gepland bij ., Op  staat er een afspraak gepland met ., 17/2 is n poli afspraak weer gepland.]
# 9                                                                                                                                                                                                                                                                                                                      [Ik ben afgelopen maandag met Cortiment gestart., In mijn digitale [ZIEKENHUIS] omgeving staat alleen de CRP-waarde (3,2mg/L), maar niet de calprotectine-waarde vermeld., In mijn digitale [ZIEKENHUIS] omgeving staat alleen de CRP-waarde (3,2mg/L), maar niet de calprotectine-waarde vermeld.]

# %%
# Reduce outliers
topics = topic_model.topics_
new_topics = topic_model.reduce_outliers(sentences, topics)
# Out:
# 100%|██████████| 20/20 [00:02<00:00,  8.01it/s]

# %%
topic_model.update_topics(sentences, topics=new_topics)
# Out:
# 2024-11-18 22:25:40,234 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.

# %%
topic_model.save("/workspace/mijnidbcoachnlp/data/result_data/saved_BERTje_model_reduced_outliers", serialization="pytorch", save_ctfidf=True, save_embedding_model=embedding_model)

# %%
loaded_model_ro = BERTopic.load("/workspace/mijnidbcoachnlp/data/result_data/saved_BERTje_model_reduced_outliers", embedding_model=embedding_model)

# %%
# INSPECT topics again # Looks good
topic_model = loaded_model_ro
topic_model.get_topic_info()
# Out:
#      Topic  Count                                     Name  \
# 0       -1    240                     -1_jl_topper_bent_ja
# 1        0   2231            0_pijn_toilet_buikpijn_gevoel
# 2        1    828              1_kunt_zouden_kunnen_sturen
# 3        2    834      2_recept_nieuw_herhaalrecept_nethol
# 4        3    603            3_ziekenhuis_in_apotheek_naar
# ..     ...    ...                                      ...
# 335    334     46  334_nachts_extreem_wakker_zondagochtend
# 336    335     46       335_voet_irritatie_gewricht_aantal
# 337    336     21            336_uw_alvast_reactie_bedankt
# 338    337     49            337_calpro_test_gedaan_gluten
# 339    338     72                338_hoor_graag_jullie_hoe
#
#                                                                                         Representation  \
# 0                        [jl, topper, bent, ja, braakgevoel, vriendekijke, beangstigend, 09, doen, 1x]
# 1                             [pijn, toilet, buikpijn, gevoel, buik, last, veel, wc, diarree, krampen]
# 2                         [kunt, zouden, kunnen, sturen, mij, doorgeven, jullie, willen, wilt, recept]
# 3           [recept, nieuw, herhaalrecept, nethol, aanvragen, herhaal, puri, apotheek, pentasa, graag]
# 4                        [ziekenhuis, in, apotheek, naar, het, bij, gestuurd, komen, prikken, ophalen]
# ..                                                                                                 ...
# 335  [nachts, extreem, wakker, zondagochtend, maagzuur, gespuugd, warm, hierdoor, borrelt, gewrichten]
# 336      [voet, irritatie, gewricht, aantal, sinds, heftige, donderdagavond, warmte, enkels, bepaalde]
# 337                               [uw, alvast, reactie, bedankt, antwoord, voor, advies, jullie, en, ]
# 338            [calpro, test, gedaan, gluten, calprotectine, abces, achtergelaten, ug, score, conform]
# 339              [hoor, graag, jullie, hoe, mogelijkheid, ondernemen, denken, verder, geluk, bevallen]
#
#      Representative_Docs
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ..                   ...
# 335                  NaN
# 336                  NaN
# 337                  NaN
# 338                  NaN
# 339                  NaN
#
# [340 rows x 5 columns]

# %%
vectorizer_model=CountVectorizer(stop_words=dutch_stopwords, min_df=2, ngram_range=(1, 1), token_pattern=r'\b[a-zA-Z]{3,}\b')
topic_model.update_topics(sentences, vectorizer_model=vectorizer_model)
topic_model.get_topic_info()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[401], line 2
#       1 vectorizer_model=CountVectorizer(stop_words=dutch_stopwords, min_df=2, ngram_range=(1, 1), token_pattern=r'\b[a-zA-Z]{3,}\b')
# ----> 2 topic_model.update_topics(sentences, vectorizer_model=vectorizer_model)
#       3 topic_model.get_topic_info()
#
# File /workspace/.venv/lib/python3.8/site-packages/bertopic/_bertopic.py:1569, in BERTopic.update_topics(self, docs, images, topics, top_n_words, n_gram_range, vectorizer_model, ctfidf_model, representation_model)
#    1567     self.topic_embeddings_ = self.topic_embeddings_[1:]
#    1568 else:
# -> 1569     self._create_topic_vectors()
#
# File /workspace/.venv/lib/python3.8/site-packages/bertopic/_bertopic.py:4158, in BERTopic._create_topic_vectors(self, documents, embeddings, mappings)
#    4156 topic_words = [self.get_topic(topic) for topic in topic_list]
#    4157 topic_words = [word[0] for topic in topic_words for word in topic]
# -> 4158 word_embeddings = self._extract_embeddings(topic_words, method="word", verbose=False)
#    4160 # Take the weighted average of word embeddings in a topic based on their c-TF-IDF value
#    4161 # The embeddings var is a single numpy matrix and therefore slicing is necessary to
#    4162 # access the words per topic
#    4163 topic_embeddings = []
#
# File /workspace/.venv/lib/python3.8/site-packages/bertopic/_bertopic.py:3675, in BERTopic._extract_embeddings(self, documents, images, method, verbose)
#    3673     embeddings = self.embedding_model.embed(documents=documents, images=images, verbose=verbose)
#    3674 elif method == "word":
# -> 3675     embeddings = self.embedding_model.embed_words(words=documents, verbose=verbose)
#    3676 elif method == "document":
#    3677     embeddings = self.embedding_model.embed_documents(documents, verbose=verbose)
#
# File /workspace/.venv/lib/python3.8/site-packages/bertopic/backend/_base.py:48, in BaseEmbedder.embed_words(self, words, verbose)
#      35 def embed_words(self, words: List[str], verbose: bool = False) -> np.ndarray:
#      36     """Embed a list of n words into an n-dimensional
#      37     matrix of embeddings.
#      38
#    (...)
#      46
#      47     """
# ---> 48     return self.embed(words, verbose)
#
# File /workspace/.venv/lib/python3.8/site-packages/bertopic/backend/_hftransformers.py:60, in HFTransformerBackend.embed(self, documents, verbose)
#      57 dataset = MyDataset(documents)
#      59 embeddings = []
# ---> 60 for document, features in tqdm(
#      61     zip(documents, self.embedding_model(dataset, truncation=True, padding=True)),
#      62     total=len(dataset),
#      63     disable=not verbose,
#      64 ):
#      65     embeddings.append(self._embed(document, features))
#      67 return np.array(embeddings)
#
# File /workspace/.venv/lib/python3.8/site-packages/tqdm/std.py:1169, in tqdm.__iter__(self)
#    1166 # If the bar is disabled, then just walk the iterable
#    1167 # (note: keep this check outside the loop for performance)
#    1168 if self.disable:
# -> 1169     for obj in iterable:
#    1170         yield obj
#    1171     return
#
# File /workspace/.venv/lib/python3.8/site-packages/transformers/pipelines/pt_utils.py:124, in PipelineIterator.__next__(self)
#     121     return self.loader_batch_item()
#     123 # We're out of items within a batch
# --> 124 item = next(self.iterator)
#     125 processed = self.infer(item, **self.params)
#     126 # We now have a batch of "inferred things".
#
# File /workspace/.venv/lib/python3.8/site-packages/transformers/pipelines/pt_utils.py:125, in PipelineIterator.__next__(self)
#     123 # We're out of items within a batch
#     124 item = next(self.iterator)
# --> 125 processed = self.infer(item, **self.params)
#     126 # We now have a batch of "inferred things".
#     127 if self.loader_batch_size is not None:
#     128     # Try to infer the size of the batch
#
# File /workspace/.venv/lib/python3.8/site-packages/transformers/pipelines/base.py:1209, in Pipeline.forward(self, model_inputs, **forward_params)
#    1207     with inference_context():
#    1208         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1209         model_outputs = self._forward(model_inputs, **forward_params)
#    1210         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1211 else:
#
# File /workspace/.venv/lib/python3.8/site-packages/transformers/pipelines/feature_extraction.py:64, in FeatureExtractionPipeline._forward(self, model_inputs)
#      63 def _forward(self, model_inputs):
# ---> 64     model_outputs = self.model(**model_inputs)
#      65     return model_outputs
#
# File /workspace/.venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /workspace/.venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /workspace/.venv/lib/python3.8/site-packages/transformers/models/bert/modeling_bert.py:1142, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1135 # Prepare head mask if needed
#    1136 # 1.0 in head_mask indicate we keep the head
#    1137 # attention_probs has shape bsz x n_heads x N x N
#    1138 # input head_mask has shape [num_heads] or [num_hidden_layers x num_heads]
#    1139 # and head_mask is converted to shape [num_hidden_layers x batch x num_heads x seq_length x seq_length]
#    1140 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
# -> 1142 encoder_outputs = self.encoder(
#    1143     embedding_output,
#    1144     attention_mask=extended_attention_mask,
#    1145     head_mask=head_mask,
#    1146     encoder_hidden_states=encoder_hidden_states,
#    1147     encoder_attention_mask=encoder_extended_attention_mask,
#    1148     past_key_values=past_key_values,
#    1149     use_cache=use_cache,
#    1150     output_attentions=output_attentions,
#    1151     output_hidden_states=output_hidden_states,
#    1152     return_dict=return_dict,
#    1153 )
#    1154 sequence_output = encoder_outputs[0]
#    1155 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File /workspace/.venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /workspace/.venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /workspace/.venv/lib/python3.8/site-packages/transformers/models/bert/modeling_bert.py:695, in BertEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     684     layer_outputs = self._gradient_checkpointing_func(
#     685         layer_module.__call__,
#     686         hidden_states,
#    (...)
#     692         output_attentions,
#     693     )
#     694 else:
# --> 695     layer_outputs = layer_module(
#     696         hidden_states,
#     697         attention_mask,
#     698         layer_head_mask,
#     699         encoder_hidden_states,
#     700         encoder_attention_mask,
#     701         past_key_value,
#     702         output_attentions,
#     703     )
#     705 hidden_states = layer_outputs[0]
#     706 if use_cache:
#
# File /workspace/.venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /workspace/.venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /workspace/.venv/lib/python3.8/site-packages/transformers/models/bert/modeling_bert.py:585, in BertLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     573 def forward(
#     574     self,
#     575     hidden_states: torch.Tensor,
#    (...)
#     582 ) -> Tuple[torch.Tensor]:
#     583     # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     584     self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 585     self_attention_outputs = self.attention(
#     586         hidden_states,
#     587         attention_mask,
#     588         head_mask,
#     589         output_attentions=output_attentions,
#     590         past_key_value=self_attn_past_key_value,
#     591     )
#     592     attention_output = self_attention_outputs[0]
#     594     # if decoder, the last output is tuple of self-attn cache
#
# File /workspace/.venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /workspace/.venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /workspace/.venv/lib/python3.8/site-packages/transformers/models/bert/modeling_bert.py:524, in BertAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     505 def forward(
#     506     self,
#     507     hidden_states: torch.Tensor,
#    (...)
#     513     output_attentions: Optional[bool] = False,
#     514 ) -> Tuple[torch.Tensor]:
#     515     self_outputs = self.self(
#     516         hidden_states,
#     517         attention_mask,
#    (...)
#     522         output_attentions,
#     523     )
# --> 524     attention_output = self.output(self_outputs[0], hidden_states)
#     525     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#     526     return outputs
#
# File /workspace/.venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /workspace/.venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /workspace/.venv/lib/python3.8/site-packages/transformers/models/bert/modeling_bert.py:468, in BertSelfOutput.forward(self, hidden_states, input_tensor)
#     466 hidden_states = self.dense(hidden_states)
#     467 hidden_states = self.dropout(hidden_states)
# --> 468 hidden_states = self.LayerNorm(hidden_states + input_tensor)
#     469 return hidden_states
#
# File /workspace/.venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /workspace/.venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /workspace/.venv/lib/python3.8/site-packages/torch/nn/modules/normalization.py:202, in LayerNorm.forward(self, input)
#     201 def forward(self, input: Tensor) -> Tensor:
# --> 202     return F.layer_norm(
#     203         input, self.normalized_shape, self.weight, self.bias, self.eps)
#
# File /workspace/.venv/lib/python3.8/site-packages/torch/nn/functional.py:2576, in layer_norm(input, normalized_shape, weight, bias, eps)
#    2572 if has_torch_function_variadic(input, weight, bias):
#    2573     return handle_torch_function(
#    2574         layer_norm, (input, weight, bias), input, normalized_shape, weight=weight, bias=bias, eps=eps
#    2575     )
# -> 2576 return torch.layer_norm(input, normalized_shape, weight, bias, eps, torch.backends.cudnn.enabled)
#
# KeyboardInterrupt:

# %%
#save the topic info
topic_info = topic_model.get_topic_info()
topic_info.to_csv('/workspace/mijnidbcoachnlp/data/result_data/topic_info_bertje.csv', index=False)

# %%
#save the topic info
doc_info = topic_model.get_document_info(sentences)
doc_info.to_csv('/workspace/mijnidbcoachnlp/data/result_data/doc_info_bertje.csv', index=False)

# %% [markdown]
# ### 4.2 Merging topics with hierarchy

# %%
topic_model = BERTopic.load("/workspace/mijnidbcoachnlp/data/result_data/saved_BERTje_model_reduced_outliers", embedding_model=embedding_model)

# %%
topic_model.get_topic_info()
# Out:
#      Topic  Count                                     Name  \
# 0       -1    240                     -1_jl_topper_bent_ja
# 1        0   2231            0_pijn_toilet_buikpijn_gevoel
# 2        1    828              1_kunt_zouden_kunnen_sturen
# 3        2    834      2_recept_nieuw_herhaalrecept_nethol
# 4        3    603            3_ziekenhuis_in_apotheek_naar
# ..     ...    ...                                      ...
# 335    334     46  334_nachts_extreem_wakker_zondagochtend
# 336    335     46       335_voet_irritatie_gewricht_aantal
# 337    336     21            336_uw_alvast_reactie_bedankt
# 338    337     49            337_calpro_test_gedaan_gluten
# 339    338     72                338_hoor_graag_jullie_hoe
#
#                                                                                         Representation  \
# 0                        [jl, topper, bent, ja, braakgevoel, vriendekijke, beangstigend, 09, doen, 1x]
# 1                             [pijn, toilet, buikpijn, gevoel, buik, last, veel, wc, diarree, krampen]
# 2                         [kunt, zouden, kunnen, sturen, mij, doorgeven, jullie, willen, wilt, recept]
# 3           [recept, nieuw, herhaalrecept, nethol, aanvragen, herhaal, puri, apotheek, pentasa, graag]
# 4                        [ziekenhuis, in, apotheek, naar, het, bij, gestuurd, komen, prikken, ophalen]
# ..                                                                                                 ...
# 335  [nachts, extreem, wakker, zondagochtend, maagzuur, gespuugd, warm, hierdoor, borrelt, gewrichten]
# 336      [voet, irritatie, gewricht, aantal, sinds, heftige, donderdagavond, warmte, enkels, bepaalde]
# 337                               [uw, alvast, reactie, bedankt, antwoord, voor, advies, jullie, en, ]
# 338            [calpro, test, gedaan, gluten, calprotectine, abces, achtergelaten, ug, score, conform]
# 339              [hoor, graag, jullie, hoe, mogelijkheid, ondernemen, denken, verder, geluk, bevallen]
#
#      Representative_Docs
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ..                   ...
# 335                  NaN
# 336                  NaN
# 337                  NaN
# 338                  NaN
# 339                  NaN
#
# [340 rows x 5 columns]

# %%
hierarchical_topics = topic_model.hierarchical_topics(sentences)
topic_model.visualize_hierarchy(hierarchical_topics=hierarchical_topics)
# Out:
# 100%|██████████| 338/338 [00:02<00:00, 159.32it/s]
# <div>                            <div id="f16d8503-3016-474f-bbb3-c5ad769b1418" class="plotly-graph-div" style="height:5285px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f16d8503-3016-474f-bbb3-c5ad769b1418")) {                    Plotly.newPlot(                        "f16d8503-3016-474f-bbb3-c5ad769b1418",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["tablet_mg_wijziging_innemen_anrukinzumab","","","azathioprine_betreft_50_2dd_daags"],"x":[0.0,0.8506041858584337,0.8506041858584337,0.0],"xaxis":"x","y":[-5.0,-5.0,-15.0,-15.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["dgs_500_mg_chew_calci","","","foliumzuur_mtx_bestellen_capsules_mg"],"x":[0.0,0.8228519137979539,0.8228519137979539,0.0],"xaxis":"x","y":[-25.0,-25.0,-35.0,-35.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["azathioprine_tablet_betreft_50_2dd","","","foliumzuur_mg_dgs_500_bestellen"],"x":[0.8506041858584337,0.9084323307760783,0.9084323307760783,0.8228519137979539],"xaxis":"x","y":[-10.0,-10.0,-30.0,-30.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["maal_voorgeschreven_daags_bloeddruk_prednisolon","","","psylliumvezels_daags_kuur_voorgeschreven_salofalk"],"x":[0.0,0.6452900225520437,0.6452900225520437,0.0],"xaxis":"x","y":[-45.0,-45.0,-55.0,-55.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["beclometason_dagelijks_gebruik_zetpillen_salofalk","","","slik_gebruik_prednison_gram_per"],"x":[0.0,0.6644449649149928,0.6644449649149928,0.0],"xaxis":"x","y":[-65.0,-65.0,-75.0,-75.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["daags_voorgeschreven_maal_psylliumvezels_gebruik","","","gebruik_slik_prednison_beclometason_dagelijks"],"x":[0.6452900225520437,0.776606070571204,0.776606070571204,0.6644449649149928],"xaxis":"x","y":[-50.0,-50.0,-70.0,-70.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["mg_foliumzuur_azathioprine_500_dgs","","","gebruik_daags_slik_maal_voorgeschreven"],"x":[0.9084323307760783,0.9986273812943818,0.9986273812943818,0.776606070571204],"xaxis":"x","y":[-20.0,-20.0,-60.0,-60.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["gestopt_overgang_besloten_zus_reumatoloog","","","bijwerkingen_gebruik_medicijn_nsaid_gebruikte"],"x":[0.0,0.765974988612277,0.765974988612277,0.0],"xaxis":"x","y":[-85.0,-85.0,-95.0,-95.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["prednisolon_afgebouwd_eustikinimab_dosis_korrels","","","voorgeschreven_voeding_movicolon_risico_zalf"],"x":[0.0,0.7203139648102095,0.7203139648102095,0.0],"xaxis":"x","y":[-105.0,-105.0,-115.0,-115.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["prednisolon_afgebouwd_voorgeschreven_zetpillen_eustikinimab","","","werkt_pricoprep_werkzaam_bloedspiegel_blaasklachten"],"x":[0.7203139648102095,0.8105657073635234,0.8105657073635234,0.0],"xaxis":"x","y":[-110.0,-110.0,-125.0,-125.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["gestopt_bijwerkingen_overgang_gebruik_effect","","","prednisolon_afgebouwd_voorgeschreven_zetpillen_ziekte"],"x":[0.765974988612277,0.8451260342358684,0.8451260342358684,0.8105657073635234],"xaxis":"x","y":[-90.0,-90.0,-117.5,-117.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","mark ...

# %%
#save the topic info
topic_info = topic_model.get_topic_info()
topic_info["Name"].to_list()
# Out:
# ['-1_bedankt_dank_reactie_hoor',
#  '0_last_ontlasting_pijn_buikpijn',
#  '1_afspraak_ontvangen_formulieren_mogelijk',
#  '2_bloed_prikken_ontlasting_uitslag',
#  '3_gebruik_humira_crohn_medicatie',
#  '4_recept_apotheek_ziekenhuis_nieuw',
#  '5_weet_advies_mee_beste',
#  '6_afspraak_contact_uur_telefonisch',
#  '7_gaat_goed_zorgen_voel',
#  '8_huisarts_afspraak_coloscopie_oproep',
#  '9_corona_getest_positief_covid',
#  '10_scan_endoscopie_mri_onderzoek',
#  '11_stress_kilo_afgevallen_eten',
#  '12_zwanger_begonnen_gedaan_zwangerschapstest',
#  '13_werk_meld_begin_gemeld']

# %%
# merge some topics
topics_to_merge = [[20, 328, 207, 301], # Diet
                    [281, 158, 278, 263, 259, 41, 13, 220], # Consultation/Hospital Visit
                    [181, 276, 243, 175, 163, 112,311, 246, 325, 216, 312, 321, 303, 306, 175, 163, 112, 188, 40, 129, 142, 204, 148], # Health Update
                    [261, 297, 190, 53, 70, 131, 171, 251, 323, 203, 225, 300, 160, 67, 111, 252, 213, 176, 258, 257, 66, 224, 162, 52, 49,
                    38, 153, 226, 152, 168, 309, 180, 104, 196, 201], # Medical Advice/Discussion
                    [192, 324, 54, 110], # Exam
                    [210, 103, 135, 106, 63, 62, 288, 113, 149, 81, 109, 92, 159, 14, 88, 332, 108, 79, 95, 134, 250, 75, 284, 169, 266, 193,
                    51, 37, 194, 72], # Medication
                    [329, 268, 215], # Pregnancy
                    [147, 86, 50, 27, 97, 260, 61, 71, 47, 326, 209, 273, 335, 182, 32, 0, 6, 105, 286, 334, 126, 227, 15, 231, 313, 293, 78, 146, 320, 270, 255, 42], # Symptoms
                    [], # Surgery
                    [197, 244, 136, 229, 154, 329, 43, 248, 302, 172], # Vaccination
                    [276, 243], # Work
                    [56, 141, 235, 191, 232, 36, 33, 265, 285, 57, 264, 179, 205, 48, 115, 94, 107, 118, 64,
                    291, 295, 236, 254, 285, 80, 22, 280, 242, 289, 59, 223, 187, 294, 282, 73, 240, 161, 25, 198, 310, 178, 316, 26, 221, 157,
                    55, 127, 24, 17, 16, 34, 5], # Admin comm (survey, patient info, documents)
                    [122, 18, 137, 144, 164, 292, 83, 87, 123, 31, 116, 10, 174, 230], # Appointment/contact
                    [3, 256, 90, 296, 2, 208, 1, 202, 84, 253, 114, 290, 315, 100, 317, 8], # Pharmacy
                    [183, 121, 165, 211, 167, 12, 21, 132, 65, 337, 89, 9, 125, 60, 28, 23, 19, 29, 68, 7, 173, 186, 304, 124], # Test
                    [239, 151, 277, 287, 222, 262, 139, 102, 85, 322, 189, 150, 234, 119, 143, 35, 338, 184, 279, 98, 44, 233, 99, 212, 331, 76, 199, 298, 247, 128,
                    336, 91, 330, 333, 138, 145, 245, 46, 58, 314, 214, 305, 166, 93, 4, 217, 117, 274, 219, 200, 69, 319, 241, 185, 267, 74, 77,
                    249, 82, 307, 177, 318, 269, 156, 195, 238, 218, 272, 155, 275, 271, 299, 228, 308, 237, 96, 206, 133, 101, 327, 170, 39, 130] # Other

]
topic_model.merge_topics(sentences, topics_to_merge)

# %%
doc_info = topic_model.get_document_info(sentences)
doc_info[doc_info["Topic"] == 301]
# Out:
#                                                                                                                                                                                                                                                                      Document  \
# 2294                                                                                                                                                                                                                                                        Kun je dat i.i.g.
# 4575                                                                                                                                                                                                            Ik ga nu dan ook toch weer 2 nutridrink per dag pakken ipv 1.
# 4763                                                                                                                                                                                                                                                        Dus kunt u a.u.b.
# 11597                                                                                                                                                                                                                                    Die andere Nutridrink drink ik niet.
# 14691                                                                                                                                                                                                         Gisteren heb ik mijn nutridrink op de sorgente website besteld.
# 15756                                                                                                                                                                                                                                                       Kan jullie a.u.b.
# 15774                                                                                                                                                                                                                                              en ,  Kunnen jullie a.u.b.
# 20302                                                                                                                                                                                                                                                    willen jullie a.u.b.
# 27275                                                                                                                                                                                                                                 Ik heb ook echt geen zin in Nutridrink!
# 28020                                                                                                                                                                                                                                                    Kunnen jullie a.u.b.
# 28024                                                                                                                                                                                                                                                    Kunnen jullie a.u.b.
# 28027                                                                                                                                                                                                                                                    Kunnen jullie a.u.b.
# 28030                                                                                                                                                                                                                                                    Kunnen jullie a.u.b.
# 28033                                                                                                                                                                                                                                                    Kunnen jullie a.u.b.
# 28057                                                                                                                                                                                                                                                    Kunnen jullie a.u.b.
# 28061                                                                                                                                                                                                                                                    Kunnen jullie a.u.b.
# 28064                                                                                                                                                                                                                                         Kunnen jullie het recept a.u.b.
# 28065                                                                                                                                                                                                                                                    Kunnen jullie a.u.b.
# 31667                                                                                                                                                                                                                                                       Kunt u mij z.s.m.
# 33297                                                                                                                                                                                                            Ik drink geen nutridrink meer gezien ik zelf alles kan eten.
# 33368                                                                                                                                                     'Eet' sinds dinsdag, op advies van de diëtiste, alleen vloeibaar met 3 nutridrink per dag, dat gaat relatief prima.
# 34429                                                                                                                                                                                                                                                    Is Nutridrink o.i.d.
# 36445                                                                                                                                                                                                                                                    Kunnen jullie a.u.b.
# 36559                                                                                                                                                                                                                              Ben toen ook terug gestart met nutridrink.
# 36567                                                                                                                                                                                                                              Ben toen ook terug gestart met nutridrink.
# 36575                                                                                                                                                                                                                              Ben toen ook terug gestart met nutridrink.
# 36583                                                                                                                                                                                                                              Ben toen ook terug gestart met nutridrink.
# 37313  graag zou ik  willen weten of de machtiging bij medireva voor de bijvoeding (nutridrink)die ik heb gehad nog geld en of t mogelijk is om een nieuwe machtiging aan te vragen aangezien ik blijf afvallen en van de 63 kg die ik eerst woog ik nu nog maar 56,4 kg ben.
# 37766                            Drink al weken nutridrink en eet beetje vloeibaar  en drink elke avond zakje movicolon..maar ben vannacht naar huisartsenpost moeten gaan met snijdende aanhoudende pijn in middenrif, dat uitstraalt naar achterkant tussen schouderbladen.
# 41171                                                                                                                                                                                                                                                    Kunnen jullie a.u.b.
# 41173                                                                                                                                                                                                                                                    Kunnen jullie a.u.b.
# 41178                                                                                                                                                                                                                                                    Kunnen jullie a.u.b.
# 41180                                                                                                                                                                                                                                                    Kunnen jullie a.u.b.
# 41183                                                                                                                                                                                                                                                    Kunnen jullie a.u.b.
# 41293                                                                                                                                                                                                                                           Kunnen jullie deze mij a.u.b.
#
#        Topic                                    Name  \
# 2294     301  301_nutridrink_drink_vloeibaar_gestart
# 4575     301  301_nutridrink_drink_vloeibaar_gestart
# 4763     301  301_nutridrink_drink_vloeibaar_gestart
# 11597    301  301_nutridrink_drink_vloeibaar_gestart
# 14691    301  301_nutridrink_drink_vloeibaar_gestart
# 15756    301  301_nutridrink_drink_vloeibaar_gestart
# 15774    301  301_nutridrink_drink_vloeibaar_gestart
# 20302    301  301_nutridrink_drink_vloeibaar_gestart
# 27275    301  301_nutridrink_drink_vloeibaar_gestart
# 28020    301  301_nutridrink_drink_vloeibaar_gestart
# 28024    301  301_nutridrink_drink_vloeibaar_gestart
# 28027    301  301_nutridrink_drink_vloeibaar_gestart
# 28030    301  301_nutridrink_drink_vloeibaar_gestart
# 28033    301  301_nutridrink_drink_vloeibaar_gestart
# 28057    301  301_nutridrink_drink_vloeibaar_gestart
# 28061    301  301_nutridrink_drink_vloeibaar_gestart
# 28064    301  301_nutridrink_drink_vloeibaar_gestart
# 28065    301  301_nutridrink_drink_vloeibaar_gestart
# 31667    301  301_nutridrink_drink_vloeibaar_gestart
# 33297    301  301_nutridrink_drink_vloeibaar_gestart
# 33368    301  301_nutridrink_drink_vloeibaar_gestart
# 34429    301  301_nutridrink_drink_vloeibaar_gestart
# 36445    301  301_nutridrink_drink_vloeibaar_gestart
# 36559    301  301_nutridrink_drink_vloeibaar_gestart
# 36567    301  301_nutridrink_drink_vloeibaar_gestart
# 36575    301  301_nutridrink_drink_vloeibaar_gestart
# 36583    301  301_nutridrink_drink_vloeibaar_gestart
# 37313    301  301_nutridrink_drink_vloeibaar_gestart
# 37766    301  301_nutridrink_drink_vloeibaar_gestart
# 41171    301  301_nutridrink_drink_vloeibaar_gestart
# 41173    301  301_nutridrink_drink_vloeibaar_gestart
# 41178    301  301_nutridrink_drink_vloeibaar_gestart
# 41180    301  301_nutridrink_drink_vloeibaar_gestart
# 41183    301  301_nutridrink_drink_vloeibaar_gestart
# 41293    301  301_nutridrink_drink_vloeibaar_gestart
#
#                                                                                                     Representation  \
# 2294   [nutridrink, drink, vloeibaar, gestart, machtiging, middenrif, achterkant, medireva, snijdende, bijvoeding]
# 4575   [nutridrink, drink, vloeibaar, gestart, machtiging, middenrif, achterkant, medireva, snijdende, bijvoeding]
# 4763   [nutridrink, drink, vloeibaar, gestart, machtiging, middenrif, achterkant, medireva, snijdende, bijvoeding]
# 11597  [nutridrink, drink, vloeibaar, gestart, machtiging, middenrif, achterkant, medireva, snijdende, bijvoeding]
# 14691  [nutridrink, drink, vloeibaar, gestart, machtiging, middenrif, achterkant, medireva, snijdende, bijvoeding]
# 15756  [nutridrink, drink, vloeibaar, gestart, machtiging, middenrif, achterkant, medireva, snijdende, bijvoeding]
# 15774  [nutridrink, drink, vloeibaar, gestart, machtiging, middenrif, achterkant, medireva, snijdende, bijvoeding]
# 20302  [nutridrink, drink, vloeibaar, gestart, machtiging, middenrif, achterkant, medireva, snijdende, bijvoeding]
# 27275  [nutridrink, drink, vloeibaar, gestart, machtiging, middenrif, achterkant, medireva, snijdende, bijvoeding]
# 28020  [nutridrink, drink, vloeibaar, gestart, machtiging, middenrif, achterkant, medireva, snijdende, bijvoeding]
# 28024  [nutridrink, drink, vloeibaar, gestart, machtiging, middenrif, achterkant, medireva, snijdende, bijvoeding]
# 28027  [nutridrink, drink, vloeibaar, gestart, machtiging, middenrif, achterkant, medireva, snijdende, bijvoeding]
# 28030  [nutridrink, drink, vloeibaar, gestart, machtiging, middenrif, achterkant, medireva, snijdende, bijvoeding]
# 28033  [nutridrink, drink, vloeibaar, gestart, machtiging, middenrif, achterkant, medireva, snijdende, bijvoeding]
# 28057  [nutridrink, drink, vloeibaar, gestart, machtiging, middenrif, achterkant, medireva, snijdende, bijvoeding]
# 28061  [nutridrink, drink, vloeibaar, gestart, machtiging, middenrif, achterkant, medireva, snijdende, bijvoeding]
# 28064  [nutridrink, drink, vloeibaar, gestart, machtiging, middenrif, achterkant, medireva, snijdende, bijvoeding]
# 28065  [nutridrink, drink, vloeibaar, gestart, machtiging, middenrif, achterkant, medireva, snijdende, bijvoeding]
# 31667  [nutridrink, drink, vloeibaar, gestart, machtiging, middenrif, achterkant, medireva, snijdende, bijvoeding]
# 33297  [nutridrink, drink, vloeibaar, gestart, machtiging, middenrif, achterkant, medireva, snijdende, bijvoeding]
# 33368  [nutridrink, drink, vloeibaar, gestart, machtiging, middenrif, achterkant, medireva, snijdende, bijvoeding]
# 34429  [nutridrink, drink, vloeibaar, gestart, machtiging, middenrif, achterkant, medireva, snijdende, bijvoeding]
# 36445  [nutridrink, drink, vloeibaar, gestart, machtiging, middenrif, achterkant, medireva, snijdende, bijvoeding]
# 36559  [nutridrink, drink, vloeibaar, gestart, machtiging, middenrif, achterkant, medireva, snijdende, bijvoeding]
# 36567  [nutridrink, drink, vloeibaar, gestart, machtiging, middenrif, achterkant, medireva, snijdende, bijvoeding]
# 36575  [nutridrink, drink, vloeibaar, gestart, machtiging, middenrif, achterkant, medireva, snijdende, bijvoeding]
# 36583  [nutridrink, drink, vloeibaar, gestart, machtiging, middenrif, achterkant, medireva, snijdende, bijvoeding]
# 37313  [nutridrink, drink, vloeibaar, gestart, machtiging, middenrif, achterkant, medireva, snijdende, bijvoeding]
# 37766  [nutridrink, drink, vloeibaar, gestart, machtiging, middenrif, achterkant, medireva, snijdende, bijvoeding]
# 41171  [nutridrink, drink, vloeibaar, gestart, machtiging, middenrif, achterkant, medireva, snijdende, bijvoeding]
# 41173  [nutridrink, drink, vloeibaar, gestart, machtiging, middenrif, achterkant, medireva, snijdende, bijvoeding]
# 41178  [nutridrink, drink, vloeibaar, gestart, machtiging, middenrif, achterkant, medireva, snijdende, bijvoeding]
# 41180  [nutridrink, drink, vloeibaar, gestart, machtiging, middenrif, achterkant, medireva, snijdende, bijvoeding]
# 41183  [nutridrink, drink, vloeibaar, gestart, machtiging, middenrif, achterkant, medireva, snijdende, bijvoeding]
# 41293  [nutridrink, drink, vloeibaar, gestart, machtiging, middenrif, achterkant, medireva, snijdende, bijvoeding]
#
#        Representative_Docs  \
# 2294                   NaN
# 4575                   NaN
# 4763                   NaN
# 11597                  NaN
# 14691                  NaN
# 15756                  NaN
# 15774                  NaN
# 20302                  NaN
# 27275                  NaN
# 28020                  NaN
# 28024                  NaN
# 28027                  NaN
# 28030                  NaN
# 28033                  NaN
# 28057                  NaN
# 28061                  NaN
# 28064                  NaN
# 28065                  NaN
# 31667                  NaN
# 33297                  NaN
# 33368                  NaN
# 34429                  NaN
# 36445                  NaN
# 36559                  NaN
# 36567                  NaN
# 36575                  NaN
# 36583                  NaN
# 37313                  NaN
# 37766                  NaN
# 41171                  NaN
# 41173                  NaN
# 41178                  NaN
# 41180                  NaN
# 41183                  NaN
# 41293                  NaN
#
#                                                                                                               Top_n_words  \
# 2294   nutridrink - drink - vloeibaar - gestart - machtiging - middenrif - achterkant - medireva - snijdende - bijvoeding
# 4575   nutridrink - drink - vloeibaar - gestart - machtiging - middenrif - achterkant - medireva - snijdende - bijvoeding
# 4763   nutridrink - drink - vloeibaar - gestart - machtiging - middenrif - achterkant - medireva - snijdende - bijvoeding
# 11597  nutridrink - drink - vloeibaar - gestart - machtiging - middenrif - achterkant - medireva - snijdende - bijvoeding
# 14691  nutridrink - drink - vloeibaar - gestart - machtiging - middenrif - achterkant - medireva - snijdende - bijvoeding
# 15756  nutridrink - drink - vloeibaar - gestart - machtiging - middenrif - achterkant - medireva - snijdende - bijvoeding
# 15774  nutridrink - drink - vloeibaar - gestart - machtiging - middenrif - achterkant - medireva - snijdende - bijvoeding
# 20302  nutridrink - drink - vloeibaar - gestart - machtiging - middenrif - achterkant - medireva - snijdende - bijvoeding
# 27275  nutridrink - drink - vloeibaar - gestart - machtiging - middenrif - achterkant - medireva - snijdende - bijvoeding
# 28020  nutridrink - drink - vloeibaar - gestart - machtiging - middenrif - achterkant - medireva - snijdende - bijvoeding
# 28024  nutridrink - drink - vloeibaar - gestart - machtiging - middenrif - achterkant - medireva - snijdende - bijvoeding
# 28027  nutridrink - drink - vloeibaar - gestart - machtiging - middenrif - achterkant - medireva - snijdende - bijvoeding
# 28030  nutridrink - drink - vloeibaar - gestart - machtiging - middenrif - achterkant - medireva - snijdende - bijvoeding
# 28033  nutridrink - drink - vloeibaar - gestart - machtiging - middenrif - achterkant - medireva - snijdende - bijvoeding
# 28057  nutridrink - drink - vloeibaar - gestart - machtiging - middenrif - achterkant - medireva - snijdende - bijvoeding
# 28061  nutridrink - drink - vloeibaar - gestart - machtiging - middenrif - achterkant - medireva - snijdende - bijvoeding
# 28064  nutridrink - drink - vloeibaar - gestart - machtiging - middenrif - achterkant - medireva - snijdende - bijvoeding
# 28065  nutridrink - drink - vloeibaar - gestart - machtiging - middenrif - achterkant - medireva - snijdende - bijvoeding
# 31667  nutridrink - drink - vloeibaar - gestart - machtiging - middenrif - achterkant - medireva - snijdende - bijvoeding
# 33297  nutridrink - drink - vloeibaar - gestart - machtiging - middenrif - achterkant - medireva - snijdende - bijvoeding
# 33368  nutridrink - drink - vloeibaar - gestart - machtiging - middenrif - achterkant - medireva - snijdende - bijvoeding
# 34429  nutridrink - drink - vloeibaar - gestart - machtiging - middenrif - achterkant - medireva - snijdende - bijvoeding
# 36445  nutridrink - drink - vloeibaar - gestart - machtiging - middenrif - achterkant - medireva - snijdende - bijvoeding
# 36559  nutridrink - drink - vloeibaar - gestart - machtiging - middenrif - achterkant - medireva - snijdende - bijvoeding
# 36567  nutridrink - drink - vloeibaar - gestart - machtiging - middenrif - achterkant - medireva - snijdende - bijvoeding
# 36575  nutridrink - drink - vloeibaar - gestart - machtiging - middenrif - achterkant - medireva - snijdende - bijvoeding
# 36583  nutridrink - drink - vloeibaar - gestart - machtiging - middenrif - achterkant - medireva - snijdende - bijvoeding
# 37313  nutridrink - drink - vloeibaar - gestart - machtiging - middenrif - achterkant - medireva - snijdende - bijvoeding
# 37766  nutridrink - drink - vloeibaar - gestart - machtiging - middenrif - achterkant - medireva - snijdende - bijvoeding
# 41171  nutridrink - drink - vloeibaar - gestart - machtiging - middenrif - achterkant - medireva - snijdende - bijvoeding
# 41173  nutridrink - drink - vloeibaar - gestart - machtiging - middenrif - achterkant - medireva - snijdende - bijvoeding
# 41178  nutridrink - drink - vloeibaar - gestart - machtiging - middenrif - achterkant - medireva - snijdende - bijvoeding
# 41180  nutridrink - drink - vloeibaar - gestart - machtiging - middenrif - achterkant - medireva - snijdende - bijvoeding
# 41183  nutridrink - drink - vloeibaar - gestart - machtiging - middenrif - achterkant - medireva - snijdende - bijvoeding
# 41293  nutridrink - drink - vloeibaar - gestart - machtiging - middenrif - achterkant - medireva - snijdende - bijvoeding
#
#        Representative_document
# 2294                     False
# 4575                     False
# 4763                     False
# 11597                    False
# 14691                    False
# 15756                    False
# 15774                    False
# 20302                    False
# 27275                    False
# 28020                    False
# 28024                    False
# 28027                    False
# 28030                    False
# 28033                    False
# 28057                    False
# 28061                    False
# 28064                    False
# 28065                    False
# 31667                    False
# 33297                    False
# 33368                    False
# 34429                    False
# 36445                    False
# 36559                    False
# 36567                    False
# 36575                    False
# 36583                    False
# 37313                    False
# 37766                    False
# 41171                    False
# 41173                    False
# 41178                    False
# 41180                    False
# 41183                    False
# 41293                    False

# %%
# merge some topics
topics_to_merge = [[2, 12]
]
topic_model.merge_topics(sentences, topics_to_merge)

# %%
# Manually Put Labels in the Label Column
# Create the customized label column
topic_info["Label"] = None

# %%
topic_info.to_excel('/workspace/mijnidbcoachnlp/data/result_data/final_topic_info_bertje.xlsx', index=False)

# %%
labeled_topic_info = pd.read_excel('/workspace/mijnidbcoachnlp/data/result_data/merged_topic_info_bertje_labeled.xlsx')

# %%
labeled_topic_info.rename(columns={"Unnamed: 5": "Model_Label"}, inplace=True)

# %%
merged_doc_info = topic_model.get_document_info(sentences)
merged_doc_info.to_excel('/workspace/mijnidbcoachnlp/data/result_data/merged_doc_info_bertje.xlsx', index=False)

# %%
merged_doc_info["Sentence_ID"] = merged_doc_info.index

# %%
annotated_df['Sentence_ID'] = annotated_df['Sentence_ID'].astype(str)
merged_doc_info['Sentence_ID'] = merged_doc_info['Sentence_ID'].astype(str)

# %%
# Now perform the merge
annotated_df = pd.merge(
    annotated_df,
    merged_doc_info[['Sentence_ID', 'Topic', 'Top_n_words']],
    on='Sentence_ID',
    how='left'
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[385], line 2
#       1 # Now perform the merge
# ----> 2 annotated_df = pd.merge(
#       3     annotated_df,
#       4     merged_doc_info[['Sentence_ID', 'Topic', 'Top_n_words']],
#       5     on='Sentence_ID',
#       6     how='left'
#       7 )
#
# File /workspace/.venv/lib/python3.8/site-packages/pandas/core/reshape/merge.py:148, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     131 @Substitution("\nleft : DataFrame or named Series")
#     132 @Appender(_merge_doc, indents=0)
#     133 def merge(
#    (...)
#     146     validate: str | None = None,
#     147 ) -> DataFrame:
# --> 148     op = _MergeOperation(
#     149         left,
#     150         right,
#     151         how=how,
#     152         on=on,
#     153         left_on=left_on,
#     154         right_on=right_on,
#     155         left_index=left_index,
#     156         right_index=right_index,
#     157         sort=sort,
#     158         suffixes=suffixes,
#     159         indicator=indicator,
#     160         validate=validate,
#     161     )
#     162     return op.get_result(copy=copy)
#
# File /workspace/.venv/lib/python3.8/site-packages/pandas/core/reshape/merge.py:741, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     733 (
#     734     self.left_join_keys,
#     735     self.right_join_keys,
#     736     self.join_names,
#     737 ) = self._get_merge_keys()
#     739 # validate the merge keys dtypes. We may need to coerce
#     740 # to avoid incompatible dtypes
# --> 741 self._maybe_coerce_merge_keys()
#     743 # If argument passed to validate,
#     744 # check if columns specified as unique
#     745 # are in fact unique.
#     746 if validate is not None:
#
# File /workspace/.venv/lib/python3.8/site-packages/pandas/core/reshape/merge.py:1401, in _MergeOperation._maybe_coerce_merge_keys(self)
#    1395     # unless we are merging non-string-like with string-like
#    1396     elif (
#    1397         inferred_left in string_types and inferred_right not in string_types
#    1398     ) or (
#    1399         inferred_right in string_types and inferred_left not in string_types
#    1400     ):
# -> 1401         raise ValueError(msg)
#    1403 # datetimelikes must match exactly
#    1404 elif needs_i8_conversion(lk.dtype) and not needs_i8_conversion(rk.dtype):
#
# ValueError: You are trying to merge on int64 and object columns. If you wish to proceed you should use pd.concat

# %%
annotated_df = pd.merge(
    annotated_df,
    labeled_topic_info[['Topic', 'Model_Label']],
    on='Topic',
    how='left'
)

# %%
# Filter the DataFrame for manual labels equal to "A4"
label = "M7"
test_df = annotated_df[annotated_df["Manual_Label"] == label]

# Calculate the accuracy as the percentage of matches
accuracy = (test_df['Manual_Label'] == test_df['Model_Label']).sum() / len(test_df)

# Output the accuracy
print(f"Accuracy for Manual_Label == {label}: {accuracy * 100:.2f}%")
# Out:
# Accuracy for Manual_Label == M7: 0.00%
